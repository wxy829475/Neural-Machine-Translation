# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import numpy as np
import pdb
import pandas as pd
from tqdm import tqdm
import io
import pickle
import os
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.optim import lr_scheduler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
PAD_idx = 0
SOS_idx = 1
EOS_idx = 2
UNK_idx= 3
batch_size = 256
MAX_SENTENCE_LENGTH = 70

# %%
tgt_pretrained_path = '../data/cc.en.300.vec'
src_pretrained_path = '../data/cc.vi.300.vec'
data_prefix = '../data/'

# %% [markdown]
# ## Read data

# %%
train_tgt = open('../data/iwslt-vi-en/train.tok.en' , encoding='utf-8').read().strip().split('\n')
val_tgt = open('../data/iwslt-vi-en/dev.tok.en', encoding='utf-8').read().strip().split('\n')
test_tgt = open('../data/iwslt-vi-en/test.tok.en', encoding='utf-8').read().strip().split('\n')
train_tgt[:5]
# Out:
# ['Rachel Pike : The science behind a climate headline',
#  'In 4 minutes , atmospheric chemist Rachel Pike provides a glimpse of the massive scientific effort behind the bold headlines on climate change , with her team -- one of thousands who contributed -- taking a risky flight over the rainforest in pursuit of data on a key molecule .',
#  'I &apos;d like to talk to you today about the scale of the scientific effort that goes into making the headlines you see in the paper .',
#  'Headlines that look like this when they have to do with climate change , and headlines that look like this when they have to do with air quality or smog .',
#  'They are both two branches of the same field of atmospheric science .']

# %%
train_src = open('../data/iwslt-vi-en/train.tok.vi', encoding='utf-8').read().strip().split('\n')
val_src = open('../data/iwslt-vi-en/dev.tok.vi', encoding='utf-8').read().strip().split('\n')
test_src = open('../data/iwslt-vi-en/test.tok.vi', encoding='utf-8').read().strip().split('\n')
train_src[:5]
# Out:
# ['Khoa_học đằng_sau một tiêu_đề về khí_hậu',
#  'Trong 4 phút , chuyên_gia hoá_học khí_quyển Rachel Pike giới_thiệu sơ_lược về những nỗ_lực khoa_học miệt_mài đằng_sau những tiêu_đề táo_bạo về biến_đổi khí_hậu , cùng với đoàn nghiên_cứu của mình - - hàng ngàn người đã cống_hiến cho dự_án này - - một chuyến bay mạo_hiểm qua rừng_già để tìm_kiếm thông_tin về một phân_tử then_chốt .',
#  'Tôi muốn cho các bạn biết về sự to_lớn của những nỗ_lực khoa_học đã góp_phần làm_nên các dòng tít bạn thường thấy trên báo .',
#  'Có những dòng trông như thế_này khi bàn về biến_đổi khí_hậu , và như thế_này khi nói về chất_lượng không_khí hay khói bụi .',
#  'Cả hai đều là một nhánh của cùng một lĩnh_vực trong ngành khoa_học khí_quyển .']

# %% [markdown]
# ## Data statistics

# %%
print ('Length of train data:', len(train_tgt))
print ('Length of val data:', len(val_tgt))
print ('Length of test data:', len(test_tgt))
# Out:
# Length of train data: 133317
# Length of val data: 1268
# Length of test data: 1553

# %%
def to_dataframe(en, ch, len_raio=0.95):
    en_len_list, ch_len_list = [], []
    for en_sample, ch_sample in zip(en, ch):
        en_len_list.append(len(en_sample))
        ch_len_list.append(len(ch_sample))
    df = pd.DataFrame({'en': en, 
                       'en_len': en_len_list,
                       'vi': ch,
                       'vi_len': ch_len_list
                      })
    en_len_at_ratio = sorted(en_len_list)[int(len_raio*len(en_len_list))]
    ch_len_at_ratio = sorted(ch_len_list)[int(len_raio*len(ch_len_list))]
    return df, max(en_len_at_ratio, ch_len_at_ratio)

# %% [markdown]
# ## Data Preprocessing

# %%
# Get the vocabulary based on the training data
from collections import Counter

def get_vocabulary(data, VOCABULARY_SIZE_en=10000, VOCABULARY_SIZE_zh=10000, min_time=None):
    en_vocab, ch_vocab = [], []
    for idx, row in data.iterrows():
        en_vocab += row['en'].split()
        ch_vocab += row['vi'].split()
    en_token_counter = Counter(en_vocab)
    ch_token_counter = Counter(ch_vocab)
    print ("Number of en words: {}, vi words: {}".format(len(en_token_counter), len(ch_token_counter)))

    en_word, en_count = zip(*en_token_counter.most_common(VOCABULARY_SIZE_en))
    ch_word, ch_count  = zip(*ch_token_counter.most_common(VOCABULARY_SIZE_zh))
    print (en_count[-1], ch_count[-1])
    en_id2token = ['<PAD>','<SOS>','<EOS>','<UNK>'] + list(en_word)
    en_token2id = dict(zip(en_id2token, np.arange(len(en_id2token))))
    ch_id2token = ['<PAD>','<SOS>','<EOS>','<UNK>'] + list(ch_word)
    ch_token2id = dict(zip(ch_id2token, np.arange(len(ch_id2token))))
    return en_id2token, en_token2id, ch_id2token, ch_token2id

# %%
def load_vectors(fname):
    """
    load the pretrained word embeddings
    param fname: the path the to the word embedding
    return: 
            a dictionary of the {word: embedding}
    """
    fin = io.open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    for line in tqdm(fin):
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = list(map(float, tokens[1:]))
    return data

# %%
def load_pickle(data_path, callback, *callback_args):
    """
    Create huge file with the callback function if not exist, otherwise load directly
    param data_path: the path of the load file if exist, otherwise the path to store the created file
    param callback: the function to generate the data if not exist
    param callback_args: the argument for the callback:
    return: 
            the data, either loaded or created by callback
    """

    data_path = data_prefix+data_path
    if os.path.isfile(data_path):
        print ('File exists, load from path...')
        data = pickle.load(open(data_path, 'rb'))
    else:
        print ('File not exists, creating...')
        data = callback(*callback_args)
        pickle.dump(data, open(data_path, 'wb'))
    return data

# %%
def get_embedding_weights(whole_vec, id2token):
    """
    get the embeddings based on the word, create the embedding matrix
    param whole_vec: the dictionary of pretrained embeddings
    param id2token: the whole vocabulary
    return:
            embedding matrix
    """
    weight = np.zeros((len(id2token), len(whole_vec['sky'])))
    mask = np.zeros((len(id2token)))
    for i, word in enumerate(id2token[1:]):
        if word in whole_vec.keys():
            weight[i+1] = np.array(whole_vec[word])
        elif i<3:
            weight[i+1] = np.array(np.random.randn(300))
        else:
            weight[i+1] = np.array(whole_vec['UNK'])
            mask[i+1] = 1
            print ("Out of vocabulary word: ", word)   
    return weight, mask

# %%
#Turn a Unicode string to plain ASCII
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

def normalizeZh(s):
    s = s.strip()
    s = re.sub( '\s+', ' ', s )
    return s

def normalizeVi(s):
    s = s.lower().strip()
    s =re.sub(r"[-()\"#/@;:<>{}`+=~|,]", "", s)
    s = re.sub(r"[0-9]","",s)
    s = re.sub( '\s+', ' ', s)
    return s

# %%
def token_to_index(sentence, token2id):
    indicies_data = []
    for s in sentence:
        tokens = s.split(' ')
        index_list =[token2id[token] if token in token2id else UNK_idx for token in tokens]
        assert len(tokens) == len(index_list)
        indicies_data.append(index_list)
    return indicies_data

# %%
normalize_train_tgt = [normalizeString(s) for s in train_tgt]
normalize_val_tgt = [normalizeString(s) for s in val_tgt]
normalize_test_tgt = [normalizeString(s) for s in test_tgt]

# %%
normalize_train_tgt[:5]
# Out:
# ['rachel pike the science behind a climate headline',
#  'in minutes atmospheric chemist rachel pike provides a glimpse of the massive scientific effort behind the bold headlines on climate change with her team one of thousands who contributed taking a risky flight over the rainforest in pursuit of data on a key molecule .',
#  'i apos d like to talk to you today about the scale of the scientific effort that goes into making the headlines you see in the paper .',
#  'headlines that look like this when they have to do with climate change and headlines that look like this when they have to do with air quality or smog .',
#  'they are both two branches of the same field of atmospheric science .']

# %%
normalize_train_src = [normalizeVi(s) for s in train_src]
normalize_val_src = [normalizeVi(s) for s in val_src]
normalize_test_src = [normalizeVi(s) for s in test_src]

# %%
normalize_train_src[0]
# Out:
# 'khoa_học đằng_sau một tiêu_đề về khí_hậu'

# %%
train_df, pad_len = to_dataframe(normalize_train_tgt, normalize_train_src)
val_df, _ = to_dataframe(normalize_val_tgt, normalize_val_src)
test_df, _ = to_dataframe(normalize_test_tgt, normalize_test_src)

# %%
tgt_id2token, tgt_token2id, src_id2token, src_token2id = get_vocabulary(train_df,6600,11000, min_time=30)
# Out:
# Number of en words: 41267, vi words: 33913
# 19 6

# %%
train_tgt_indicies = token_to_index(normalize_train_tgt, tgt_token2id)
val_tgt_indicies = token_to_index(normalize_val_tgt, tgt_token2id)
test_tgt_indicies = token_to_index(normalize_test_tgt, tgt_token2id)

# %%
train_src_indicies = token_to_index(normalize_train_src, src_token2id)
val_src_indicies = token_to_index(normalize_val_src, src_token2id)
test_src_indicies = token_to_index(normalize_test_src, src_token2id)

# %%
tgt_pretrain_emb, zh_pretrain_emb = [], []
# print ('-'*100)
# tgt_pretrain_emb = load_pickle('en_pretrain_emb.p', load_vectors, tgt_pretrained_path)
print ('-'*100)
tgt_embedding, _ = load_pickle('eng_embedding6.6k_vi.p', get_embedding_weights, tgt_pretrain_emb, tgt_id2token)
# Out:
# ----------------------------------------------------------------------------------------------------
# File exists, load from path...

# %%
print ('-'*100)
src_pretrain_emb = load_pickle('vi_pretrain_emb.p', load_vectors, src_pretrained_path)
print ('-'*100)
src_embedding, _ = load_pickle('vi_embedding1.1w.p', get_embedding_weights, src_pretrain_emb, src_id2token)
# Out:
# 1106it [00:00, 11059.11it/s]
# ----------------------------------------------------------------------------------------------------
# File not exists, creating...
# 2000000it [02:08, 15565.33it/s]
# ----------------------------------------------------------------------------------------------------
# File not exists, creating...
# Out of vocabulary word:  chúng_ta
# Out of vocabulary word:  có_thể
# Out of vocabulary word:  chúng_tôi
# Out of vocabulary word:  tất_cả
# Out of vocabulary word:  thế_giới
# Out of vocabulary word:  thực_sự
# Out of vocabulary word:  bắt_đầu
# Out of vocabulary word:  vấn_đề
# Out of vocabulary word:  thay_đổi
# Out of vocabulary word:  sử_dụng
# Out of vocabulary word:  bởi_vì
# Out of vocabulary word:  thế_nào
# Out of vocabulary word:  không_thể
# Out of vocabulary word:  bây_giờ
# Out of vocabulary word:  đầu_tiên
# Out of vocabulary word:  quan_trọng
# Out of vocabulary word:  con_người
# Out of vocabulary word:  thời_gian
# Out of vocabulary word:  phát_triển
# Out of vocabulary word:  nghiên_cứu
# Out of vocabulary word:  làm_việc
# Out of vocabulary word:  có_một
# Out of vocabulary word:  tại_sao
# Out of vocabulary word:  hệ_thống
# Out of vocabulary word:  câu_chuyện
# Out of vocabulary word:  một_cách
# Out of vocabulary word:  vì_vậy
# Out of vocabulary word:  xã_hội
# Out of vocabulary word:  trở_thành
# Out of vocabulary word:  khả_năng
# Out of vocabulary word:  ý_tưởng
# Out of vocabulary word:  phụ_nữ
# Out of vocabulary word:  cuộc_sống
# Out of vocabulary word:  khoa_học
# Out of vocabulary word:  như_vậy
# Out of vocabulary word:  một_số
# Out of vocabulary word:  công_nghệ
# Out of vocabulary word:  thực_hiện
# Out of vocabulary word:  ví_dụ
# Out of vocabulary word:  thực_tế
# Out of vocabulary word:  thiết_kế
# Out of vocabulary word:  hoàn_toàn
# Out of vocabulary word:  tuyệt_vời
# Out of vocabulary word:  cảm_ơn
# Out of vocabulary word:  đơn_giản
# Out of vocabulary word:  cuối_cùng
# Out of vocabulary word:  thông_tin
# Out of vocabulary word:  hoạt_động
# Out of vocabulary word:  thật_sự
# Out of vocabulary word:  đối_với
# Out of vocabulary word:  công_việc
# Out of vocabulary word:  một_vài
# Out of vocabulary word:  cố_gắng
# Out of vocabulary word:  quyết_định
# Out of vocabulary word:  xây_dựng
# Out of vocabulary word:  tế_bào
# Out of vocabulary word:  trở_nên
# Out of vocabulary word:  bao_giờ
# Out of vocabulary word:  thậm_chí
# Out of vocabulary word:  thú_vị
# Out of vocabulary word:  thành_phố
# Out of vocabulary word:  câu_hỏi
# Out of vocabulary word:  trả_lời
# Out of vocabulary word:  cảm_thấy
# Out of vocabulary word:  dữ_liệu
# Out of vocabulary word:  kinh_tế
# Out of vocabulary word:  bản_thân
# Out of vocabulary word:  vì_thế
# Out of vocabulary word:  người_ta
# Out of vocabulary word:  lý_do
# Out of vocabulary word:  giống_như
# Out of vocabulary word:  quốc_gia
# Out of vocabulary word:  có_lẽ
# Out of vocabulary word:  tổ_chức
# Out of vocabulary word:  công_ty
# Out of vocabulary word:  năng_lượng
# Out of vocabulary word:  cơ_thể
# Out of vocabulary word:  gọi_là
# Out of vocabulary word:  nói_chuyện
# Out of vocabulary word:  bất_cứ
# Out of vocabulary word:  suy_nghĩ
# Out of vocabulary word:  hôm_nay
# Out of vocabulary word:  hình_ảnh
# Out of vocabulary word:  dự_án
# Out of vocabulary word:  gia_đình
# Out of vocabulary word:  đặc_biệt
# Out of vocabulary word:  tương_lai
# Out of vocabulary word:  quá_trình
# Out of vocabulary word:  môi_trường
# Out of vocabulary word:  cộng_đồng
# Out of vocabulary word:  tưởng_tượng
# Out of vocabulary word:  khác_biệt
# Out of vocabulary word:  như_thế
# Out of vocabulary word:  chia_sẻ
# Out of vocabulary word:  máy_tính
# Out of vocabulary word:  ảnh_hưởng
# Out of vocabulary word:  cơ_bản
# Out of vocabulary word:  như_là
# Out of vocabulary word:  xảy_ra
# Out of vocabulary word:  tiếp_tục
# Out of vocabulary word:  tham_gia
# Out of vocabulary word:  thiết_bị
# Out of vocabulary word:  không_gian
# Out of vocabulary word:  chương_trình
# Out of vocabulary word:  đàn_ông
# Out of vocabulary word:  tồn_tại
# Out of vocabulary word:  giải_quyết
# Out of vocabulary word:  trở_lại
# Out of vocabulary word:  vũ_trụ
# Out of vocabulary word:  quan_tâm
# Out of vocabulary word:  chắc_chắn
# Out of vocabulary word:  thế_này
# Out of vocabulary word:  liên_quan
# Out of vocabulary word:  thành_công
# Out of vocabulary word:  tự_nhiên
# Out of vocabulary word:  hiệu_quả
# Out of vocabulary word:  trẻ_em
# Out of vocabulary word:  sáng_tạo
# Out of vocabulary word:  toàn_cầu
# Out of vocabulary word:  cơ_hội
# Out of vocabulary word:  duy_nhất
# Out of vocabulary word:  một_chút
# Out of vocabulary word:  nghệ_thuật
# Out of vocabulary word:  rõ_ràng
# Out of vocabulary word:  hầu_hết
# Out of vocabulary word:  trường_hợp
# Out of vocabulary word:  tương_tự
# Out of vocabulary word:  khu_vực
# Out of vocabulary word:  giá_trị
# Out of vocabulary word:  trung_quốc
# Out of vocabulary word:  ngôn_ngữ
# Out of vocabulary word:  kết_nối
# Out of vocabulary word:  ngày_nay
# Out of vocabulary word:  chính_phủ
# Out of vocabulary word:  lịch_sử
# Out of vocabulary word:  thời_điểm
# Out of vocabulary word:  phức_tạp
# Out of vocabulary word:  sản_xuất
# Out of vocabulary word:  kết_quả
# Out of vocabulary word:  quan_hệ
# Out of vocabulary word:  cá_nhân
# Out of vocabulary word:  bộ_não
# Out of vocabulary word:  văn_hoá
# Out of vocabulary word:  nghĩa_là
# Out of vocabulary word:  mô_hình
# Out of vocabulary word:  ánh_sáng
# Out of vocabulary word:  tất_nhiên
# Out of vocabulary word:  giáo_dục
# Out of vocabulary word:  toàn_bộ
# Out of vocabulary word:  trái_đất
# Out of vocabulary word:  sản_phẩm
# Out of vocabulary word:  chính_xác
# Out of vocabulary word:  không_phải
# Out of vocabulary word:  tập_trung
# Out of vocabulary word:  hạnh_phúc
# Out of vocabulary word:  khám_phá
# Out of vocabulary word:  vậy_nên
# Out of vocabulary word:  tìm_kiếm
# Out of vocabulary word:  ý_nghĩa
# Out of vocabulary word:  sức_khoẻ
# Out of vocabulary word:  giải_thích
# Out of vocabulary word:  xung_quanh
# Out of vocabulary word:  cuộc_đời
# Out of vocabulary word:  đất_nước
# Out of vocabulary word:  bao_nhiêu
# Out of vocabulary word:  cảm_giác
# Out of vocabulary word:  bảo_vệ
# Out of vocabulary word:  di_chuyển
# Out of vocabulary word:  chính_trị
# Out of vocabulary word:  khác_nhau
# Out of vocabulary word:  xuất_hiện
# Out of vocabulary word:  cho_rằng
# Out of vocabulary word:  nhìn_thấy
# Out of vocabulary word:  khó_khăn
# Out of vocabulary word:  bình_thường
# Out of vocabulary word:  hành_tinh
# Out of vocabulary word:  bệnh_nhân
# Out of vocabulary word:  cho_phép
# Out of vocabulary word:  trung_tâm
# Out of vocabulary word:  kết_thúc
# Out of vocabulary word:  công_cụ
# Out of vocabulary word:  sau_đó
# Out of vocabulary word:  phát_hiện
# Out of vocabulary word:  ung_thư
# Out of vocabulary word:  đại_học
# Out of vocabulary word:  lựa_chọn
# Out of vocabulary word:  hành_động
# Out of vocabulary word:  động_vật
# Out of vocabulary word:  tìm_ra
# Out of vocabulary word:  làm_cho
# Out of vocabulary word:  cung_cấp
# Out of vocabulary word:  nhận_thức
# Out of vocabulary word:  tiếp_theo
# Out of vocabulary word:  phần_trăm
# Out of vocabulary word:  hiện_nay
# Out of vocabulary word:  làm_sao
# Out of vocabulary word:  trải_nghiệm
# Out of vocabulary word:  bác_sĩ
# Out of vocabulary word:  thần_kinh
# Out of vocabulary word:  có_vẻ
# Out of vocabulary word:  yêu_cầu
# Out of vocabulary word:  tự_do
# Out of vocabulary word:  thông_minh
# Out of vocabulary word:  sinh_học
# Out of vocabulary word:  hy_vọng
# Out of vocabulary word:  thử_nghiệm
# Out of vocabulary word:  bất_kỳ
# Out of vocabulary word:  âm_thanh
# Out of vocabulary word:  hiện_tại
# Out of vocabulary word:  ấn_độ
# Out of vocabulary word:  thí_nghiệm
# Out of vocabulary word:  giải_pháp
# Out of vocabulary word:  phản_ứng
# Out of vocabulary word:  phương_pháp
# Out of vocabulary word:  kiểm_soát
# Out of vocabulary word:  trước_khi
# Out of vocabulary word:  hơn_là
# Out of vocabulary word:  mặt_trời
# Out of vocabulary word:  sức_mạnh
# Out of vocabulary word:  tìm_thấy
# Out of vocabulary word:  trò_chơi
# Out of vocabulary word:  quan_sát
# Out of vocabulary word:  thế_là
# Out of vocabulary word:  điều_khiển
# Out of vocabulary word:  kinh_doanh
# Out of vocabulary word:  tác_phẩm
# Out of vocabulary word:  chú_ý
# Out of vocabulary word:  vị_trí
# Out of vocabulary word:  cái_gì
# Out of vocabulary word:  chăm_sóc
# Out of vocabulary word:  âm_nhạc
# Out of vocabulary word:  lãnh_đạo
# Out of vocabulary word:  chiến_tranh
# Out of vocabulary word:  đô_la
# Out of vocabulary word:  dân_chủ
# Out of vocabulary word:  con_số
# Out of vocabulary word:  dễ_dàng
# Out of vocabulary word:  sinh_viên
# Out of vocabulary word:  cấu_trúc
# Out of vocabulary word:  kiểm_tra
# Out of vocabulary word:  sự_thật
# Out of vocabulary word:  mục_tiêu
# Out of vocabulary word:  cảm_nhận
# Out of vocabulary word:  vô_cùng
# Out of vocabulary word:  ngạc_nhiên
# Out of vocabulary word:  nhận_ra
# Out of vocabulary word:  máy_bay
# Out of vocabulary word:  bên_trong
# Out of vocabulary word:  đưa_ra
# Out of vocabulary word:  phân_tử
# Out of vocabulary word:  xem_xét
# Out of vocabulary word:  giáo_viên
# Out of vocabulary word:  cảm_xúc
# Out of vocabulary word:  thế_hệ
# Out of vocabulary word:  thay_vì
# Out of vocabulary word:  thể_hiện
# Out of vocabulary word:  lĩnh_vực
# Out of vocabulary word:  đầu_tư
# Out of vocabulary word:  trong_vòng
# Out of vocabulary word:  cám_ơn
# Out of vocabulary word:  tuy_nhiên
# Out of vocabulary word:  thông_qua
# Out of vocabulary word:  thực_ra
# Out of vocabulary word:  sinh_vật
# Out of vocabulary word:  tiếp_cận
# Out of vocabulary word:  số_lượng
# Out of vocabulary word:  an_toàn
# Out of vocabulary word:  kỹ_thuật
# Out of vocabulary word:  công_nghiệp
# Out of vocabulary word:  tác_động
# Out of vocabulary word:  học_sinh
# Out of vocabulary word:  đánh_giá
# Out of vocabulary word:  mặc_dù
# Out of vocabulary word:  kết_hợp
# Out of vocabulary word:  giai_đoạn
# Out of vocabulary word:  đối_mặt
# Out of vocabulary word:  phần_lớn
# Out of vocabulary word:  kế_hoạch
# Out of vocabulary word:  truyền_thông
# Out of vocabulary word:  cần_thiết
# Out of vocabulary word:  phòng_thí_nghiệm
# Out of vocabulary word:  giúp_đỡ
# Out of vocabulary word:  điện_thoại
# Out of vocabulary word:  đạo_đức
# Out of vocabulary word:  sẵn_sàng
# Out of vocabulary word:  thị_trường
# Out of vocabulary word:  biến_đổi
# Out of vocabulary word:  thức_ăn
# Out of vocabulary word:  tìm_hiểu
# Out of vocabulary word:  phẫu_thuật
# Out of vocabulary word:  tương_tác
# Out of vocabulary word:  nào_đó
# Out of vocabulary word:  tiến_hoá
# Out of vocabulary word:  hành_vi
# Out of vocabulary word:  khán_giả
# Out of vocabulary word:  mục_đích
# Out of vocabulary word:  trách_nhiệm
# Out of vocabulary word:  mức_độ
# Out of vocabulary word:  mạng_lưới
# Out of vocabulary word:  ngay_cả
# Out of vocabulary word:  dĩ_nhiên
# Out of vocabulary word:  liên_kết
# Out of vocabulary word:  nguy_hiểm
# Out of vocabulary word:  cụ_thể
# Out of vocabulary word:  điều_kiện
# Out of vocabulary word:  trước_đây
# Out of vocabulary word:  quan_điểm
# Out of vocabulary word:  mạnh_mẽ
# Out of vocabulary word:  giới_thiệu
# Out of vocabulary word:  cũng_như
# Out of vocabulary word:  vật_liệu
# Out of vocabulary word:  nổi_tiếng
# Out of vocabulary word:  thực_phẩm
# Out of vocabulary word:  kiến_thức
# Out of vocabulary word:  chấp_nhận
# Out of vocabulary word:  lắng_nghe
# Out of vocabulary word:  khái_niệm
# Out of vocabulary word:  trong_suốt
# Out of vocabulary word:  bản_đồ
# Out of vocabulary word:  trong_khi
# Out of vocabulary word:  chuẩn_bị
# Out of vocabulary word:  may_mắn
# Out of vocabulary word:  kinh_ngạc
# Out of vocabulary word:  thật_là
# Out of vocabulary word:  bao_gồm
# Out of vocabulary word:  trung_bình
# Out of vocabulary word:  quản_lý
# Out of vocabulary word:  khổng_lồ
# Out of vocabulary word:  thất_bại
# Out of vocabulary word:  thế_kỷ
# Out of vocabulary word:  mà_còn
# Out of vocabulary word:  đôi_khi
# Out of vocabulary word:  dân_số
# Out of vocabulary word:  hợp_tác
# Out of vocabulary word:  cơ_quan
# Out of vocabulary word:  của_ông
# Out of vocabulary word:  bất_kì
# Out of vocabulary word:  nhanh_chóng
# Out of vocabulary word:  theo_dõi
# Out of vocabulary word:  giờ_đây
# Out of vocabulary word:  so_với
# Out of vocabulary word:  nhân_viên
# Out of vocabulary word:  lợi_ích
# Out of vocabulary word:  quyền_lực
# Out of vocabulary word:  nghệ_sĩ
# Out of vocabulary word:  dịch_vụ
# Out of vocabulary word:  tình_yêu
# Out of vocabulary word:  truyền_thống
# Out of vocabulary word:  vật_lý
# Out of vocabulary word:  vai_trò
# Out of vocabulary word:  địa_phương
# Out of vocabulary word:  cùng_với
# Out of vocabulary word:  tiến_hành
# Out of vocabulary word:  ủng_hộ
# Out of vocabulary word:  khí_hậu
# Out of vocabulary word:  trường_học
# Out of vocabulary word:  new_york
# Out of vocabulary word:  lo_lắng
# Out of vocabulary word:  nhu_cầu
# Out of vocabulary word:  thách_thức
# Out of vocabulary word:  y_tế
# Out of vocabulary word:  bộ_phận
# Out of vocabulary word:  tài_chính
# Out of vocabulary word:  sợ_hãi
# Out of vocabulary word:  tốt_đẹp
# Out of vocabulary word:  não_bộ
# Out of vocabulary word:  cách_mạng
# Out of vocabulary word:  phát_minh
# Out of vocabulary word:  hiện_đại
# Out of vocabulary word:  bệnh_viện
# Out of vocabulary word:  yếu_tố
# Out of vocabulary word:  áp_dụng
# Out of vocabulary word:  ngày_càng
# Out of vocabulary word:  sự_kiện
# Out of vocabulary word:  nhiệm_vụ
# Out of vocabulary word:  chuyên_gia
# Out of vocabulary word:  phương_tiện
# Out of vocabulary word:  nhất_là
# Out of vocabulary word:  quay_lại
# Out of vocabulary word:  bạo_lực
# Out of vocabulary word:  việc_làm
# Out of vocabulary word:  tin_tưởng
# Out of vocabulary word:  hấp_dẫn
# Out of vocabulary word:  sâu_sắc
# Out of vocabulary word:  phù_hợp
# Out of vocabulary word:  chức_năng
# Out of vocabulary word:  ứng_dụng
# Out of vocabulary word:  trình_bày
# Out of vocabulary word:  phân_tích
# Out of vocabulary word:  kinh_nghiệm
# Out of vocabulary word:  giới_hạn
# Out of vocabulary word:  so_sánh
# Out of vocabulary word:  hoàn_hảo
# Out of vocabulary word:  định_nghĩa
# Out of vocabulary word:  đại_dương
# Out of vocabulary word:  tỉ_lệ
# Out of vocabulary word:  trực_tiếp
# Out of vocabulary word:  tốc_độ
# Out of vocabulary word:  yêu_thích
# Out of vocabulary word:  tình_trạng
# Out of vocabulary word:  vi_khuẩn
# Out of vocabulary word:  mở_rộng
# Out of vocabulary word:  sai_lầm
# Out of vocabulary word:  phần_mềm
# Out of vocabulary word:  gần_đây
# Out of vocabulary word:  hỗ_trợ
# Out of vocabulary word:  thông_thường
# Out of vocabulary word:  cảm_hứng
# Out of vocabulary word:  hiểu_biết
# Out of vocabulary word:  thu_nhập
# Out of vocabulary word:  thật_ra
# Out of vocabulary word:  tồi_tệ
# Out of vocabulary word:  hoa_kỳ
# Out of vocabulary word:  tính_toán
# Out of vocabulary word:  hình_thành
# Out of vocabulary word:  phổ_biến
# Out of vocabulary word:  tâm_lý
# Out of vocabulary word:  điều_trị
# Out of vocabulary word:  cực_kỳ
# Out of vocabulary word:  phương_tây
# Out of vocabulary word:  làm_gì
# Out of vocabulary word:  tôn_giáo
# Out of vocabulary word:  hoà_bình
# Out of vocabulary word:  tranh_luận
# Out of vocabulary word:  tình_dục
# Out of vocabulary word:  không_khí
# Out of vocabulary word:  là_vì
# Out of vocabulary word:  chi_tiết
# Out of vocabulary word:  xác_định
# Out of vocabulary word:  nhất_định
# Out of vocabulary word:  tự_hỏi
# Out of vocabulary word:  con_trai
# Out of vocabulary word:  hay_là
# Out of vocabulary word:  to_lớn
# Out of vocabulary word:  thu_thập
# Out of vocabulary word:  hành_trình
# Out of vocabulary word:  trở_về
# Out of vocabulary word:  không_hề
# Out of vocabulary word:  xử_lý
# Out of vocabulary word:  với_nhau
# Out of vocabulary word:  dự_đoán
# Out of vocabulary word:  hình_dung
# Out of vocabulary word:  giao_tiếp
# Out of vocabulary word:  vậy_thì
# Out of vocabulary word:  chi_phí
# Out of vocabulary word:  số_liệu
# Out of vocabulary word:  xu_hướng
# Out of vocabulary word:  điện_tử
# Out of vocabulary word:  quảng_cáo
# Out of vocabulary word:  khi_nào
# Out of vocabulary word:  quá_khứ
# Out of vocabulary word:  dường_như
# Out of vocabulary word:  chính_sách
# Out of vocabulary word:  thúc_đẩy
# Out of vocabulary word:  phụ_thuộc
# Out of vocabulary word:  căn_bệnh
# Out of vocabulary word:  hoàn_thành
# Out of vocabulary word:  tiết_kiệm
# Out of vocabulary word:  thứ_hai
# Out of vocabulary word:  chưa_từng
# Out of vocabulary word:  chuyển_động
# Out of vocabulary word:  loài_người
# Out of vocabulary word:  toán_học
# Out of vocabulary word:  tỷ_lệ
# Out of vocabulary word:  chống_lại
# Out of vocabulary word:  công_trình
# Out of vocabulary word:  chủ_đề
# Out of vocabulary word:  chỉ_có
# Out of vocabulary word:  nền_tảng
# Out of vocabulary word:  nỗ_lực
# Out of vocabulary word:  cải_thiện
# Out of vocabulary word:  thuyết_phục
# Out of vocabulary word:  bất_ngờ
# Out of vocabulary word:  khoảnh_khắc
# Out of vocabulary word:  ngân_hàng
# Out of vocabulary word:  mong_muốn
# Out of vocabulary word:  di_truyền
# Out of vocabulary word:  động_cơ
# Out of vocabulary word:  đồng_ý
# Out of vocabulary word:  đảm_bảo
# Out of vocabulary word:  con_cái
# Out of vocabulary word:  thành_viên
# Out of vocabulary word:  bạn_bè
# Out of vocabulary word:  thường_xuyên
# Out of vocabulary word:  bí_mật
# Out of vocabulary word:  ban_đầu
# Out of vocabulary word:  hoá_học
# Out of vocabulary word:  chứng_kiến
# Out of vocabulary word:  để_cho
# Out of vocabulary word:  khủng_hoảng
# Out of vocabulary word:  lý_thuyết
# Out of vocabulary word:  liên_hệ
# Out of vocabulary word:  thử_thách
# Out of vocabulary word:  chế_tạo
# Out of vocabulary word:  chất_lượng
# Out of vocabulary word:  cảnh_sát
# Out of vocabulary word:  màn_hình
# Out of vocabulary word:  chẳng_hạn
# Out of vocabulary word:  đam_mê
# Out of vocabulary word:  tích_cực
# Out of vocabulary word:  như_thể
# Out of vocabulary word:  tổn_thương
# Out of vocabulary word:  vượt_qua
# Out of vocabulary word:  văn_phòng
# Out of vocabulary word:  tâm_thần
# Out of vocabulary word:  bằng_chứng
# Out of vocabulary word:  chỉ_cần
# Out of vocabulary word:  cô_bé
# Out of vocabulary word:  hồi_giáo
# Out of vocabulary word:  bền_vững
# Out of vocabulary word:  tinh_thần
# Out of vocabulary word:  lí_do
# Out of vocabulary word:  đa_dạng
# Out of vocabulary word:  bề_mặt
# Out of vocabulary word:  lớn_lên
# Out of vocabulary word:  hi_vọng
# Out of vocabulary word:  kiến_trúc
# Out of vocabulary word:  vì_sao
# Out of vocabulary word:  khuôn_mặt
# Out of vocabulary word:  gần_như
# Out of vocabulary word:  tâm_trí
# Out of vocabulary word:  liên_tục
# Out of vocabulary word:  biểu_đồ
# Out of vocabulary word:  làm_tôi
# Out of vocabulary word:  quốc_tế
# Out of vocabulary word:  cậu_bé
# Out of vocabulary word:  mô_tả
# Out of vocabulary word:  thay_thế
# Out of vocabulary word:  thông_điệp
# Out of vocabulary word:  vật_chất
# Out of vocabulary word:  sở_hữu
# Out of vocabulary word:  đồng_nghiệp
# Out of vocabulary word:  vĩ_đại
# Out of vocabulary word:  chứng_minh
# Out of vocabulary word:  con_gái
# Out of vocabulary word:  lợi_nhuận
# Out of vocabulary word:  chế_độ
# Out of vocabulary word:  thời_đại
# Out of vocabulary word:  tấn_công
# Out of vocabulary word:  nội_dung
# Out of vocabulary word:  chủ_yếu
# Out of vocabulary word:  đe_doạ
# Out of vocabulary word:  nói_là
# Out of vocabulary word:  ngay_lập_tức
# Out of vocabulary word:  tiến_bộ
# Out of vocabulary word:  biểu_diễn
# Out of vocabulary word:  cuộc_chiến
# Out of vocabulary word:  hiện_tượng
# Out of vocabulary word:  ý_thức
# Out of vocabulary word:  đấu_tranh
# Out of vocabulary word:  thu_hút
# Out of vocabulary word:  thống_kê
# Out of vocabulary word:  bầu_cử
# Out of vocabulary word:  nhiệt_độ
# Out of vocabulary word:  cơ_sở
# Out of vocabulary word:  điều_hành
# Out of vocabulary word:  danh_sách
# Out of vocabulary word:  quy_mô
# Out of vocabulary word:  sân_khấu
# Out of vocabulary word:  tạp_chí
# Out of vocabulary word:  hình_dạng
# Out of vocabulary word:  bản_chất
# Out of vocabulary word:  ít_hơn
# Out of vocabulary word:  tiềm_năng
# Out of vocabulary word:  hoá_ra
# Out of vocabulary word:  luôn_luôn
# Out of vocabulary word:  lúc_nào
# Out of vocabulary word:  hơn_nữa
# Out of vocabulary word:  kích_thích
# Out of vocabulary word:  tình_huống
# Out of vocabulary word:  cách_thức
# Out of vocabulary word:  bên_ngoài
# Out of vocabulary word:  cha_mẹ
# Out of vocabulary word:  ngẫu_nhiên
# Out of vocabulary word:  xung_đột
# Out of vocabulary word:  đề_cập
# Out of vocabulary word:  bảo_tàng
# Out of vocabulary word:  duy_trì
# Out of vocabulary word:  bài_học
# Out of vocabulary word:  tín_hiệu
# Out of vocabulary word:  tự_động
# Out of vocabulary word:  lúc_này
# Out of vocabulary word:  đồng_hồ
# Out of vocabulary word:  tài_liệu
# Out of vocabulary word:  nhận_thấy
# Out of vocabulary word:  tác_dụng
# Out of vocabulary word:  động_lực
# Out of vocabulary word:  khách_hàng
# Out of vocabulary word:  phân_biệt
# Out of vocabulary word:  kể_cả
# Out of vocabulary word:  chủ_nghĩa
# Out of vocabulary word:  đồng_thời
# Out of vocabulary word:  ít_nhất
# Out of vocabulary word:  tập_hợp
# Out of vocabulary word:  đề_nghị
# Out of vocabulary word:  doanh_nghiệp
# Out of vocabulary word:  nguyên_nhân
# Out of vocabulary word:  khía_cạnh
# Out of vocabulary word:  năm_ngoái
# Out of vocabulary word:  trao_đổi
# Out of vocabulary word:  nhân_vật
# Out of vocabulary word:  phục_vụ
# Out of vocabulary word:  trái_tim
# Out of vocabulary word:  ra_sao
# Out of vocabulary word:  trạng_thái
# Out of vocabulary word:  nguyên_tắc
# Out of vocabulary word:  thành_phần
# Out of vocabulary word:  nếu_như
# Out of vocabulary word:  khoảng_cách
# Out of vocabulary word:  ngôi_sao
# Out of vocabulary word:  công_cộng
# Out of vocabulary word:  đào_tạo
# Out of vocabulary word:  đại_diện
# Out of vocabulary word:  thế_kỉ
# Out of vocabulary word:  trải_qua
# Out of vocabulary word:  tài_nguyên
# Out of vocabulary word:  nhìn_nhận
# Out of vocabulary word:  cửa_hàng
# Out of vocabulary word:  lao_động
# Out of vocabulary word:  công_dân
# Out of vocabulary word:  nghiêm_trọng
# Out of vocabulary word:  thương_mại
# Out of vocabulary word:  đổi_mới
# Out of vocabulary word:  kéo_dài
# Out of vocabulary word:  thập_kỷ
# Out of vocabulary word:  miễn_phí
# Out of vocabulary word:  ý_kiến
# Out of vocabulary word:  màu_sắc
# Out of vocabulary word:  tội_phạm
# Out of vocabulary word:  trưởng_thành
# Out of vocabulary word:  vận_động
# Out of vocabulary word:  côn_trùng
# Out of vocabulary word:  đằng_sau
# Out of vocabulary word:  không_ai
# Out of vocabulary word:  ấn_tượng
# Out of vocabulary word:  bài_hát
# Out of vocabulary word:  dấu_hiệu
# Out of vocabulary word:  tái_tạo
# Out of vocabulary word:  còn_lại
# Out of vocabulary word:  ra_đời
# Out of vocabulary word:  cá_mập
# Out of vocabulary word:  thoải_mái
# Out of vocabulary word:  lái_xe
# Out of vocabulary word:  sống_sót
# Out of vocabulary word:  tầm_nhìn
# Out of vocabulary word:  cho_nên
# Out of vocabulary word:  nhà_máy
# Out of vocabulary word:  có_mặt
# Out of vocabulary word:  công_bằng
# Out of vocabulary word:  thích_thú
# Out of vocabulary word:  kỹ_năng
# Out of vocabulary word:  gia_tăng
# Out of vocabulary word:  hình_thức
# Out of vocabulary word:  khai_thác
# Out of vocabulary word:  bố_mẹ
# Out of vocabulary word:  phục_hồi
# Out of vocabulary word:  anh_chàng
# Out of vocabulary word:  khoẻ_mạnh
# Out of vocabulary word:  hiển_nhiên
# Out of vocabulary word:  chiến_thắng
# Out of vocabulary word:  cân_bằng
# Out of vocabulary word:  thiên_nhiên
# Out of vocabulary word:  tiêu_thụ
# Out of vocabulary word:  vận_hành
# Out of vocabulary word:  độc_lập
# Out of vocabulary word:  lập_trình
# Out of vocabulary word:  con_đường
# Out of vocabulary word:  tranh_cãi
# Out of vocabulary word:  hết_sức
# Out of vocabulary word:  một_nơi
# Out of vocabulary word:  quy_tắc
# Out of vocabulary word:  ngược_lại
# Out of vocabulary word:  đòi_hỏi
# Out of vocabulary word:  hạn_chế
# Out of vocabulary word:  khuyến_khích
# Out of vocabulary word:  do_đó
# Out of vocabulary word:  đáng_kể
# Out of vocabulary word:  tổng_hợp
# Out of vocabulary word:  hoặc_là
# Out of vocabulary word:  đến_nỗi
# Out of vocabulary word:  sắp_xếp
# Out of vocabulary word:  tử_vong
# Out of vocabulary word:  để_ý
# Out of vocabulary word:  tăng_trưởng
# Out of vocabulary word:  điều_chỉnh
# Out of vocabulary word:  phiên_bản
# Out of vocabulary word:  sáng_chế
# Out of vocabulary word:  thảo_luận
# Out of vocabulary word:  từ_bỏ
# Out of vocabulary word:  vật_thể
# Out of vocabulary word:  loại_bỏ
# Out of vocabulary word:  xe_đạp
# Out of vocabulary word:  cùng_nhau
# Out of vocabulary word:  niềm_tin
# Out of vocabulary word:  giáo_sư
# Out of vocabulary word:  mang_lại
# Out of vocabulary word:  thực_vật
# Out of vocabulary word:  quen_thuộc
# Out of vocabulary word:  mặt_đất
# Out of vocabulary word:  hoàn_cảnh
# Out of vocabulary word:  tổng_thống
# Out of vocabulary word:  ổn_định
# Out of vocabulary word:  máy_móc
# Out of vocabulary word:  hiện_thực
# Out of vocabulary word:  minh_hoạ
# Out of vocabulary word:  trò_chuyện
# Out of vocabulary word:  hầu_như
# Out of vocabulary word:  hài_hước
# Out of vocabulary word:  phỏng_vấn
# Out of vocabulary word:  tham_nhũng
# Out of vocabulary word:  sinh_ra
# Out of vocabulary word:  vân_vân
# Out of vocabulary word:  xấu_hổ
# Out of vocabulary word:  kĩ_thuật
# Out of vocabulary word:  kết_luận
# Out of vocabulary word:  tài_trợ
# Out of vocabulary word:  diễn_thuyết
# Out of vocabulary word:  tư_duy
# Out of vocabulary word:  chiến_lược
# Out of vocabulary word:  sụp_đổ
# Out of vocabulary word:  bước_vào
# Out of vocabulary word:  chiến_dịch
# Out of vocabulary word:  đúng_đắn
# Out of vocabulary word:  chữa_trị
# Out of vocabulary word:  hơn_cả
# Out of vocabulary word:  cà_phê
# Out of vocabulary word:  tiêu_chuẩn
# Out of vocabulary word:  đi_vào
# Out of vocabulary word:  kích_thước
# Out of vocabulary word:  vui_vẻ
# Out of vocabulary word:  xuất_bản
# Out of vocabulary word:  vũ_khí
# Out of vocabulary word:  xin_lỗi
# Out of vocabulary word:  khởi_đầu
# Out of vocabulary word:  dinh_dưỡng
# Out of vocabulary word:  nguy_cơ
# Out of vocabulary word:  nghe_thấy
# Out of vocabulary word:  tiếng_nói
# Out of vocabulary word:  năm_qua
# Out of vocabulary word:  nông_nghiệp
# Out of vocabulary word:  hạt_nhân
# Out of vocabulary word:  nhân_loại
# Out of vocabulary word:  nhân_tạo
# Out of vocabulary word:  cỗ_máy
# Out of vocabulary word:  chiến_đấu
# Out of vocabulary word:  rủi_ro
# Out of vocabulary word:  hợp_lý
# Out of vocabulary word:  quân_đội
# Out of vocabulary word:  hướng_dẫn
# Out of vocabulary word:  bàn_tay
# Out of vocabulary word:  ngăn_chặn
# Out of vocabulary word:  đô_thị
# Out of vocabulary word:  học_hỏi
# Out of vocabulary word:  cạnh_tranh
# Out of vocabulary word:  chính_quyền
# Out of vocabulary word:  lớp_học
# Out of vocabulary word:  đột_nhiên
# Out of vocabulary word:  giọng_nói
# Out of vocabulary word:  thể_thao
# Out of vocabulary word:  biểu_tượng
# Out of vocabulary word:  đau_đớn
# Out of vocabulary word:  báo_cáo
# Out of vocabulary word:  hứng_thú
# Out of vocabulary word:  xe_hơi
# Out of vocabulary word:  căn_bản
# Out of vocabulary word:  nhiên_liệu
# Out of vocabulary word:  theo_đuổi
# Out of vocabulary word:  trí_tuệ
# Out of vocabulary word:  dụng_cụ
# Out of vocabulary word:  khắp_nơi
# Out of vocabulary word:  miêu_tả
# Out of vocabulary word:  đầy_đủ
# Out of vocabulary word:  mong_đợi
# Out of vocabulary word:  chẩn_đoán
# Out of vocabulary word:  tuổi_thọ
# Out of vocabulary word:  học_tập
# Out of vocabulary word:  cửa_sổ
# Out of vocabulary word:  trình_diễn
# Out of vocabulary word:  tò_mò
# Out of vocabulary word:  ô_tô
# Out of vocabulary word:  nghiêm_túc
# Out of vocabulary word:  cho_là
# Out of vocabulary word:  phạm_vi
# Out of vocabulary word:  truyền_hình
# Out of vocabulary word:  giàu_có
# Out of vocabulary word:  tiêu_dùng
# Out of vocabulary word:  căng_thẳng
# Out of vocabulary word:  giới_tính
# Out of vocabulary word:  từ_chối
# Out of vocabulary word:  công_viên
# Out of vocabulary word:  trước_hết
# Out of vocabulary word:  rắc_rối
# Out of vocabulary word:  cho_đến
# Out of vocabulary word:  tin_tức
# Out of vocabulary word:  phá_huỷ
# Out of vocabulary word:  rối_loạn
# Out of vocabulary word:  đa_số
# Out of vocabulary word:  giao_thông
# Out of vocabulary word:  khủng_khiếp
# Out of vocabulary word:  hệ_sinh_thái
# Out of vocabulary word:  nông_dân
# Out of vocabulary word:  cho_dù
# Out of vocabulary word:  bản_nhạc
# Out of vocabulary word:  tư_cách
# Out of vocabulary word:  cô_ta
# Out of vocabulary word:  cơ_chế
# Out of vocabulary word:  thực_chất
# Out of vocabulary word:  thất_vọng
# Out of vocabulary word:  do_vậy
# Out of vocabulary word:  văn_minh
# Out of vocabulary word:  thứ_ba
# Out of vocabulary word:  đến_mức
# Out of vocabulary word:  nhỏ_bé
# Out of vocabulary word:  tự_hào
# Out of vocabulary word:  kích_cỡ
# Out of vocabulary word:  điên_rồ
# Out of vocabulary word:  chuyển_đổi
# Out of vocabulary word:  công_bố
# Out of vocabulary word:  thập_niên
# Out of vocabulary word:  đóng_góp
# Out of vocabulary word:  cá_voi
# Out of vocabulary word:  kể_chuyện
# Out of vocabulary word:  hậu_quả
# Out of vocabulary word:  gợi_ý
# Out of vocabulary word:  tốt_nghiệp
# Out of vocabulary word:  có_phải
# Out of vocabulary word:  phi_thường
# Out of vocabulary word:  chịu_đựng
# Out of vocabulary word:  kỹ_sư
# Out of vocabulary word:  nguồn_gốc
# Out of vocabulary word:  sự_nghiệp
# Out of vocabulary word:  địa_điểm
# Out of vocabulary word:  vận_chuyển
# Out of vocabulary word:  phản_hồi
# Out of vocabulary word:  huấn_luyện
# Out of vocabulary word:  công_thức
# Out of vocabulary word:  lặp_lại
# Out of vocabulary word:  đồng_tính
# Out of vocabulary word:  an_ninh
# Out of vocabulary word:  điển_hình
# Out of vocabulary word:  thời_kỳ
# Out of vocabulary word:  trung_đông
# Out of vocabulary word:  đơn_vị
# Out of vocabulary word:  kiến_trúc_sư
# Out of vocabulary word:  khối_u
# Out of vocabulary word:  tài_sản
# Out of vocabulary word:  lương_thực
# Out of vocabulary word:  ý_nghĩ
# Out of vocabulary word:  bối_cảnh
# Out of vocabulary word:  thấu_hiểu
# Out of vocabulary word:  cá_thể
# Out of vocabulary word:  tuyên_bố
# Out of vocabulary word:  xuất_phát
# Out of vocabulary word:  lạc_quan
# Out of vocabulary word:  khả_thi
# Out of vocabulary word:  thành_lập
# Out of vocabulary word:  thuật_toán
# Out of vocabulary word:  mạo_hiểm
# Out of vocabulary word:  nghi_ngờ
# Out of vocabulary word:  phong_trào
# Out of vocabulary word:  hàng_ngày
# Out of vocabulary word:  nhà_hàng
# Out of vocabulary word:  kêu_gọi
# Out of vocabulary word:  bảo_tồn
# Out of vocabulary word:  đám_mây
# Out of vocabulary word:  hội_nghị
# Out of vocabulary word:  tự_tin
# Out of vocabulary word:  ám_ảnh
# Out of vocabulary word:  mặt_trăng
# Out of vocabulary word:  từ_thiện
# Out of vocabulary word:  tiến_sĩ
# Out of vocabulary word:  nhật_bản
# Out of vocabulary word:  một_khi
# Out of vocabulary word:  nguyên_tử
# Out of vocabulary word:  cẩn_thận
# Out of vocabulary word:  biên_giới
# Out of vocabulary word:  liên_lạc
# Out of vocabulary word:  nạn_nhân
# Out of vocabulary word:  thảm_hoạ
# Out of vocabulary word:  câu_nói
# Out of vocabulary word:  nam_giới
# Out of vocabulary word:  tài_năng
# Out of vocabulary word:  du_lịch
# Out of vocabulary word:  làm_vậy
# Out of vocabulary word:  hữu_ích
# Out of vocabulary word:  quan_niệm
# Out of vocabulary word:  tư_tưởng
# Out of vocabulary word:  bỏ_qua
# Out of vocabulary word:  quy_trình
# Out of vocabulary word:  người_ở
# Out of vocabulary word:  ô_nhiễm
# Out of vocabulary word:  một_ít
# Out of vocabulary word:  can_thiệp
# Out of vocabulary word:  thỉnh_thoảng
# Out of vocabulary word:  vùng_đất
# Out of vocabulary word:  bí_ẩn
# Out of vocabulary word:  tương_đương
# Out of vocabulary word:  giấc_mơ
# Out of vocabulary word:  trẻ_con
# Out of vocabulary word:  từ_ngữ
# Out of vocabulary word:  thiết_lập
# Out of vocabulary word:  đường_phố
# Out of vocabulary word:  cánh_tay
# Out of vocabulary word:  kì_diệu
# Out of vocabulary word:  một_mình
# Out of vocabulary word:  thuyết_trình
# Out of vocabulary word:  người_lớn
# Out of vocabulary word:  quy_luật
# Out of vocabulary word:  trực_tuyến
# Out of vocabulary word:  lưu_trữ
# Out of vocabulary word:  ký_ức
# Out of vocabulary word:  bánh_mì
# Out of vocabulary word:  chim_cánh_cụt
# Out of vocabulary word:  tai_nạn
# Out of vocabulary word:  cải_tiến
# Out of vocabulary word:  hiệu_ứng
# Out of vocabulary word:  giả_thuyết
# Out of vocabulary word:  vòng_quanh
# Out of vocabulary word:  từ_điển
# Out of vocabulary word:  di_động
# Out of vocabulary word:  kinh_khủng
# Out of vocabulary word:  phương_thức
# Out of vocabulary word:  kỳ_diệu
# Out of vocabulary word:  nguyên_liệu
# Out of vocabulary word:  ẩn_dụ
# Out of vocabulary word:  đương_nhiên
# Out of vocabulary word:  sửa_chữa
# Out of vocabulary word:  lúc_đó
# Out of vocabulary word:  khối_lượng
# Out of vocabulary word:  trị_liệu
# Out of vocabulary word:  đáng_sợ
# Out of vocabulary word:  hàng_loạt
# Out of vocabulary word:  phá_vỡ
# Out of vocabulary word:  chụp_ảnh
# Out of vocabulary word:  truy_cập
# Out of vocabulary word:  vô_hình
# Out of vocabulary word:  tình_cờ
# Out of vocabulary word:  thích_nghi
# Out of vocabulary word:  vận_động_viên
# Out of vocabulary word:  trắc_ẩn
# Out of vocabulary word:  anh_hùng
# Out of vocabulary word:  đặc_tính
# Out of vocabulary word:  đề_xuất
# Out of vocabulary word:  thói_quen
# Out of vocabulary word:  làm_nên
# Out of vocabulary word:  rộng_lớn
# Out of vocabulary word:  lực_lượng
# Out of vocabulary word:  bài_tập
# Out of vocabulary word:  phát_biểu
# Out of vocabulary word:  hài_lòng
# Out of vocabulary word:  giải_phóng
# Out of vocabulary word:  vệ_tinh
# Out of vocabulary word:  rời_khỏi
# Out of vocabulary word:  ngoại_trừ
# Out of vocabulary word:  gấp_đôi
# Out of vocabulary word:  đời_sống
# Out of vocabulary word:  đánh_dấu
# Out of vocabulary word:  bất_kể
# Out of vocabulary word:  tiếp_xúc
# Out of vocabulary word:  vậy_là
# Out of vocabulary word:  một_lần
# Out of vocabulary word:  thiên_hà
# Out of vocabulary word:  từ_đó
# Out of vocabulary word:  đối_tượng
# Out of vocabulary word:  diễn_viên
# Out of vocabulary word:  đi_qua
# Out of vocabulary word:  triệu_chứng
# Out of vocabulary word:  hiện_giờ
# Out of vocabulary word:  hôn_nhân
# Out of vocabulary word:  lâu_dài
# Out of vocabulary word:  kích_hoạt
# Out of vocabulary word:  một_lúc
# Out of vocabulary word:  khủng_bố
# Out of vocabulary word:  sa_mạc
# Out of vocabulary word:  thừa_nhận
# Out of vocabulary word:  phân_phối
# Out of vocabulary word:  làm_ra
# Out of vocabulary word:  đối_thoại
# Out of vocabulary word:  chủng_tộc
# Out of vocabulary word:  luật_sư
# Out of vocabulary word:  biểu_hiện
# Out of vocabulary word:  nhà_thờ
# Out of vocabulary word:  phản_đối
# Out of vocabulary word:  kì_lạ
# Out of vocabulary word:  y_học
# Out of vocabulary word:  công_chúng
# Out of vocabulary word:  đặc_điểm
# Out of vocabulary word:  em_bé
# Out of vocabulary word:  cải_cách
# Out of vocabulary word:  cực_kì
# Out of vocabulary word:  những_ai
# Out of vocabulary word:  thông_báo
# Out of vocabulary word:  khó_chịu
# Out of vocabulary word:  quần_áo
# Out of vocabulary word:  xứng_đáng
# Out of vocabulary word:  mặt_khác
# Out of vocabulary word:  chuyển_hoá
# Out of vocabulary word:  diện_tích
# Out of vocabulary word:  béo_phì
# Out of vocabulary word:  điện_thoại_di_động
# Out of vocabulary word:  đối_xử
# Out of vocabulary word:  tuyệt_đối
# Out of vocabulary word:  sốt_rét
# Out of vocabulary word:  áp_lực
# Out of vocabulary word:  tác_giả
# Out of vocabulary word:  sao_chép
# Out of vocabulary word:  thoát_khỏi
# Out of vocabulary word:  tri_thức
# Out of vocabulary word:  nguồn_lực
# Out of vocabulary word:  tận_dụng
# Out of vocabulary word:  có_người
# Out of vocabulary word:  khảo_sát
# Out of vocabulary word:  nói_dối
# Out of vocabulary word:  dù_sao
# Out of vocabulary word:  vừa_qua
# Out of vocabulary word:  biết_ơn
# Out of vocabulary word:  quốc_hội
# Out of vocabulary word:  lý_tưởng
# Out of vocabulary word:  mới_mẻ
# Out of vocabulary word:  bình_đẳng
# Out of vocabulary word:  cấy_ghép
# Out of vocabulary word:  tính_chất
# Out of vocabulary word:  đại_loại
# Out of vocabulary word:  nói_cách_khác
# Out of vocabulary word:  đồ_vật
# Out of vocabulary word:  tình_nguyện
# Out of vocabulary word:  riêng_biệt
# Out of vocabulary word:  quả_là
# Out of vocabulary word:  mô_phỏng
# Out of vocabulary word:  đi_bộ
# Out of vocabulary word:  sau_này
# Out of vocabulary word:  nuôi_dưỡng
# Out of vocabulary word:  sư_tử
# Out of vocabulary word:  bầu_trời
# Out of vocabulary word:  mãi_mãi
# Out of vocabulary word:  nhận_biết
# Out of vocabulary word:  tiết_lộ
# Out of vocabulary word:  đặc_trưng
# Out of vocabulary word:  khí_quyển
# Out of vocabulary word:  im_lặng
# Out of vocabulary word:  nếu_không
# Out of vocabulary word:  y_tá
# Out of vocabulary word:  sau_đây
# Out of vocabulary word:  ngân_sách
# Out of vocabulary word:  tầng_lớp
# Out of vocabulary word:  con_bé
# Out of vocabulary word:  trung_học
# Out of vocabulary word:  quí_vị
# Out of vocabulary word:  tự_kỷ
# Out of vocabulary word:  rô_bốt
# Out of vocabulary word:  bắt_chước
# Out of vocabulary word:  hoang_dã
# Out of vocabulary word:  cơ_sở_hạ_tầng
# Out of vocabulary word:  trầm_cảm
# Out of vocabulary word:  đơn_thuần
# Out of vocabulary word:  bờ_biển
# Out of vocabulary word:  mùa_hè
# Out of vocabulary word:  đáp_ứng
# Out of vocabulary word:  chìa_khoá
# Out of vocabulary word:  giải_thưởng
# Out of vocabulary word:  nói_chung
# Out of vocabulary word:  mới_chỉ
# Out of vocabulary word:  điều_tra
# Out of vocabulary word:  lớn_lao
# Out of vocabulary word:  nước_ngoài
# Out of vocabulary word:  bảo_hiểm
# Out of vocabulary word:  bản_năng
# Out of vocabulary word:  kết_cấu
# Out of vocabulary word:  triển_lãm
# Out of vocabulary word:  tính_cách
# Out of vocabulary word:  tôn_trọng
# Out of vocabulary word:  kim_loại
# Out of vocabulary word:  hội_thảo
# Out of vocabulary word:  tuyệt_chủng
# Out of vocabulary word:  kế_tiếp
# Out of vocabulary word:  bắt_tay
# Out of vocabulary word:  ted.
# Out of vocabulary word:  đồ_chơi
# Out of vocabulary word:  hiện_diện
# Out of vocabulary word:  giảng_dạy
# Out of vocabulary word:  hàng_đầu
# Out of vocabulary word:  hình_mẫu
# Out of vocabulary word:  giao_diện
# Out of vocabulary word:  hay_không
# Out of vocabulary word:  đối_phó
# Out of vocabulary word:  giải_trí
# Out of vocabulary word:  mật_khẩu
# Out of vocabulary word:  luyện_tập
# Out of vocabulary word:  niềm_vui
# Out of vocabulary word:  hàng_xóm
# Out of vocabulary word:  đám_đông
# Out of vocabulary word:  nhưng_mà
# Out of vocabulary word:  tiên_phong
# Out of vocabulary word:  ưu_tiên
# Out of vocabulary word:  sinh_sản
# Out of vocabulary word:  của_riêng
# Out of vocabulary word:  chờ_đợi
# Out of vocabulary word:  nhắc_nhở
# Out of vocabulary word:  giám_đốc
# Out of vocabulary word:  con_chuột
# Out of vocabulary word:  xe_tải
# Out of vocabulary word:  ghi_nhớ
# Out of vocabulary word:  sao_hoả
# Out of vocabulary word:  làm_bạn
# Out of vocabulary word:  sự_việc
# Out of vocabulary word:  vệ_sinh
# Out of vocabulary word:  nhân_tố
# Out of vocabulary word:  tị_nạn
# Out of vocabulary word:  ranh_giới
# Out of vocabulary word:  luật_lệ
# Out of vocabulary word:  tập_thể
# Out of vocabulary word:  giác_quan
# Out of vocabulary word:  chấm_dứt
# Out of vocabulary word:  định_hướng
# Out of vocabulary word:  tiến_trình
# Out of vocabulary word:  trích_dẫn
# Out of vocabulary word:  năng_lực
# Out of vocabulary word:  vòng_tròn
# Out of vocabulary word:  ngón_tay
# Out of vocabulary word:  chút_nào
# Out of vocabulary word:  cấp_độ
# Out of vocabulary word:  tiến_triển
# Out of vocabulary word:  kỳ_lạ
# Out of vocabulary word:  thị_giác
# Out of vocabulary word:  viện_trợ
# Out of vocabulary word:  em_gái
# Out of vocabulary word:  tương_đối
# Out of vocabulary word:  vừa_mới
# Out of vocabulary word:  nhà_tù
# Out of vocabulary word:  thám_hiểm
# Out of vocabulary word:  riêng_tư
# Out of vocabulary word:  chính_trị_gia
# Out of vocabulary word:  thời_tiết
# Out of vocabulary word:  dân_cư
# Out of vocabulary word:  thái_độ
# Out of vocabulary word:  tin_cậy
# Out of vocabulary word:  gặp_phải
# Out of vocabulary word:  bệnh_tật
# Out of vocabulary word:  chọn_lọc
# Out of vocabulary word:  xuất_sắc
# Out of vocabulary word:  triết_học
# Out of vocabulary word:  thư_viện
# Out of vocabulary word:  công_nhân
# Out of vocabulary word:  nhà_nước
# Out of vocabulary word:  phương_diện
# Out of vocabulary word:  nói_lên
# Out of vocabulary word:  nhạy_cảm
# Out of vocabulary word:  chất_thải
# Out of vocabulary word:  cốt_lõi
# Out of vocabulary word:  sưu_tập
# Out of vocabulary word:  trợ_giúp
# Out of vocabulary word:  bong_bóng
# Out of vocabulary word:  vào_khoảng
# Out of vocabulary word:  quy_định
# Out of vocabulary word:  một_nửa
# Out of vocabulary word:  bao_lâu
# Out of vocabulary word:  nhà_văn
# Out of vocabulary word:  nguyên_mẫu
# Out of vocabulary word:  mâu_thuẫn
# Out of vocabulary word:  ghi_nhận
# Out of vocabulary word:  dần_dần
# Out of vocabulary word:  độ_cao
# Out of vocabulary word:  thời_kì
# Out of vocabulary word:  hoạt_hình
# Out of vocabulary word:  động_đất
# Out of vocabulary word:  ước_mơ
# Out of vocabulary word:  tái_chế
# Out of vocabulary word:  san_hô
# Out of vocabulary word:  mấu_chốt
# Out of vocabulary word:  biện_pháp
# Out of vocabulary word:  ngôi_nhà
# Out of vocabulary word:  thì_có
# Out of vocabulary word:  bên_cạnh
# Out of vocabulary word:  dân_tộc
# Out of vocabulary word:  ảo_giác
# Out of vocabulary word:  ảo_thuật
# Out of vocabulary word:  truyền_tải
# Out of vocabulary word:  người_làm
# Out of vocabulary word:  tức_là
# Out of vocabulary word:  nâng_cao
# Out of vocabulary word:  trưng_bày
# Out of vocabulary word:  hoàn_thiện
# Out of vocabulary word:  cảnh_báo
# Out of vocabulary word:  đã_là
# Out of vocabulary word:  thích_hợp
# Out of vocabulary word:  qua_đời
# Out of vocabulary word:  da_đen
# Out of vocabulary word:  nhà_báo
# Out of vocabulary word:  chuyên_nghiệp
# Out of vocabulary word:  mã_hoá
# Out of vocabulary word:  giả_định
# Out of vocabulary word:  cùng_lúc
# Out of vocabulary word:  kĩ_năng
# Out of vocabulary word:  di_cư
# Out of vocabulary word:  gắn_kết
# Out of vocabulary word:  tâm_hồn
# Out of vocabulary word:  căn_hộ
# Out of vocabulary word:  liên_bang
# Out of vocabulary word:  bộ_lạc
# Out of vocabulary word:  giám_sát
# Out of vocabulary word:  cá_heo
# Out of vocabulary word:  hữu_cơ
# Out of vocabulary word:  thị_trấn
# Out of vocabulary word:  phân_loại
# Out of vocabulary word:  máy_ảnh
# Out of vocabulary word:  khẳng_định
# Out of vocabulary word:  hoá_chất
# Out of vocabulary word:  thời_trang
# Out of vocabulary word:  hàng_năm
# Out of vocabulary word:  kinh_thánh
# Out of vocabulary word:  trong_khoảng
# Out of vocabulary word:  trước_tiên
# Out of vocabulary word:  dẫn_dắt
# Out of vocabulary word:  nhấn_mạnh
# Out of vocabulary word:  phản_ánh
# Out of vocabulary word:  đưa_vào
# Out of vocabulary word:  nghèo_đói
# Out of vocabulary word:  sinh_nhật
# Out of vocabulary word:  đối_diện
# Out of vocabulary word:  có_lợi
# Out of vocabulary word:  ngắn_gọn
# Out of vocabulary word:  đâu_đó
# Out of vocabulary word:  bại_liệt
# Out of vocabulary word:  lan_truyền
# Out of vocabulary word:  tiếp_nhận
# Out of vocabulary word:  tiểu_thuyết
# Out of vocabulary word:  trí_óc
# Out of vocabulary word:  trân_trọng
# Out of vocabulary word:  bỏ_phiếu
# Out of vocabulary word:  xinh_đẹp
# Out of vocabulary word:  phân_chia
# Out of vocabulary word:  nông_thôn
# Out of vocabulary word:  nghề_nghiệp
# Out of vocabulary word:  năm_tới
# Out of vocabulary word:  rộng_rãi
# Out of vocabulary word:  tù_nhân
# Out of vocabulary word:  lãng_phí
# Out of vocabulary word:  vỏ_não
# Out of vocabulary word:  khuynh_hướng
# Out of vocabulary word:  ngoại_giao
# Out of vocabulary word:  khách_sạn
# Out of vocabulary word:  thành_quả
# Out of vocabulary word:  đôi_lúc
# Out of vocabulary word:  đứng_lên
# Out of vocabulary word:  thanh_niên
# Out of vocabulary word:  gặp_gỡ
# Out of vocabulary word:  quân_sự
# Out of vocabulary word:  giảm_thiểu
# Out of vocabulary word:  ghi_chép
# Out of vocabulary word:  khao_khát
# Out of vocabulary word:  mỗi_một
# Out of vocabulary word:  đề_tài
# Out of vocabulary word:  ổ_chuột
# Out of vocabulary word:  phối_hợp
# Out of vocabulary word:  hữu_dụng
# Out of vocabulary word:  hồi_phục
# Out of vocabulary word:  nổi_bật
# Out of vocabulary word:  bình_luận
# Out of vocabulary word:  ước_tính
# Out of vocabulary word:  có_nghĩa
# Out of vocabulary word:  quỹ_đạo
# Out of vocabulary word:  đứa_bé
# Out of vocabulary word:  cổ_điển
# Out of vocabulary word:  luật_pháp
# Out of vocabulary word:  gì_mà
# Out of vocabulary word:  bóng_tối
# Out of vocabulary word:  tập_đoàn
# Out of vocabulary word:  bắt_nguồn
# Out of vocabulary word:  địa_lý
# Out of vocabulary word:  thoả_mãn
# Out of vocabulary word:  bài_thơ
# Out of vocabulary word:  ý_niệm
# Out of vocabulary word:  sẽ_biết
# Out of vocabulary word:  tài_khoản
# Out of vocabulary word:  thung_lũng
# Out of vocabulary word:  thập_kỉ
# Out of vocabulary word:  bộ_máy
# Out of vocabulary word:  đột_phá
# Out of vocabulary word:  bùng_nổ
# Out of vocabulary word:  cân_nhắc
# Out of vocabulary word:  tiền_bạc
# Out of vocabulary word:  lãng_mạn
# Out of vocabulary word:  đau_khổ
# Out of vocabulary word:  sinh_sống
# Out of vocabulary word:  bên_dưới
# Out of vocabulary word:  bởi_vậy
# Out of vocabulary word:  người_già
# Out of vocabulary word:  bắc_cực
# Out of vocabulary word:  có_ích
# Out of vocabulary word:  cam_kết
# Out of vocabulary word:  tinh_tinh
# Out of vocabulary word:  đo_lường
# Out of vocabulary word:  hào_hứng
# Out of vocabulary word:  nhiệt_đới
# Out of vocabulary word:  trẻ_tuổi
# Out of vocabulary word:  công_nhận
# Out of vocabulary word:  thế_thì
# Out of vocabulary word:  lão_hoá
# Out of vocabulary word:  để_lại
# Out of vocabulary word:  làm_theo
# Out of vocabulary word:  xe_buýt
# Out of vocabulary word:  trí_nhớ
# Out of vocabulary word:  thoả_thuận
# Out of vocabulary word:  điêu_khắc
# Out of vocabulary word:  tự_kỉ
# Out of vocabulary word:  bản_quyền
# Out of vocabulary word:  da_trắng
# Out of vocabulary word:  thức_dậy
# Out of vocabulary word:  chụp_hình
# Out of vocabulary word:  dự_trữ
# Out of vocabulary word:  thắc_mắc
# Out of vocabulary word:  thuật_ngữ
# Out of vocabulary word:  y_khoa
# Out of vocabulary word:  yêu_thương
# Out of vocabulary word:  trở_ngại
# Out of vocabulary word:  cộng_hoà
# Out of vocabulary word:  tàn_phá
# Out of vocabulary word:  công_khai
# Out of vocabulary word:  vừa_rồi
# Out of vocabulary word:  lời_khuyên
# Out of vocabulary word:  nữa_là
# Out of vocabulary word:  giấc_ngủ
# Out of vocabulary word:  trọng_lượng
# Out of vocabulary word:  tiêu_cực
# Out of vocabulary word:  tổ_tiên
# Out of vocabulary word:  gian_lận
# Out of vocabulary word:  hỗn_loạn
# Out of vocabulary word:  đánh_bại
# Out of vocabulary word:  tên_lửa
# Out of vocabulary word:  đi_theo
# Out of vocabulary word:  hàng_hoá
# Out of vocabulary word:  tờ_báo
# Out of vocabulary word:  hạt_giống
# Out of vocabulary word:  hợp_pháp
# Out of vocabulary word:  phần_nào
# Out of vocabulary word:  không_ngừng
# Out of vocabulary word:  miễn_dịch
# Out of vocabulary word:  khủng_long
# Out of vocabulary word:  nghĩa_đen
# Out of vocabulary word:  trực_giác
# Out of vocabulary word:  đồ_ăn
# Out of vocabulary word:  khởi_động
# Out of vocabulary word:  phần_thưởng
# Out of vocabulary word:  tiến_tới
# Out of vocabulary word:  nhà_ở
# Out of vocabulary word:  tình_hình
# Out of vocabulary word:  minh_bạch
# Out of vocabulary word:  nhiếp_ảnh
# Out of vocabulary word:  định_hình
# Out of vocabulary word:  thiếu_niên
# Out of vocabulary word:  thế_nhưng
# Out of vocabulary word:  giây_phút
# Out of vocabulary word:  kẻ_thù
# Out of vocabulary word:  sân_bay
# Out of vocabulary word:  hôm_qua
# Out of vocabulary word:  khác_thường
# Out of vocabulary word:  xếp_hạng
# Out of vocabulary word:  thịnh_vượng
# Out of vocabulary word:  cảm_biến
# Out of vocabulary word:  nam_cực
# Out of vocabulary word:  nho_nhỏ
# Out of vocabulary word:  chỉ_số
# Out of vocabulary word:  trừu_tượng
# Out of vocabulary word:  từ_đầu
# Out of vocabulary word:  bữa_ăn
# Out of vocabulary word:  giận_dữ
# Out of vocabulary word:  buôn_bán
# Out of vocabulary word:  mệt_mỏi
# Out of vocabulary word:  cảm_ứng
# Out of vocabulary word:  dẫn_đầu
# Out of vocabulary word:  xa_xôi
# Out of vocabulary word:  nhạc_cụ
# Out of vocabulary word:  cô_gái
# Out of vocabulary word:  máy_vi_tính
# Out of vocabulary word:  dự_định
# Out of vocabulary word:  hoàn_chỉnh
# Out of vocabulary word:  khôn_ngoan
# Out of vocabulary word:  huỷ_hoại
# Out of vocabulary word:  buồn_cười
# Out of vocabulary word:  dầu_mỏ
# Out of vocabulary word:  toàn_diện
# Out of vocabulary word:  báo_chí
# Out of vocabulary word:  bao_phủ
# Out of vocabulary word:  gắn_bó
# Out of vocabulary word:  nhà_kính
# Out of vocabulary word:  bóng_đèn
# Out of vocabulary word:  linh_hoạt
# Out of vocabulary word:  dịch_bệnh
# Out of vocabulary word:  ngu_ngốc
# Out of vocabulary word:  chi_trả
# Out of vocabulary word:  lắp_ráp
# Out of vocabulary word:  kháng_sinh
# Out of vocabulary word:  lâm_sàng
# Out of vocabulary word:  đến_là
# Out of vocabulary word:  sáng_tác
# Out of vocabulary word:  liệu_pháp
# Out of vocabulary word:  năm_nay
# Out of vocabulary word:  xoá_bỏ
# Out of vocabulary word:  suy_giảm
# Out of vocabulary word:  cộng_tác
# Out of vocabulary word:  sáng_lập
# Out of vocabulary word:  trang_bị
# Out of vocabulary word:  trái_ngược
# Out of vocabulary word:  bổ_sung
# ...
# Out of vocabulary word:  thần_chết
# Out of vocabulary word:  đĩa_mềm
# Out of vocabulary word:  tổng_giám_đốc
# Out of vocabulary word:  quyết_đoán
# Out of vocabulary word:  trẻ_thơ
# Out of vocabulary word:  đá_phiến
# Out of vocabulary word:  babbage
# Out of vocabulary word:  bến_tàu
# Out of vocabulary word:  đầu_tay
# Out of vocabulary word:  thi_công
# Out of vocabulary word:  oldenburg
# Out of vocabulary word:  kim_tự
# Out of vocabulary word:  dây_xích
# Out of vocabulary word:  ống_nhòm
# Out of vocabulary word:  mỹ_nghệ
# Out of vocabulary word:  tay_nghề
# Out of vocabulary word:  ngõ_cụt
# Out of vocabulary word:  luyến_ái
# Out of vocabulary word:  thân_mến
# Out of vocabulary word:  sặc_sỡ
# Out of vocabulary word:  ngoại_lai
# Out of vocabulary word:  đơn_bào
# Out of vocabulary word:  súng_đạn
# Out of vocabulary word:  nguệch_ngoạc
# Out of vocabulary word:  cốt_truyện
# Out of vocabulary word:  bật_cười
# Out of vocabulary word:  thượng_lưu
# Out of vocabulary word:  tự_quyết
# Out of vocabulary word:  meyerowitz
# Out of vocabulary word:  trưởng_phòng
# Out of vocabulary word:  đường_hướng
# Out of vocabulary word:  giải_ngân_hà
# Out of vocabulary word:  hubble
# Out of vocabulary word:  nhiễu_loạn
# Out of vocabulary word:  va_đập
# Out of vocabulary word:  mở_miệng
# Out of vocabulary word:  mcluhan
# Out of vocabulary word:  dị_ứng
# Out of vocabulary word:  mà_còn_về
# Out of vocabulary word:  vẻ_mặt
# Out of vocabulary word:  đùa_cợt
# Out of vocabulary word:  thuốc_nhuộm
# Out of vocabulary word:  nghiền_ngẫm
# Out of vocabulary word:  búp_bê
# Out of vocabulary word:  tĩnh_mạch
# Out of vocabulary word:  u_xơ
# Out of vocabulary word:  đi_sâu
# Out of vocabulary word:  bán_nguyệt
# Out of vocabulary word:  hết_thảy
# Out of vocabulary word:  chất_keo
# Out of vocabulary word:  phai_mờ
# Out of vocabulary word:  y_dược
# Out of vocabulary word:  phép_nhân
# Out of vocabulary word:  quá_hạn
# Out of vocabulary word:  quay_lưng
# Out of vocabulary word:  đóng_đinh
# Out of vocabulary word:  tiếng_vang
# Out of vocabulary word:  chiếm_giữ
# Out of vocabulary word:  ưu_việt
# Out of vocabulary word:  rùng_mình
# Out of vocabulary word:  kuznets
# Out of vocabulary word:  đời_người
# Out of vocabulary word:  công_chiếu
# Out of vocabulary word:  xoay_chiều
# Out of vocabulary word:  seligman
# Out of vocabulary word:  hối_hả
# Out of vocabulary word:  phù_hộ
# Out of vocabulary word:  nước_tiểu
# Out of vocabulary word:  sunitha
# Out of vocabulary word:  bể_bơi
# Out of vocabulary word:  thể_theo
# Out of vocabulary word:  thường_niên
# Out of vocabulary word:  trói_buộc
# Out of vocabulary word:  vì_thế_mà
# Out of vocabulary word:  hồi_trước
# Out of vocabulary word:  đại_gia
# Out of vocabulary word:  bộ_ba
# Out of vocabulary word:  danh_nghĩa
# Out of vocabulary word:  nhẫn_nại
# Out of vocabulary word:  con_lắc
# Out of vocabulary word:  vòng_cung
# Out of vocabulary word:  đau_nhức
# Out of vocabulary word:  darwln
# Out of vocabulary word:  phổ_cập
# Out of vocabulary word:  trọng_tải
# Out of vocabulary word:  tinh_hoa
# Out of vocabulary word:  chu_đáo
# Out of vocabulary word:  hiếu_kì
# Out of vocabulary word:  thanh_lọc
# Out of vocabulary word:  hợp_lực
# Out of vocabulary word:  đề_kháng
# Out of vocabulary word:  ngủ_gục
# Out of vocabulary word:  hàng_hải
# Out of vocabulary word:  đưa_tay
# Out of vocabulary word:  già_nua
# Out of vocabulary word:  bụi_rậm
# Out of vocabulary word:  lúa_mạch
# Out of vocabulary word:  bắt_mắt
# Out of vocabulary word:  feki
# Out of vocabulary word:  sách_báo
# Out of vocabulary word:  cha_ông
# Out of vocabulary word:  chọn_người
# Out of vocabulary word:  không_thèm
# Out of vocabulary word:  ngần_ngại
# Out of vocabulary word:  lưu_huỳnh
# Out of vocabulary word:  phế_phẩm
# Out of vocabulary word:  bàn_ghế
# Out of vocabulary word:  giám_định
# Out of vocabulary word:  thưa_thớt
# Out of vocabulary word:  giá_lạnh
# Out of vocabulary word:  hội_họp
# Out of vocabulary word:  biến_thiên
# Out of vocabulary word:  bù_lại
# Out of vocabulary word:  lên_lớp
# Out of vocabulary word:  phê_duyệt
# Out of vocabulary word:  đầu_máy
# Out of vocabulary word:  kém_cỏi
# Out of vocabulary word:  viện_dẫn
# Out of vocabulary word:  nghe_tin
# Out of vocabulary word:  dẫn_dụ
# Out of vocabulary word:  hôm_sau
# Out of vocabulary word:  trục_tung
# Out of vocabulary word:  khai_sinh
# Out of vocabulary word:  trò_vui
# Out of vocabulary word:  thương_thuyết
# Out of vocabulary word:  cuồng_nhiệt
# Out of vocabulary word:  đung_đưa
# Out of vocabulary word:  chiến_trận
# Out of vocabulary word:  đường_thuỷ
# Out of vocabulary word:  nọc_độc
# Out of vocabulary word:  dựa_dẫm
# Out of vocabulary word:  xương_sườn
# Out of vocabulary word:  ghế_dài
# Out of vocabulary word:  cam_go
# Out of vocabulary word:  ra_bảng
# Out of vocabulary word:  hời_hợt
# Out of vocabulary word:  kén_chọn
# Out of vocabulary word:  sơ_qua
# Out of vocabulary word:  một_lượt
# Out of vocabulary word:  tưởng_thưởng
# Out of vocabulary word:  ngoan_cố
# Out of vocabulary word:  vĩnh_hằng
# Out of vocabulary word:  thú_tội
# Out of vocabulary word:  ngọn_gió
# Out of vocabulary word:  khởi_tố
# Out of vocabulary word:  lo_nghĩ
# Out of vocabulary word:  liên_đoàn
# Out of vocabulary word:  chủ_tâm
# Out of vocabulary word:  tivo
# Out of vocabulary word:  đôi_lần
# Out of vocabulary word:  diệt_cỏ
# Out of vocabulary word:  người_đẹp
# Out of vocabulary word:  màu_nước
# Out of vocabulary word:  chúa_tể
# Out of vocabulary word:  nên_người
# Out of vocabulary word:  tổng_thu_nhập
# Out of vocabulary word:  kéo_lê
# Out of vocabulary word:  lạ_kỳ
# Out of vocabulary word:  phòng_tối
# Out of vocabulary word:  số_đo
# Out of vocabulary word:  denisovan
# Out of vocabulary word:  quả_cảm
# Out of vocabulary word:  đường_tắt
# Out of vocabulary word:  thợ_nề
# Out of vocabulary word:  vệ_sĩ
# Out of vocabulary word:  thời_thượng
# Out of vocabulary word:  rối_tung
# Out of vocabulary word:  ecosia
# Out of vocabulary word:  ra_hiệu
# Out of vocabulary word:  xoắn_ốc
# Out of vocabulary word:  nhất_quyết
# Out of vocabulary word:  dây_giày
# Out of vocabulary word:  ông_ngoại
# Out of vocabulary word:  eo_biển
# Out of vocabulary word:  tiếng_kêu
# Out of vocabulary word:  phiến_loạn
# Out of vocabulary word:  thượng_hải
# Out of vocabulary word:  san_phẳng
# Out of vocabulary word:  bắt_bớ
# Out of vocabulary word:  dầu_cá
# Out of vocabulary word:  ganđi
# Out of vocabulary word:  tân_ngữ
# Out of vocabulary word:  thai_nhi
# Out of vocabulary word:  sai_khiến
# Out of vocabulary word:  hoà_thuận
# Out of vocabulary word:  ra_toà
# Out of vocabulary word:  thử_sức
# Out of vocabulary word:  tài_ba
# Out of vocabulary word:  bài_bản
# Out of vocabulary word:  dracorex
# Out of vocabulary word:  inuit
# Out of vocabulary word:  toàn_năng
# Out of vocabulary word:  giễu_cợt
# Out of vocabulary word:  cuộc_đấu
# Out of vocabulary word:  hải_ly
# Out of vocabulary word:  luận_án
# Out of vocabulary word:  sai_lạc
# Out of vocabulary word:  công_đoàn
# Out of vocabulary word:  vô_tâm
# Out of vocabulary word:  hào_hiệp
# Out of vocabulary word:  kiệt_xuất
# Out of vocabulary word:  hoang_sơ
# Out of vocabulary word:  cừ_khôi
# Out of vocabulary word:  derartu
# Out of vocabulary word:  radcliffe
# Out of vocabulary word:  thương_tích
# Out of vocabulary word:  ập_tới
# Out of vocabulary word:  toàn_phần
# Out of vocabulary word:  đắc_cử
# Out of vocabulary word:  xem_thường
# Out of vocabulary word:  tự_tôn
# Out of vocabulary word:  tích_tắc
# Out of vocabulary word:  đần_độn
# Out of vocabulary word:  đổ_bộ
# Out of vocabulary word:  tỉ_phú
# Out of vocabulary word:  liều_mạng
# Out of vocabulary word:  công_trường
# Out of vocabulary word:  chuyên_đề
# Out of vocabulary word:  liên_hồi
# Out of vocabulary word:  anh_họ
# Out of vocabulary word:  dereck
# Out of vocabulary word:  ác_liệt
# Out of vocabulary word:  xa_hoa
# Out of vocabulary word:  xử_sự
# Out of vocabulary word:  náo_nhiệt
# Out of vocabulary word:  đa_cực
# Out of vocabulary word:  cho_ăn
# Out of vocabulary word:  kê_đơn
# Out of vocabulary word:  không_kích
# Out of vocabulary word:  trưởng_giả
# Out of vocabulary word:  ngột_ngạt
# Out of vocabulary word:  durkheim
# Out of vocabulary word:  viết_hoa
# Out of vocabulary word:  tài_khoá
# Out of vocabulary word:  lau_chùi
# Out of vocabulary word:  chồng_chéo
# Out of vocabulary word:  quần_bò
# Out of vocabulary word:  người_cá
# Out of vocabulary word:  kiêu_hãnh
# Out of vocabulary word:  bắp_cày
# Out of vocabulary word:  khiếu_nại
# Out of vocabulary word:  torvalds
# Out of vocabulary word:  thợ_mỏ
# Out of vocabulary word:  bảo_dưỡng
# Out of vocabulary word:  xdr
# Out of vocabulary word:  chân_lông
# Out of vocabulary word:  xa_lánh
# Out of vocabulary word:  nhà_kinh_doanh
# Out of vocabulary word:  duy_linh
# Out of vocabulary word:  vượt_biên
# Out of vocabulary word:  nhắn_nhủ
# Out of vocabulary word:  chất_khoáng
# Out of vocabulary word:  xứ_sở
# Out of vocabulary word:  trốn_thuế
# Out of vocabulary word:  bạo_loạn
# Out of vocabulary word:  phi_đội
# Out of vocabulary word:  bùa_mê
# Out of vocabulary word:  qui_định
# Out of vocabulary word:  beijerinck
# Out of vocabulary word:  thụt_lùi
# Out of vocabulary word:  sa_thạch
# Out of vocabulary word:  hạ_thuỷ
# Out of vocabulary word:  quay_cuồng
# Out of vocabulary word:  engelbart
# Out of vocabulary word:  tương_hợp
# Out of vocabulary word:  michoacán
# Out of vocabulary word:  fildes
# Out of vocabulary word:  khadija
# Out of vocabulary word:  democracyos
# Out of vocabulary word:  tonya
# Out of vocabulary word:  lục_bảo
# Out of vocabulary word:  moocs
# Out of vocabulary word:  thành_bộ
# Out of vocabulary word:  thâm_thuý
# Out of vocabulary word:  lẩn_trốn
# Out of vocabulary word:  thô_thiển
# Out of vocabulary word:  quán_quân
# Out of vocabulary word:  ông_tự
# Out of vocabulary word:  ưu_đãi
# Out of vocabulary word:  tiền_lẻ
# Out of vocabulary word:  sinh_hoá
# Out of vocabulary word:  gào_thét
# Out of vocabulary word:  joplin
# Out of vocabulary word:  máy_nghe
# Out of vocabulary word:  bè_bạn
# Out of vocabulary word:  nẻo_đường
# Out of vocabulary word:  đứng_lại
# Out of vocabulary word:  gửi_gắm
# Out of vocabulary word:  ngại_ngùng
# Out of vocabulary word:  tí_xíu
# Out of vocabulary word:  tạp_chất
# Out of vocabulary word:  ni_lông
# Out of vocabulary word:  nghỉ_mát
# Out of vocabulary word:  mơ_tưởng
# Out of vocabulary word:  chăm_nom
# Out of vocabulary word:  mò_mẫm
# Out of vocabulary word:  san_bằng
# Out of vocabulary word:  bắt_đầu_từ
# Out of vocabulary word:  trầm_uất
# Out of vocabulary word:  nghìn_dặm
# Out of vocabulary word:  mũi_tiêm
# Out of vocabulary word:  tuổi_đời
# Out of vocabulary word:  postsecret
# Out of vocabulary word:  quần_lót
# Out of vocabulary word:  matty
# Out of vocabulary word:  ngẩng_đầu
# Out of vocabulary word:  sững_sờ
# Out of vocabulary word:  dự_bị
# Out of vocabulary word:  đèn_xanh
# Out of vocabulary word:  dưa_hấu
# Out of vocabulary word:  say_sưa
# Out of vocabulary word:  chức_vụ
# Out of vocabulary word:  vật_phẩm
# Out of vocabulary word:  nước_dùng
# Out of vocabulary word:  khách_mời
# Out of vocabulary word:  ngoại_suy
# Out of vocabulary word:  phân_cách
# Out of vocabulary word:  bệnh_học
# Out of vocabulary word:  quý_hiếm
# Out of vocabulary word:  địa_phận
# Out of vocabulary word:  đầu_bài
# Out of vocabulary word:  hàm_chứa
# Out of vocabulary word:  mãn_kinh
# Out of vocabulary word:  ngồi_thiền
# Out of vocabulary word:  bionicle
# Out of vocabulary word:  kinshasa
# Out of vocabulary word:  thị_chính
# Out of vocabulary word:  gia_hạn
# Out of vocabulary word:  hạ_viện
# Out of vocabulary word:  bệnh_tình
# Out of vocabulary word:  trẻ_hoá
# Out of vocabulary word:  bay_là
# Out of vocabulary word:  lạnh_cóng
# Out of vocabulary word:  starck
# Out of vocabulary word:  trông_chừng
# Out of vocabulary word:  an_lành
# Out of vocabulary word:  khích_động
# Out of vocabulary word:  nhiệt_liệt
# Out of vocabulary word:  hung_bạo
# Out of vocabulary word:  cloudburst
# Out of vocabulary word:  bóng_nước
# Out of vocabulary word:  tiếp_lời
# Out of vocabulary word:  từ_thuở
# Out of vocabulary word:  lặt_vặt
# Out of vocabulary word:  bay_bổng
# Out of vocabulary word:  nhà_giam
# Out of vocabulary word:  tù_tội
# Out of vocabulary word:  buồn_ngủ
# Out of vocabulary word:  ibm.
# Out of vocabulary word:  gallup
# Out of vocabulary word:  cô_đọng
# Out of vocabulary word:  áo_quần
# Out of vocabulary word:  y.
# Out of vocabulary word:  phủ_định
# Out of vocabulary word:  behar
# Out of vocabulary word:  lướt_ván
# Out of vocabulary word:  thẩm_mĩ
# Out of vocabulary word:  da_cam
# Out of vocabulary word:  nhân_giống
# Out of vocabulary word:  lắp_ghép
# Out of vocabulary word:  khám_phá_của
# Out of vocabulary word:  nóng_bỏng
# Out of vocabulary word:  mistry
# Out of vocabulary word:  marcel
# Out of vocabulary word:  khó_tính
# Out of vocabulary word:  cào_cào
# Out of vocabulary word:  hutu
# Out of vocabulary word:  trống_không
# Out of vocabulary word:  lục_lọi
# Out of vocabulary word:  góc_cạnh
# Out of vocabulary word:  cột_cờ
# Out of vocabulary word:  sảng_khoái
# Out of vocabulary word:  nhà_ăn
# Out of vocabulary word:  thấp_kém
# Out of vocabulary word:  nước_cờ
# Out of vocabulary word:  giả_bộ
# Out of vocabulary word:  băng_bó
# Out of vocabulary word:  ông_ta
# Out of vocabulary word:  khúc_mắc
# Out of vocabulary word:  hosni
# Out of vocabulary word:  chật_chội
# Out of vocabulary word:  dưới_quyền
# Out of vocabulary word:  mênh_mông
# Out of vocabulary word:  mẫu_mực
# Out of vocabulary word:  mộ_đạo
# Out of vocabulary word:  tập_tính
# Out of vocabulary word:  đại_ý
# Out of vocabulary word:  chọc_tức
# Out of vocabulary word:  gian_hàng
# Out of vocabulary word:  dầu_thơm
# Out of vocabulary word:  xấu_tính
# Out of vocabulary word:  băng_giá
# Out of vocabulary word:  z.
# Out of vocabulary word:  quy_tụ
# Out of vocabulary word:  có_lí
# Out of vocabulary word:  wael
# Out of vocabulary word:  tờ_rơi
# Out of vocabulary word:  góp_sức
# Out of vocabulary word:  bình_ổn
# Out of vocabulary word:  phồn_thịnh
# Out of vocabulary word:  vụn_vặt
# Out of vocabulary word:  sổ_tay
# Out of vocabulary word:  hải_quan
# Out of vocabulary word:  đạo_phật
# Out of vocabulary word:  đánh_rơi
# Out of vocabulary word:  hộp_đen
# Out of vocabulary word:  nằm_dài
# Out of vocabulary word:  trường_kỷ
# Out of vocabulary word:  crimer
# Out of vocabulary word:  gan_dạ
# Out of vocabulary word:  chín_muồi
# Out of vocabulary word:  cao_siêu
# Out of vocabulary word:  khám_nghiệm
# Out of vocabulary word:  điện_phân
# Out of vocabulary word:  xung_phong
# Out of vocabulary word:  càn_quét
# Out of vocabulary word:  căn_lều
# Out of vocabulary word:  đá_quý
# Out of vocabulary word:  đại_uý
# Out of vocabulary word:  chống_đông
# Out of vocabulary word:  ngoại_biên
# Out of vocabulary word:  rút_gọn
# Out of vocabulary word:  bơ_sữa
# Out of vocabulary word:  nguyên_chất
# Out of vocabulary word:  cách_nhiệt
# Out of vocabulary word:  tụt_hậu
# Out of vocabulary word:  con_ở
# Out of vocabulary word:  công_nghiệp_hoá
# Out of vocabulary word:  hệ_trọng
# Out of vocabulary word:  giày_dép
# Out of vocabulary word:  khuyến_nghị
# Out of vocabulary word:  thiền_định
# Out of vocabulary word:  náo_động
# Out of vocabulary word:  có_thể_nào
# Out of vocabulary word:  dị_thường
# Out of vocabulary word:  hành_trang
# Out of vocabulary word:  lửa_trại
# Out of vocabulary word:  kế_sách
# Out of vocabulary word:  bảng_đen
# Out of vocabulary word:  nước_lên
# Out of vocabulary word:  lưỡng_lự
# Out of vocabulary word:  chạy_của
# Out of vocabulary word:  tái_bản
# Out of vocabulary word:  thép_không_gỉ
# Out of vocabulary word:  chữ_nổi
# Out of vocabulary word:  pháo_đài
# Out of vocabulary word:  chứng_cớ
# Out of vocabulary word:  thượng_nguồn
# Out of vocabulary word:  nhen_nhóm
# Out of vocabulary word:  đèn_pha
# Out of vocabulary word:  sinh_tố
# Out of vocabulary word:  đĩa_hát
# Out of vocabulary word:  orwell
# Out of vocabulary word:  truy_lùng
# Out of vocabulary word:  mêhicô
# Out of vocabulary word:  truyền_dẫn
# Out of vocabulary word:  nam_nữ
# Out of vocabulary word:  sarkozy
# Out of vocabulary word:  tô_vẽ
# Out of vocabulary word:  đi_ở
# Out of vocabulary word:  suy_đồi
# Out of vocabulary word:  xám_xịt
# Out of vocabulary word:  thử_hỏi
# Out of vocabulary word:  cận_kề
# Out of vocabulary word:  xu_thế
# Out of vocabulary word:  hoà_quyện
# Out of vocabulary word:  đại_tá
# Out of vocabulary word:  chen_lấn
# Out of vocabulary word:  chuyển_nhà
# Out of vocabulary word:  nghĩ_ngợi
# Out of vocabulary word:  từ_điển_học
# Out of vocabulary word:  trong_sáng

# %%
class language(object):
    def __init__(self, name, i2t, t2i, embedding_matrix, train, test, val):
        self.name = name
        self.idx2token = i2t
        self.token2idx = t2i
        self.embedding_mat = embedding_matrix
        self.train_idx = train
        self.test_idx = test
        self.val_idx = val
        
vi = language('Vietnam', src_id2token, src_token2id, src_embedding, train_src_indicies, test_src_indicies, val_src_indicies)
en = language('English', tgt_id2token, tgt_token2id, tgt_embedding, train_tgt_indicies, test_tgt_indicies, val_tgt_indicies)

data = {
        'src': vi,
        'tgt': en
       }

pickle.dump(data, open(data_prefix+'vi1.1w-en6k.p', 'wb'))
