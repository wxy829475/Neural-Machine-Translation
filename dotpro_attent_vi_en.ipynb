# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import numpy as np
import pdb
from tqdm import tqdm
import pandas as pd
import pickle
import io
import os
import sacrebleu
from sacrebleu import raw_corpus_bleu, corpus_bleu

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# In[2]:
PAD_idx = 0
SOS_idx = 1
EOS_idx = 2
UNK_idx= 3
batch_size = 64
MAX_SENTENCE_LENGTH = 50

# %%
class language(object):
    def __init__(self, name, i2t, t2i, embedding_matrix, train, test, val):
        self.name = name
        self.idx2token = i2t
        self.token2idx = t2i
        self.embedding_mat = embedding_matrix
        self.train_idx = train
        self.test_idx = test
        self.val_idx = val
        
dataset = pickle.load(open("./vi1.1w-en6k.p", 'rb'))

class LanguageDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """

    def __init__(self, source_lan, translate_lan):
        """
        @param data_list: list of character
        @param target_list: list of targets

        """
        self.source_lan = source_lan
        self.translate_lan = translate_lan
        
        assert (len(self.source_lan) == len(self.translate_lan))

    def __len__(self):
        return len(self.source_lan)

    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        source_lan_idx = self.source_lan[key][:MAX_SENTENCE_LENGTH-1]
        translation_lan_idx = self.translate_lan[key][:MAX_SENTENCE_LENGTH-1]
        source_lan_idx.append(EOS_idx)
        translation_lan_idx.append(EOS_idx)
        
        return [source_lan_idx, translation_lan_idx, len(source_lan_idx), len(translation_lan_idx)]

def vocab_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all
    data have the same length
    """
    source_list = []
    translate_list = []
    length_list = []
    
    # padding
    for datum in batch:

        length_list.append(datum[2])
        s_padded_vec = np.pad(np.array(datum[0]),
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[2])),
                                mode="constant", constant_values=PAD_idx)
        source_list.append(s_padded_vec)
        t_padded_vec = np.pad(np.array(datum[1]),
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[3])),
                                mode="constant", constant_values=PAD_idx)
        translate_list.append(t_padded_vec)
        
#     ind_dec_order = np.argsort(length_list)[::-1]
#     source_list = np.array(source_list)[ind_dec_order]
#     length_list = np.array(length_list)[ind_dec_order]
#     translate_list = np.array(translate_list)[ind_dec_order]
    
    if torch.cuda.is_available and torch.has_cudnn:
        return [torch.from_numpy(np.array(source_list)).cuda(),torch.from_numpy(np.array(translate_list)).cuda()]
    else:
        return [torch.from_numpy(np.array(source_list)),torch.from_numpy(np.array(translate_list))]

# %%
train_dataset = LanguageDataset(dataset['src'].train_idx, dataset['tgt'].train_idx)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=True)

# s_train_dataset = LanguageDataset(train_zh_indicies[2000:2500], train_en_indicies[2000:2500])
# s_train_loader = torch.utils.data.DataLoader(dataset=s_train_dataset,
#                                            batch_size=batch_size,
#                                            collate_fn=vocab_collate_func,
#                                            shuffle=True)

val_dataset = LanguageDataset(dataset['src'].val_idx, dataset['tgt'].val_idx)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

test_dataset = LanguageDataset(dataset['src'].test_idx, dataset['tgt'].test_idx)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

# %%
class ScaledDotProductAttention(nn.Module):
    ''' Scaled Dot-Product Attention '''
    def __init__(self, sqrt_dim, attn_dropout=0.1):
        super().__init__()
        self.sqrt_dim = sqrt_dim
        self.dropout = nn.Dropout(attn_dropout)
        self.softmax = nn.Softmax(dim=2)

    def forward(self, query, k, v, mask=None):
#         Dot product in batch
#         pdb.set_trace()
        attn = torch.bmm(query, k.transpose(1, 2))
#         Rescaling
        attn = attn / self.sqrt_dim
#         Masking
        if mask is not None:
            attn = attn.masked_fill(mask, -np.inf)
#         Normalize attention
        attn = self.softmax(attn)
# ------------ Notice dropout was added -------------
        attn = self.dropout(attn)
    
        output = torch.bmm(attn, v)

        return output, attn
# In[ ]:


class EncoderRNN(nn.Module):
    def __init__(self, emb_dim, hid_dim):
        super(EncoderRNN, self).__init__()
        
        self.hid_dim = hid_dim
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(dataset['src'].embedding_mat), freeze=False)
        self.dropout = nn.Dropout(p=0.3)
        self.gru = nn.GRU(emb_dim, hid_dim, batch_first=True, bidirectional=True)

    def forward(self, inputs, hidden):
        encode_batch_size, length = inputs.size()
        embedded = self.dropout(self.embedding(inputs).float()) # the size -1 is inferred from other dimensions
        output, hidden = self.gru(embedded, hidden)
        hidden = torch.cat((hidden[0:1,:,:], hidden[1:2,:,:]),2)
        return output, hidden

    def init_hidden(self, encode_batch_size):
        
        return torch.rand(2, encode_batch_size, self.hid_dim, device=device)
# In[ ]:

class DecoderRNN(nn.Module):
    def __init__(self, emb_dim, hid_dim, output_dim, dropout_rate=0.3):
        super(DecoderRNN, self).__init__()
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.output_dim = output_dim
        
        self.dropout = nn.Dropout(p=dropout_rate)
        
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(dataset['tgt'].embedding_mat), freeze=False)
        
        self.mapping = nn.Linear(self.emb_dim+self.hid_dim, self.hid_dim)
#         self.attn_combine = nn.Linear(self.hid_dim + self.emb_dim, self.emb_dim)
        self.dot_product_att = ScaledDotProductAttention(sqrt_dim=emb_dim)
        
        self.gru = nn.GRU(emb_dim+hid_dim, hid_dim)
        self.out = nn.Linear(hid_dim, output_dim)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, inputs, hidden, encoder_outputs):
        
        emb = self.dropout(self.embedding(inputs).float())
        
        attn_keys = self.mapping(torch.cat((emb, hidden), dim=2))
        
#         attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
        
        output, attention = self.dot_product_att(attn_keys[0].unsqueeze(0).transpose(0,1), encoder_outputs, encoder_outputs)

#         output = torch.cat((emb[0], attn_applied.squeeze(1)), 1)
#         output = self.attn_combine(output).unsqueeze(0)
#         output = F.relu(output)
        
#         pdb.set_trace()
        output, hidden = self.gru(torch.cat((emb, output.transpose(0,1)), dim=2), hidden)
        output = self.softmax(self.out(output[0]))
        
        return output, hidden, attention

# %%
teacher_forcing_ratio = 1
#input_tensor: list of sentence tensor
def train(source, translate, encoder, decoder, encoder_optimizer, decoder_optimizer,
          criterion):
    encoder.train()
    decoder.train()
    
    cur_batch_size, input_length = source.size()
    cur_batch_size, target_length = translate.size()
    
    
    encoder_hidden = encoder.init_hidden(cur_batch_size)

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    loss = 0

    encoder_output, encoder_hidden = encoder(source, encoder_hidden)

    decoder_input = torch.tensor(np.array([[SOS_idx]]*cur_batch_size).reshape(1,cur_batch_size),device=device)
    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for i in range(target_length):
        
            
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_output)
            
            loss += criterion(decoder_output, translate[:,i])
            decoder_input = translate[:,i].unsqueeze(0)  # Teacher forcing
            
    else:
        # Without teacher forcing: use its own predictions as the next input
        for i in range(target_length):
            decoder_output, decoder_hidden, decoder_attention= decoder(decoder_input, decoder_hidden, encoder_output)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            
            #decoder_input [1, batch size] 
            decoder_input = decoder_input.unsqueeze(0)
 
            loss += criterion(decoder_output, translate[:,i])

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
def compute_corpus_bleu(output_words, target_words):
    output_sentence = [' '.join(parser(words)) for words in output_words]
    target_sentence = [' '.join(parser(words)) for words in target_words]
    
#     ref_sent_list = [[i.split()] for i in target_sentence]
#     candidate_sent_list = [i.split() for i in output_sentence]
    ref_sent_list = [[i for i in target_sentence]]
    candidate_sent_list = [i for i in output_sentence]
#     pdb.set_trace()
#     score = corpus_bleu(ref_sent_list, candidate_sent_list, smoothing_function=chencherry.method1)
    score = raw_corpus_bleu(candidate_sent_list, ref_sent_list)
    
    return score


# In[ ]:


def evaluate2(encoder, decoder, loader):
    encoder.eval()
    decoder.eval()
    input_words = []
    target_words = []
    decoded_words = []
    num_count = 0
    num_count = 0
    for i, (source, translate) in enumerate(loader):
        
        if i > 20:
            break
        
        cur_batch_size = translate.size()[0]
            
        with torch.no_grad():
            encoder_hidden = encoder.init_hidden(cur_batch_size)
        
        input_tensor = source
        target_tensor = translate
        target_length = target_tensor.size()[1]
        
        encoder_output, encoder_hidden = encoder(input_tensor, encoder_hidden)

        decoder_input = torch.tensor(np.array([[SOS_idx]]*cur_batch_size).reshape(1,cur_batch_size),device=device)
        decoder_hidden = encoder_hidden
        
        for i in range(cur_batch_size):
            decoded_words.append([])
            input_words.append([])
            target_words.append([])
        
        for i in range(cur_batch_size):
            for ii in range(input_tensor.size()[1]):
                if dataset['src'].idx2token[input_tensor.cpu().numpy()[i,ii]] != '<PAD>':
                    input_words[num_count].append(dataset['src'].idx2token[input_tensor.cpu().numpy()[i,ii]])
            num_count += 1
        num_count -= cur_batch_size
        for i in range(cur_batch_size):
            for ii in range(target_tensor.size()[1]):
                if dataset['tgt'].idx2token[target_tensor.cpu().numpy()[i,ii]] != '<PAD>':
                    target_words[num_count].append(dataset['tgt'].idx2token[target_tensor.cpu().numpy()[i,ii]])
            num_count += 1
        num_count -= cur_batch_size      
        
        cur_len = np.zeros(cur_batch_size, dtype=int)
        #pdb.set_trace()
        for i in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_output)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            decoder_input = decoder_input.unsqueeze(0)
            
            topi = topi.squeeze().cpu().numpy()
            if cur_len[0] == 0:
                for i in range(len(topi)):
                    decoded_words[num_count+i].append(dataset['tgt'].idx2token[topi[i]])
                    cur_len[i] += 1
            
            else:
                for i in range(len(topi)):
                    if decoded_words[num_count+i][cur_len[i]-1] == '<EOS>':
                        continue
                    decoded_words[num_count+i].append(dataset['tgt'].idx2token[topi[i]])
                    cur_len[i] += 1
        num_count += cur_batch_size
    pre_list = []
    for pre_sentenc in decoded_words:
        pre_list.append("".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in pre_sentenc]).strip())

    true_list = []
    for true_sentenc in target_words:
        true_list.append("".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in true_sentenc]).strip())
    
    true_list2 = []
    true_list2.append(true_list)        
    score = sacrebleu.corpus_bleu(pre_list, true_list2)
    print('bleu score: ', score.score)
    return decoded_words,input_words, target_words, score

# %%
def trainIters(encoder, decoder, n_iters, print_every=800, plot_every=200, learning_rate=0.001):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss(ignore_index = 0)
    count_iter = 0
    for cur_iter in range(1, n_iters + 1):
        for i, (source, translate) in tqdm(enumerate(train_loader) ,total=3334):
            
            loss = train(source, translate, encoder,
                         decoder, encoder_optimizer, decoder_optimizer, criterion)
            print_loss_total += loss
            plot_loss_total += loss
            count_iter += 1
            
            if count_iter % plot_every == 0:
                plot_loss_avg = plot_loss_total / plot_every
                plot_losses.append(plot_loss_avg)
                plot_loss_total = 0
#             if count_iter % print_every == 0:
        
        print_loss_avg = print_loss_total / print_every
        print_loss_total = 0
        print('%d %d%% %.4f' % (cur_iter, cur_iter / n_iters * 100, print_loss_avg))

        print('Train: ')
        _,_,_, score = evaluate2(encoder, decoder, train_loader)
        with open('out4.txt', 'a') as file:
            file.write('small train: ' + str(score.score) + '\n')

        print('validation: ')
        _,_,_, score = evaluate2(encoder, decoder, val_loader)
        with open('out4.txt', 'a') as file:
            file.write('validation: ' + str(score.score) + '\n')

# %%
# In[ ]:


import matplotlib.pyplot as plt
# plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np
# get_ipython().run_line_magic('matplotlib', 'inline')

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.show()
    
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
ENC_EMB_DIM = 300
ZH_EMB_DIM = 300
HID_DIM = 256
OUTPUT_DIM = len(dataset['tgt'].token2idx)


encoder = EncoderRNN(ENC_EMB_DIM, HID_DIM).to(device)
decoder = DecoderRNN(ZH_EMB_DIM, HID_DIM*2, OUTPUT_DIM).to(device)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print ('False, False, corpus_bleu')
# Out:
# False, False, corpus_bleu

# %%
trainIters(encoder, decoder, 17)

# %%
# torch.save(encoder.state_dict(), './model/encoder_stable_ATT2_sub.pth')
# torch.save(decoder.state_dict(), './model/decoder_stable_ATT2_sub.pth')

# %%
encoder.load_state_dict(torch.load('./model/encoder_stable_ATT2_vim.pth'))
decoder.load_state_dict(torch.load('./model/decoder_stable_ATT2_vim.pth'))

# %%
# evaluate2(encoder, decoder, train_loader)
# evaluate2(encoder, decoder, val_loader)
decoded_words,input_words, target_words, score = evaluate2(encoder, decoder, test_loader)
# Out:
# bleu score:  29.63016124412799

# %%
for i in range(len(decoded_words)):
    print('source: ', input_words[i])
    print('target: ', target_words[i])
    print('predict: ', decoded_words[i])
# Out:
# source:  ['làm_sao', 'tôi', 'có_thể', 'trình_bày', 'trong', 'phút', 'về', 'sợi', 'dây', 'liên_kết', 'những', 'người', 'phụ_nữ', 'qua', 'ba', 'thế_hệ', 'về', 'việc_làm', 'thế_nào', 'những', 'sợi', 'dây', 'mạnh_mẽ', 'đáng', 'kinh_ngạc', 'ấy', 'đã', '<UNK>', 'chặt', 'lấy', 'cuộc_sống', 'của', 'một', 'cô', 'bé', 'bốn', 'tuổi', '<UNK>', 'với', 'đứa', 'em_gái', 'nhỏ', 'của', 'cô', 'bé', 'với', 'mẹ', 'và', 'bà', '<EOS>']
# target:  ['how', 'can', 'i', 'speak', 'in', 'minutes', 'about', 'the', 'bonds', 'of', 'women', 'over', 'three', 'generations', 'about', 'how', 'the', 'astonishing', 'strength', 'of', 'those', 'bonds', 'took', 'hold', 'in', 'the', 'life', 'of', 'a', 'four', 'year', 'old', 'girl', '<UNK>', 'with', 'her', 'young', 'sister', 'her', 'mother', 'and', 'her', 'grandmother', 'for', 'five', 'days', 'and', 'nights', 'in', '<EOS>']
# predict:  ['how', 'do', 'i', 'can', 'express', 'up', 'minutes', 'of', 'the', 'bridge', 'of', 'the', 'bridge', 'the', 'women', 'through', 'three', 'generations', 'of', 'how', 'powerful', 'the', 'magic', '<UNK>', 'that', '<UNK>', '<UNK>', 'takes', 'the', 'life', 'of', 'a', 'tiny', 'little', 'girl', 'old', 'little', 'sister', 'with', 'her', 'little', 'sister', 'with', 'my', 'sister', 'and', 'she', 'has', '<EOS>']
# source:  ['câu_chuyện', 'này', 'chưa', 'kết_thúc', '.', '<EOS>']
# target:  ['this', 'is', 'not', 'a', 'finished', 'story', '.', '<EOS>']
# predict:  ['this', 'story', 'hasn', 'apos', 't', 'been', 'over', '.', '<EOS>']
# source:  ['nó', 'là', 'một', 'trò_chơi', 'ghép', 'hình', 'vẫn', 'đang', 'được', 'xếp', '.', '<EOS>']
# target:  ['it', 'is', 'a', '<UNK>', 'puzzle', 'still', 'being', 'put', 'together', '.', '<EOS>']
# predict:  ['it', 'apos', 's', 'a', 'game', 'that', 'apos', 's', 'still', '<UNK>', '.', '<EOS>']
# source:  ['hãy', 'để', 'tôi', 'kể', 'cho', 'các', 'bạn', 'về', 'vài', 'mảnh_ghép', 'nhé', '.', '<EOS>']
# target:  ['let', 'me', 'tell', 'you', 'about', 'some', 'of', 'the', 'pieces', '.', '<EOS>']
# predict:  ['let', 'me', 'tell', 'you', 'about', 'some', 'pieces', '.', '<EOS>']
# source:  ['hãy', 'tưởng_tượng', 'mảnh', 'đầu_tiên', 'một', 'người', 'đàn_ông', 'đốt_cháy', 'sự_nghiệp', 'cả', 'đời', 'mình', '.', '<EOS>']
# target:  ['imagine', 'the', 'first', 'piece', 'a', 'man', 'burning', 'his', 'life', 'apos', 's', 'work', '.', '<EOS>']
# predict:  ['imagine', 'the', 'first', 'thing', 'about', 'a', 'man', 'burned', 'his', 'whole', 'career', '.', '<EOS>']
# source:  ['ông', 'là', 'nhà_thơ', 'nhà', 'viết', 'kịch', 'một', 'người', 'mà_cả', 'cuộc_đời', '<UNK>', 'trên', 'tia', 'hi_vọng', 'duy_nhất', 'rằng', 'đất_nước', 'ông', 'sẽ', 'độc_lập', 'tự_do', '.', '<EOS>']
# target:  ['he', 'is', 'a', 'poet', 'a', '<UNK>', 'a', 'man', 'whose', 'whole', 'life', 'had', 'been', 'balanced', 'on', 'the', 'single', 'hope', 'of', 'his', 'country', 'apos', 's', 'unity', 'and', 'freedom', '.', '<EOS>']
# predict:  ['he', 'apos', 's', 'a', 'poet', 'who', '<UNK>', 'a', 'man', 'but', 'life', '<UNK>', 'on', 'the', '<UNK>', 'of', 'the', 'only', 'time', 'that', 'his', 'country', 'will', 'be', 'free', '.', '<EOS>']
# source:  ['hãy', 'tưởng_tượng', 'ông', 'một', 'người', 'cộng_sản', 'tiến', 'vào', '<UNK>', 'đối_diện', 'sự_thật', 'rằng', 'cả', 'cuộc_đời', 'ông', 'đã', '<UNK>', '.', '<EOS>']
# target:  ['imagine', 'him', 'as', 'the', '<UNK>', 'enter', '<UNK>', '<UNK>', 'the', 'fact', 'that', 'his', 'life', 'had', 'been', 'a', 'complete', 'waste', '.', '<EOS>']
# predict:  ['imagine', 'he', 'was', 'a', '<UNK>', '<UNK>', 'in', 'the', 'face', 'of', 'the', 'fact', 'that', 'his', 'life', 'was', '<UNK>', '.', '<EOS>']
# source:  ['ngôn_từ', 'qua', 'bao', 'năm', 'tháng', 'là', 'bạn', 'đồng_hành', 'với', 'ông', 'giờ', 'quay', 'ra', 'chế_giễu', 'ông', '.', '<EOS>']
# target:  ['words', 'for', 'so', 'long', 'his', 'friends', 'now', '<UNK>', 'him', '.', '<EOS>']
# predict:  ['the', 'word', 'quot', 'charles', 'quot', 'by', 'the', 'way', 'that', 'year', 'after', 'months', 'is', 'you', 'quot', '<UNK>', 'quot', 'for', 'you', 'sir', 'quot', '<UNK>', '!', 'quot', '<UNK>', '<EOS>']
# source:  ['ông', 'rút_lui', 'vào', 'yên_lặng', '.', '<EOS>']
# target:  ['he', '<UNK>', 'into', 'silence', '.', '<EOS>']
# predict:  ['he', '<UNK>', 'off', 'silence', '.', '<EOS>']
# source:  ['ông', 'qua_đời', 'bị', 'lịch_sử', '<UNK>', '.', '<EOS>']
# target:  ['he', 'died', 'broken', 'by', 'history', '.', '<EOS>']
# predict:  ['he', 'died', 'in', 'his', 'history', '.', '<EOS>']
# source:  ['ông', 'là', 'ông', 'của', 'tôi', '.', '<EOS>']
# target:  ['he', 'is', 'my', 'grandfather', '.', '<EOS>']
# predict:  ['he', 'apos', 's', 'my', 'grandfather', '.', '<EOS>']
# source:  ['tôi', 'chưa', 'bao_giờ', 'gặp', 'ông', 'ngoài', 'đời', '.', '<EOS>']
# target:  ['i', 'never', 'knew', 'him', 'in', 'real', 'life', '.', '<EOS>']
# predict:  ['i', 'never', 'met', 'him', 'outside', '.', '<EOS>']
# source:  ['nhưng', 'cuộc_đời', 'ta', 'nhiều', 'hơn', 'những', 'gì', 'ta', 'lưu', 'trong', 'kí_ức', 'nhiều', '.', '<EOS>']
# target:  ['but', 'our', 'lives', 'are', 'much', 'more', 'than', 'our', 'memories', '.', '<EOS>']
# predict:  ['but', 'our', 'lives', 'are', 'more', 'than', 'what', 'we', 'record', 'in', 'this', 'memory', '.', '<EOS>']
# source:  ['bà', 'tôi', 'chưa', 'bao_giờ', 'cho_phép', 'tôi', 'quên', 'cuộc_đời', 'của', 'ông', '.', '<EOS>']
# target:  ['my', 'grandmother', 'never', 'let', 'me', 'forget', 'his', 'life', '.', '<EOS>']
# predict:  ['she', 'never', 'finally', 'able', 'to', 'allow', 'me', 'to', 'forget', 'his', 'life', '.', '<EOS>']
# source:  ['nhiệm_vụ', 'của', 'tôi', 'là', 'không', 'để', 'cuộc_đời', 'ấy', 'qua', 'trong', 'vô_vọng', 'và', 'bài_học', 'của', 'tôi', 'là', 'nhận', 'ra', 'rằng', 'vâng', 'lịch_sử', 'đã', 'cố', '<UNK>', 'chúng_tôi', 'nhưng', 'chúng_tôi', 'đã', 'chịu_đựng', 'được', '.', '<EOS>']
# target:  ['my', 'duty', 'was', 'not', 'to', 'allow', 'it', 'to', 'have', 'been', 'in', '<UNK>', 'and', 'my', 'lesson', 'was', 'to', 'learn', 'that', 'yes', 'history', 'tried', 'to', '<UNK>', 'us', 'but', 'we', '<UNK>', '.', '<EOS>']
# predict:  ['my', 'mission', 'is', 'to', 'not', 'just', 'my', 'life', 'through', '<UNK>', 'and', 'my', 'lesson', 'is', 'to', 'realize', 'that', 'well', 'history', 'has', 'tried', 'to', '<UNK>', 'us', 'but', 'we', 'have', 'suffered', '.', '<EOS>']
# source:  ['mảnh_ghép', 'tiếp_theo', 'của', 'tấm', 'hình', 'là', 'một', 'con', 'thuyền', 'trong', 'sớm', 'hoàng_hôn', 'lặng_lẽ', '<UNK>', 'ra', 'biển', '.', '<EOS>']
# target:  ['the', 'next', 'piece', 'of', 'the', '<UNK>', 'is', 'of', 'a', 'boat', 'in', 'the', 'early', 'dawn', '<UNK>', '<UNK>', 'out', 'to', 'sea', '.', '<EOS>']
# predict:  ['the', 'next', 'piece', 'of', 'the', 'photograph', 'is', 'a', 'coral', 'in', 'the', 'early', '<UNK>', '<UNK>', '<UNK>', 'pops', 'into', 'the', 'sea', '.', '<EOS>']
# source:  ['mẹ', 'tôi', 'mai', 'mới', 'tuổi', 'khi', 'ba', 'của', 'mẹ', 'mất', 'đã', 'lập', 'gia_đình', 'một', 'cuộc', 'hôn_nhân', 'sắp_đặt', 'trước', 'đã', 'có', 'hai', 'cô', 'con', 'gái', 'nhỏ', '.', '<EOS>']
# target:  ['my', 'mother', '<UNK>', 'was', 'when', 'her', 'father', 'died', 'already', 'in', 'an', '<UNK>', 'marriage', 'already', 'with', 'two', 'small', 'girls', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', 'about', 'when', 'three', 'girls', 'had', 'been', 'married', 'to', 'a', 'family', 'portrait', 'two', 'months', 'ago', 'she', 'had', 'two', 'siblings', '.', '<EOS>']
# source:  ['với', 'mẹ', 'cuộc_đời', 'cô_đọng', 'vào', 'nhiệm_vụ', 'duy_nhất', 'để', 'gia_đình', 'mẹ', 'trốn', 'thoát', 'và', 'bắt_đầu', 'cuộc_sống', 'mới', 'ở', 'úc', '.', '<EOS>']
# target:  ['for', 'her', 'life', 'had', '<UNK>', 'itself', 'into', 'one', 'task', 'the', 'escape', 'of', 'her', 'family', 'and', 'a', 'new', 'life', 'in', 'australia', '.', '<EOS>']
# predict:  ['with', 'her', '<UNK>', 'life', '<UNK>', 'her', 'mom', 'and', 'she', '<UNK>', 'and', 'start', 'to', '<UNK>', 'new', 'life', 'in', 'australia', '.', '<EOS>']
# source:  ['mẹ', 'không', 'bao_giờ', 'chấp_nhận', 'được', 'là', 'mẹ', 'sẽ', 'không', 'thành_công', '.', '<EOS>']
# target:  ['it', 'was', '<UNK>', 'to', 'her', 'that', 'she', 'would', 'not', 'succeed', '.', '<EOS>']
# predict:  ['she', 'never', 'accepted', 'as', 'she', 'never', 'successfully', '<UNK>', '.', '<EOS>']
# source:  ['thế_là', 'sau', 'bốn', 'năm', 'một', '<UNK>', '<UNK>', 'hơn_cả', 'trong', 'truyện', 'một', 'chiếc', 'thuyền', '<UNK>', 'ra', 'biển', 'nguỵ_trang', 'là', 'thuyền', 'đánh_cá', '.', '<EOS>']
# target:  ['so', 'after', 'a', 'four', 'year', '<UNK>', 'that', '<UNK>', 'fiction', 'a', 'boat', '<UNK>', 'out', 'to', 'sea', '<UNK>', 'as', 'a', 'fishing', 'vessel', '.', '<EOS>']
# predict:  ['so', 'after', 'four', 'years', 'a', 'year', 'later', 'than', 'a', 'year', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'fishing', '<UNK>', 'fishing', '.', '<EOS>']
# source:  ['tất_cả', 'những', 'người_lớn', 'đều', 'biết', 'các', 'rủi_ro', '.', '<EOS>']
# target:  ['all', 'the', 'adults', 'knew', 'the', 'risks', '.', '<EOS>']
# predict:  ['all', 'the', 'adults', 'know', 'the', 'risks', '.', '<EOS>']
# source:  ['nỗi', 'sợ_hãi', 'lớn', 'nhất_là', 'cướp_biển', 'nạn', 'cưỡng_hiếp', 'và', 'cái', 'chết', '.', '<EOS>']
# target:  ['the', 'greatest', 'fear', 'was', 'of', '<UNK>', 'rape', 'and', 'death', '.', '<EOS>']
# predict:  ['the', 'greatest', 'fear', 'is', '<UNK>', '<UNK>', 'and', 'death', '.', '<EOS>']
# source:  ['như', 'hầu_hết', 'người_lớn', 'trên', 'thuyền', 'mẹ', 'tôi', 'mang', 'theo', 'một', 'chai', 'thuốc_độc', 'nhỏ', '.', '<EOS>']
# target:  ['like', 'most', 'adults', 'on', 'the', 'boat', 'my', 'mother', 'carried', 'a', 'small', 'bottle', 'of', 'poison', '.', '<EOS>']
# predict:  ['as', 'most', 'adults', 'on', 'the', 'boat', 'i', 'brought', 'a', 'small', 'bottle', 'of', '<UNK>', '.', '<EOS>']
# source:  ['nếu', 'chúng_tôi', 'bị', 'bắt', 'đầu_tiên', 'là', 'em', 'tôi', 'và', 'tôi', 'rồi', 'mẹ', 'và', 'bà', 'sẽ', 'uống', '.', '<EOS>']
# target:  ['if', 'we', 'were', 'captured', 'first', 'my', 'sister', 'and', 'i', 'then', 'she', 'and', 'my', 'grandmother', 'would', 'drink', '.', '<EOS>']
# predict:  ['if', 'we', 'were', 'first', 'of', 'my', 'first', 'time', 'and', 'i', 'was', 'my', 'mother', 'and', 'she', 'would', 'be', 'drink', '.', '<EOS>']
# source:  ['kí_ức', 'sớm', 'nhất', 'tôi', 'nhớ', 'được', 'là', 'từ', 'cái', 'thuyền', 'tiếng', 'động_cơ', '<UNK>', 'mạn', 'tiền', 'con', 'thuyền', 'chìm', 'vào', 'mỗi', 'đợt', 'sóng', 'chân_trời', 'mênh_mông', 'trống_trải', '.', '<EOS>']
# target:  ['my', 'first', 'memories', 'are', 'from', 'the', 'boat', 'the', 'steady', 'beat', 'of', 'the', 'engine', 'the', 'bow', '<UNK>', 'into', 'each', 'wave', 'the', 'vast', 'and', 'empty', 'horizon', '.', '<EOS>']
# predict:  ['so', 'the', 'worst', 'memories', 'i', 'remember', 'from', 'the', '<UNK>', 'the', 'power', 'required', 'the', '<UNK>', '<UNK>', 'in', 'each', '<UNK>', 'of', 'the', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'không', 'nhớ', 'lũ', 'cướp', 'biến', 'đã', 'đến', 'rất', 'nhiều', 'lần', 'nhưng', 'bị', 'lừa', 'bỏ_đi', 'bởi', 'sự', '<UNK>', 'càm', 'của', 'những', 'người', 'đàn_ông', 'trên', 'thuyền', 'hay_là', 'khi', 'máy', 'tàu', 'bị', 'chết', 'và', 'không', 'khởi_động', 'được', 'trong_suốt', 'sáu', 'tiếng', 'đồng_hồ', '.', '<EOS>']
# target:  ['i', 'don', 'apos', 't', 'remember', 'the', '<UNK>', 'who', 'came', 'many', 'times', 'but', 'were', '<UNK>', 'by', 'the', '<UNK>', 'of', 'the', 'men', 'on', 'our', 'boat', 'or', 'the', 'engine', 'dying', 'and', 'failing', 'to', 'start', 'for', 'six', 'hours', '.', '<EOS>']
# predict:  ['i', 'don', 'apos', 't', 'remember', 'the', '<UNK>', 'had', 'a', 'lot', 'of', 'times', 'but', 'were', '<UNK>', 'by', 'the', 'weight', 'of', 'all', 'of', 'the', 'men', 'on', 'the', 'boat', 'or', 'when', 'the', 'ships', 'were', 'killed', 'and', 'they', 'stopped', 'the', 'course', 'of', 'the', 'hour', '.', '<EOS>']
# source:  ['nhưng', 'tôi', 'nhớ', 'được', 'ánh', 'đèn', 'từ', 'giàn', 'khoan', 'dầu', 'ngoài', 'bờ_biển', 'malaysia', 'và', 'một', 'anh', 'thanh_niên', 'đã', '<UNK>', 'ngã', 'rồi', 'qua_đời', 'cái', 'kết', 'của', 'cuộc', 'hành_trình', 'là', 'quá_sức', 'chịu_đựng', 'với', 'anh', 'và', 'quả', 'táo', 'đầu_tiên', 'tôi', 'được', 'nếm', 'quả', 'táo', 'mà', 'công_nhân', 'trên', 'giàn', 'khoan', '<UNK>', 'tôi', '<UNK>', '<EOS>']
# target:  ['but', 'i', 'do', 'remember', 'the', 'lights', 'on', 'the', 'oil', 'rig', 'off', 'the', '<UNK>', 'coast', 'and', 'the', 'young', 'man', 'who', 'collapsed', 'and', 'died', 'the', 'journey', 'apos', 's', 'end', 'too', 'much', 'for', 'him', 'and', 'the', 'first', 'apple', 'i', '<UNK>', 'given', 'to', 'me', 'by', 'the', 'men', 'on', 'the', 'rig', '.', '<EOS>']
# predict:  ['but', 'i', 'remember', 'blowing', 'light', 'from', 'oil', '<UNK>', 'oil', 'and', 'a', 'young', 'man', 'fell', 'out', 'of', 'the', '<UNK>', 'and', 'the', '<UNK>', 'of', 'the', 'journey', 'was', 'too', '<UNK>', 'to', 'me', 'and', 'the', 'first', 'thing', 'i', 'was', 'trying', 'to', 'do', 'the', 'apple', 'for', 'the', 'united', 'states', '<UNK>', '<EOS>']
# source:  ['không', 'có', 'quả', 'táo', 'nào', 'ngon', 'được', 'đến', 'thế', '.', '<EOS>']
# target:  ['no', 'apple', 'has', 'ever', '<UNK>', 'the', 'same', '.', '<EOS>']
# predict:  ['there', 'apos', 's', 'no', 'apples', 'that', 'you', 'can', 'apos', 't', 'have', 'any', 'good', '.', '<EOS>']
# source:  ['sau', 'ba', 'tháng', 'trong', 'trại', 'tị_nạn', 'tập_trung', 'chúng_tôi', 'đặt_chân', 'tới', '<UNK>', '.', '<EOS>']
# target:  ['after', 'three', 'months', 'in', 'a', 'refugee', 'camp', 'we', 'landed', 'in', '<UNK>', '.', '<EOS>']
# predict:  ['after', 'three', 'months', 'of', 'refugee', 'camps', 'we', 'were', '<UNK>', '.', '<EOS>']
# source:  ['và', 'mảnh_ghép', 'tiếp_theo', 'của', 'bức', 'tranh', 'là', 'về', 'bốn', 'người', 'phụ_nữ', 'ba', 'thế_hệ', 'cùng_nhau', 'định_hình', 'cuộc_sống', 'mới', '.', '<EOS>']
# target:  ['and', 'the', 'next', 'piece', 'of', 'the', '<UNK>', 'is', 'about', 'four', 'women', 'across', 'three', 'generations', 'shaping', 'a', 'new', 'life', 'together', '.', '<EOS>']
# predict:  ['and', 'the', 'next', 'piece', 'of', 'the', 'piece', 'is', 'about', 'four', 'women', 'and', '<UNK>', 'into', 'the', 'new', 'life', '.', '<EOS>']
# source:  ['chúng_tôi', 'định_cư', 'ở', '<UNK>', 'vùng', 'ngoại_ô', 'cho', 'dân', 'lao_động', 'trong', 'đó', 'dân', 'số', 'là', 'các', 'tầng_lớp', 'người', 'nhập_cư', '.', '<EOS>']
# target:  ['we', 'settled', 'in', '<UNK>', 'a', 'working', 'class', '<UNK>', 'whose', 'demographic', 'is', 'layers', 'of', '<UNK>', '.', '<EOS>']
# predict:  ['we', '<UNK>', 'in', '<UNK>', '<UNK>', 'in', '<UNK>', '<UNK>', 'in', 'which', 'the', 'primary', '<UNK>', 'of', 'the', '<UNK>', '.', '<EOS>']
# source:  ['không', 'như', 'những', 'vùng', 'ngoại_ô', 'ổn_định', 'cho', 'giai_cấp', 'trung_lưu', 'mà', 'tôi', 'không', 'hề', 'biết', 'là', 'có', 'tồn_tại', 'chẳng', 'có', 'tí', 'quyền_lợi', 'nào', 'ở', '<UNK>', '.', '<EOS>']
# target:  ['unlike', 'the', 'settled', 'middle', 'class', '<UNK>', 'whose', 'existence', 'i', 'was', '<UNK>', 'of', 'there', 'was', 'no', 'sense', 'of', '<UNK>', 'in', '<UNK>', '.', '<EOS>']
# predict:  ['not', 'like', '<UNK>', '<UNK>', 'in', 'the', 'middle', 'class', 'room', 'i', 'don', 'apos', 't', 'know', 'there', 'apos', 's', 'nothing', 'there', 'apos', 's', 'nothing', 'to', 'do', 'there', '.', '<EOS>']
# source:  ['mùi', 'từ', 'các', 'cửa_hàng', 'đến', 'từ', 'khắp', 'thế_giới', '.', '<EOS>']
# target:  ['the', 'smells', 'from', 'shop', 'doors', 'were', 'from', 'the', 'rest', 'of', 'the', 'world', '.', '<EOS>']
# predict:  ['the', 'smell', 'of', 'all', 'the', '<UNK>', 'from', 'around', 'the', 'world', '.', '<EOS>']
# source:  ['và', 'những', 'mảnh', 'tiếng', 'anh', '<UNK>', 'trong', 'cuộc', 'hội_thoại', 'giữa', 'những', 'con_người', 'có', 'duy', 'một', 'điểm', 'chung', 'họ', 'đang', 'bắt_đầu', 'lại', 'từ', 'đầu', '.', '<EOS>']
# target:  ['and', 'the', '<UNK>', 'of', '<UNK>', 'english', 'were', '<UNK>', 'between', 'people', 'who', 'had', 'one', 'thing', 'in', 'common', 'they', 'were', 'starting', 'again', '.', '<EOS>']
# predict:  ['and', 'these', '<UNK>', '<UNK>', 'in', 'the', 'conversation', 'about', 'the', 'people', 'who', 'have', 'a', 'common', 'point', 'they', 'apos', 're', 'starting', 'to', 'start', 'back', '.', '<EOS>']
# source:  ['mẹ', 'tôi', 'làm_việc', 'trong', 'trang_trại', 'rồi', 'trong', 'dây_chuyền', 'sản_xuất', 'ô_tô', 'làm_việc', 'tuần', 'sáu', 'ngày', 'hai', 'ca', '.', '<EOS>']
# target:  ['my', 'mother', 'worked', 'on', 'farms', 'then', 'on', 'a', 'car', 'assembly', 'line', 'working', 'six', 'days', 'double', 'shifts', '.', '<EOS>']
# predict:  ['my', 'mom', 'worked', 'in', 'my', 'farm', 'and', 'in', 'the', 'production', 'of', 'production', 'prototypes', 'for', 'nine', 'hours', 'a', 'day', 'two', 'nights', '.', '<EOS>']
# source:  ['thế_mà', 'mẹ', 'vẫn', 'kiếm', 'ra', 'thời_gian', 'học', 'tiếng', 'anh', 'và', 'lấy', 'bằng', 'công_nghệ_thông_tin', '.', '<EOS>']
# target:  ['somehow', 'she', 'found', 'time', 'to', 'study', 'english', 'and', 'gain', 'it', '<UNK>', '.', '<EOS>']
# predict:  ['so', 'she', 'still', 'has', 'a', 'conversation', 'when', 'english', 'and', 'take', 'it', 'through', 'technology', '.', '<EOS>']
# source:  ['chúng_tôi', 'rất', 'nghèo', '.', '<EOS>']
# target:  ['we', 'were', 'poor', '.', '<EOS>']
# predict:  ['we', 'were', 'very', 'poor', '.', '<EOS>']
# source:  ['từng', 'đồng_tiền', 'đều', 'được', 'cân_nhắc', 'và', 'tiền', 'học', 'thêm', 'tiếng', 'anh', 'và', 'toán', 'được', 'đặt', 'riêng', 'ra', 'bất_kể', 'việc', 'khoản', 'nào', 'phải', 'trừ', 'bớt', 'đi', 'thường', 'thì', 'đó', 'là', 'quần_áo', 'mới', 'quần_áo', 'chúng_tôi', 'lúc', 'nào', 'cũng', 'là', 'đồ', 'cũ', '.', '<EOS>']
# target:  ['all', 'the', 'dollars', 'were', '<UNK>', 'and', 'extra', '<UNK>', 'in', 'english', 'and', 'mathematics', 'was', '<UNK>', 'for', 'regardless', 'of', 'what', 'missed', 'out', 'which', 'was', 'usually', 'new', 'clothes', 'they', 'were', 'always', '<UNK>', '.', '<EOS>']
# predict:  ['every', 'money', 'is', 'considered', 'to', '<UNK>', 'and', 'money', 'for', '<UNK>', 'and', 'mathematics', '<UNK>', 'to', 'be', 'whatever', 'it', 'apos', 's', 'considered', 'to', 'be', 'the', 'other', 'siblings', 'that', 'we', 'apos', 're', 'used', 'to', 'be', 'old', '.', '<EOS>']
# source:  ['hai', 'đôi', 'tất', 'để', 'đi', 'học', 'mỗi', 'đôi', 'để', 'che', '<UNK>', 'trên', 'đôi', 'kia', '.', '<EOS>']
# target:  ['two', 'pairs', 'of', '<UNK>', 'for', 'school', 'each', 'to', 'hide', 'the', 'holes', 'in', 'the', 'other', '.', '<EOS>']
# predict:  ['two', '<UNK>', 'to', 'learn', 'to', 'each', 'other', '.', '<EOS>']
# source:  ['một', 'bộ', 'đồng_phục', 'dài', 'tới', '<UNK>', 'vì', 'phải', 'dành', 'mặc', 'đến', 'sáu', 'năm', '.', '<EOS>']
# target:  ['a', 'school', 'uniform', 'down', 'to', 'the', '<UNK>', 'because', 'it', 'had', 'to', 'last', 'for', 'six', 'years', '.', '<EOS>']
# predict:  ['a', 'long', '<UNK>', '<UNK>', 'because', 'it', 'apos', 's', 'waiting', 'for', 'a', 'year', '.', '<EOS>']
# source:  ['thỉnh_thoảng', 'dù', 'ít', 'tôi', 'nghe_thấy', 'tràng', 'chế_giễu', 'xé', 'lòng', 'đồ', 'mắt', '<UNK>', 'và', 'thỉnh_thoảng', 'có', 'hình_vẽ', 'trên', 'tường', 'lũ', 'châu', 'á', '<UNK>', 'về', 'nhà', '.', '<UNK>', '<EOS>']
# target:  ['and', 'there', 'were', 'rare', 'but', '<UNK>', '<UNK>', 'of', 'quot', '<UNK>', 'eye', 'quot', 'and', 'the', '<UNK>', 'graffiti', 'quot', 'asian', 'go', 'home', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['sometimes', 'i', 'heard', '<UNK>', '<UNK>', '<UNK>', 'and', 'sometimes', 'it', 'was', '<UNK>', 'on', 'the', 'walls', 'of', '<UNK>', 'asia', '.', '<EOS>']
# source:  ['về', 'nhà_ở', 'đâu', '?', '<EOS>']
# target:  ['go', 'home', 'to', 'where', '?', '<EOS>']
# predict:  ['what', 'apos', 's', 'home', '?', '<EOS>']
# source:  ['có', 'chút', 'gì', 'cứng', 'lại', 'trong', 'tôi', '.', '<EOS>']
# target:  ['something', '<UNK>', 'inside', 'me', '.', '<EOS>']
# predict:  ['there', 'is', 'a', 'little', 'bit', 'of', '<UNK>', 'in', 'me', '.', '<EOS>']
# source:  ['niềm', 'quyết_tâm', 'tụ', 'lại', 'và', 'một', 'giọng', 'lặng_lẽ', 'nói', 'tôi', 'sẽ', 'đi', 'vòng', 'qua', 'mọi', 'trở_ngại', '.', '<UNK>', '<EOS>']
# target:  ['there', 'was', 'a', 'gathering', 'of', 'resolve', 'and', 'a', 'quiet', 'voice', 'saying', 'quot', 'i', 'will', '<UNK>', 'you', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['and', '<UNK>', '<UNK>', 'and', 'a', '<UNK>', 'says', 'quot', 'i', 'apos', 'll', 'go', 'through', 'all', 'the', '<UNK>', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['mẹ', 'tôi', 'em_gái', 'và', 'tôi', 'ngủ', 'chung', 'trên', 'một', 'chiếc', 'giường', '.', '<EOS>']
# target:  ['my', 'mother', 'my', 'sister', 'and', 'i', 'slept', 'in', 'the', 'same', 'bed', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', 'my', 'sister', 'and', 'i', 'was', 'to', 'sleep', 'in', 'a', 'bed', '.', '<EOS>']
# source:  ['mẹ', '<UNK>', 'nào', 'cũng', 'kiệt_sức', 'nhưng', 'chúng_tôi', 'kể', 'cho', 'nhau', 'nghe', 'chuyện', 'trong', 'ngày', 'và', 'nghe_tiếng', 'bà', 'tôi', 'đi', 'lại', 'quanh', 'nhà', '.', '<EOS>']
# target:  ['my', 'mother', 'was', '<UNK>', 'each', 'night', 'but', 'we', 'told', 'one', 'another', 'about', 'our', 'day', 'and', 'listened', 'to', 'the', 'movements', 'of', 'my', 'grandmother', 'around', 'the', 'house', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', '<UNK>', 'but', 'we', 'told', 'her', 'stories', 'in', 'my', 'day', 'and', 'she', 'heard', 'her', '<UNK>', 'come', 'around', '.', '<EOS>']
# source:  ['mẹ', 'tôi', 'bị', 'bao_nhiêu', 'ác_mộng', 'về', 'chiếc', 'thuyền', '.', '<EOS>']
# target:  ['my', 'mother', 'suffered', 'from', '<UNK>', 'all', 'about', 'the', 'boat', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', 'how', 'much', 'of', 'the', '<UNK>', '.', '<EOS>']
# source:  ['nhiệm_vụ', 'của', 'tôi', 'là', 'thức', 'đến', 'khi', 'mẹ', 'bị', 'ác_mộng', 'hành_hạ', 'để', 'gọi', 'mẹ', 'dậy', '.', '<EOS>']
# target:  ['and', 'my', 'job', 'was', 'to', 'stay', 'awake', 'until', 'her', '<UNK>', 'came', 'so', 'i', 'could', 'wake', 'her', '.', '<EOS>']
# predict:  ['my', 'mission', 'was', 'to', 'be', 'waking', 'up', 'to', 'my', 'mother', 'was', '<UNK>', 'to', 'call', 'her', 'mother', '.', '<EOS>']
# source:  ['mẹ', 'mở', 'cửa_hàng', 'máy_tính', 'rồi', 'học', 'nghề', 'chuyên_viên', 'thẩm_mĩ', 'và', 'mở', 'một', 'cơ_sở', 'kinh_doanh', 'khác', '.', '<EOS>']
# target:  ['she', 'opened', 'a', 'computer', 'store', 'then', 'studied', 'to', 'be', 'a', '<UNK>', 'and', 'opened', 'another', 'business', '.', '<EOS>']
# predict:  ['the', 'mother', 'open', 'the', 'door', 'of', 'the', '<UNK>', 'and', '<UNK>', 'a', 'business', 'business', '.', '<EOS>']
# source:  ['và', 'rồi', 'bao', 'người', 'phụ_nữ', 'đến', 'kể', 'câu_chuyện', 'của', 'họ', 'về', 'những', 'gã', 'đàn_ông', 'không_thể', 'hoà_nhập', 'với', 'cuộc_sống', 'mới', 'giận_dữ', 'và', 'cứng_nhắc', 'và', 'những', 'đứa', 'trẻ', '<UNK>', 'giữa', 'hai', 'thế_giới', '.', '<EOS>']
# target:  ['and', 'the', 'women', 'came', 'with', 'their', 'stories', 'about', 'men', 'who', 'could', 'not', 'make', 'the', 'transition', 'angry', 'and', '<UNK>', 'and', '<UNK>', 'children', 'caught', 'between', 'two', 'worlds', '.', '<EOS>']
# predict:  ['and', 'so', 'many', 'women', 'who', 'come', 'to', 'their', 'story', 'about', 'these', 'men', 'who', 'can', 'apos', 't', '<UNK>', 'with', 'the', '<UNK>', 'and', '<UNK>', 'and', 'the', '<UNK>', '<UNK>', 'between', 'two', 'worlds', '.', '<EOS>']
# source:  ['chúng_tôi', 'kiếm', 'tìm', 'trợ_cấp', 'và', 'những', 'nhà', 'tài_trợ', '.', '<EOS>']
# target:  ['<UNK>', 'and', '<UNK>', 'were', '<UNK>', '.', '<EOS>']
# predict:  ['we', 'apos', 've', 'taken', 'a', 'grant', 'and', '<UNK>', '.', '<EOS>']
# source:  ['các', 'trung_tâm', 'được', 'thành_lập', '.', '<EOS>']
# target:  ['centers', 'were', 'established', '.', '<EOS>']
# predict:  ['the', 'center', 'are', 'formed', '.', '<EOS>']
# source:  ['tôi', 'sống', 'trong', 'hai', 'thế_giới', 'song_song', '.', '<EOS>']
# target:  ['i', 'lived', 'in', 'parallel', 'worlds', '.', '<EOS>']
# predict:  ['i', 'lived', 'in', 'two', 'parallel', 'worlds', '.', '<EOS>']
# source:  ['trong', 'một', 'thế_giới', 'tôi', 'là', 'học_sinh', 'gốc', 'á', 'điển_hình', 'đòi_hỏi', 'khắc_nghiệt', 'từ', 'chính', 'mình', '.', '<EOS>']
# target:  ['in', 'one', 'i', 'was', 'the', 'classic', 'asian', 'student', '<UNK>', 'in', 'the', 'demands', 'that', 'i', 'made', 'on', 'myself', '.', '<EOS>']
# predict:  ['in', 'a', 'world', 'i', 'was', 'a', 'teenager', 'i', 'was', 'particularly', 'the', 'classic', '<UNK>', 'for', 'the', '<UNK>', '.', '<EOS>']
# source:  ['trong', 'thế_giới', 'kia', 'tôi', 'vướng_mắc', 'trong', 'những', 'mảnh', 'đời', 'bấp_bênh', 'bị', 'tổn_thương', 'bi_thảm', 'vì', 'bạo_lực', 'nghiện_ngập', 'và', '<UNK>', '.', '<EOS>']
# target:  ['in', 'the', 'other', 'i', 'was', '<UNK>', 'in', 'lives', 'that', 'were', '<UNK>', '<UNK>', '<UNK>', 'by', 'violence', 'drug', 'abuse', 'and', 'isolation', '.', '<EOS>']
# predict:  ['in', 'the', 'other', 'part', 'i', 'apos', 'm', 'wrapped', 'up', 'in', 'these', '<UNK>', 'of', 'life', 'that', 'are', '<UNK>', 'attacks', 'for', 'extreme', 'violence', 'addiction', 'and', '<UNK>', '.', '<EOS>']
# source:  ['nhưng', 'qua', 'năm_tháng', 'rất', 'nhiều', 'em', 'đã', 'được', 'giúp_đỡ', '.', '<EOS>']
# target:  ['but', 'so', 'many', 'over', 'the', 'years', 'were', 'helped', '.', '<EOS>']
# predict:  ['but', 'in', 'the', 'years', 'of', 'many', 'of', 'you', 'have', 'been', 'help', '.', '<EOS>']
# source:  ['và', 'vì', 'công_tác', 'đó', 'khi', 'tôi', 'là', 'sinh_viên', 'luật', 'năm', 'cuối', 'tôi', 'được', 'bầu', 'là', 'thanh_niên', 'úc', 'của', 'năm', '.', '<EOS>']
# target:  ['and', 'for', 'that', 'work', 'when', 'i', 'was', 'a', 'final', 'year', 'law', 'student', 'i', 'was', 'chosen', 'as', 'the', 'young', '<UNK>', 'of', 'the', 'year', '.', '<EOS>']
# predict:  ['and', 'since', 'then', 'that', 'apos', 's', 'my', 'ph', '.d', '.', 'i', 'was', 'elected', 'to', 'vote', 'the', '<UNK>', 'young', 'men', 'of', 'the', 'year', '.', '<EOS>']
# source:  ['và', 'tôi', 'bị', 'phóng', 'từ', 'mảnh_ghép', 'xếp', 'hình', 'này', 'sang', 'mảnh', 'khác', 'nhưng', 'chúng', 'không', 'ghép', 'vừa', 'với', 'nhau', '.', '<EOS>']
# target:  ['and', 'i', 'was', '<UNK>', 'from', 'one', 'piece', 'of', 'the', '<UNK>', 'to', 'another', 'and', 'their', 'edges', 'didn', 'apos', 't', 'fit', '.', '<EOS>']
# predict:  ['and', 'i', 'was', '<UNK>', 'from', 'this', 'piece', 'of', 'this', 'piece', 'of', 'this', 'piece', 'and', 'it', 'didn', 'apos', 't', 'fit', 'together', '.', '<EOS>']
# source:  ['tan', 'le', 'cư_dân', 'vô_danh', 'ở', 'khu', '<UNK>', 'giờ', 'là', 'tan', 'le', 'người', 'tị_nạn', 'và', 'hoạt_động', 'xã_hội', 'được', 'mời', 'nói_chuyện', 'ở', 'các', 'địa_điểm', 'cô', 'chưa', 'bao_giờ', 'nghe', 'tới', 'được', 'mời', 'vào', 'những', 'nhà', 'mà', 'cô', 'chưa', 'bao_giờ', 'tưởng_tượng', 'được', 'là', 'có', 'tồn_tại', '.', '<EOS>']
# target:  ['<UNK>', '<UNK>', 'anonymous', '<UNK>', '<UNK>', 'was', 'now', '<UNK>', '<UNK>', 'refugee', 'and', 'social', 'activist', 'invited', 'to', 'speak', 'in', '<UNK>', 'she', 'had', 'never', 'heard', 'of', 'and', 'into', 'homes', 'whose', 'existence', 'she', 'could', 'never', 'have', 'imagined', '.', '<EOS>']
# predict:  ['<UNK>', '<UNK>', '<UNK>', '<UNK>', 'the', 'anonymous', '<UNK>', 'in', 'the', '<UNK>', '<UNK>', 'of', '<UNK>', 'camps', 'apos', 's', '<UNK>', 'and', 'activist', 'apos', 's', 'been', 'invited', 'to', 'speak', 'in', 'the', 'locations', 'she', 'never', 'heard', 'of', 'being', 'invited', 'to', 'the', 'house', 'that', 'she', 'never', 'ever', 'imagined', 'is', 'that', 'there', 'was', 'no', 'possibility', '.', '<EOS>']
# source:  ['tôi', 'không', 'biết', 'các', 'qui_trình', '.', '<EOS>']
# target:  ['i', 'didn', 'apos', 't', 'know', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['i', 'don', 'apos', 't', 'know', 'the', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'không', 'biết', 'cách', 'dùng', '<UNK>', 'dĩa', '.', '<EOS>']
# target:  ['i', 'didn', 'apos', 't', 'know', 'how', 'to', 'use', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['i', 'don', 'apos', 't', 'know', 'how', 'to', 'use', 'the', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'không', 'biết', 'nói_chuyện', 'về', 'rượu', '.', '<EOS>']
# target:  ['i', 'didn', 'apos', 't', 'know', 'how', 'to', 'talk', 'about', 'wine', '.', '<EOS>']
# predict:  ['i', 'don', 'apos', 't', 'know', 'about', 'wine', '.', '<EOS>']
# source:  ['tôi', 'không', 'biết', 'nói', 'về', 'cái_gì', 'hết', '.', '<EOS>']
# target:  ['i', 'didn', 'apos', 't', 'know', 'how', 'to', 'talk', 'about', 'anything', '.', '<EOS>']
# predict:  ['i', 'don', 'apos', 't', 'know', 'about', 'all', '.', '<EOS>']
# source:  ['tôi', 'muốn', 'rút', 'về', 'cái', '<UNK>', 'hàng_ngày', 'và', 'sự', 'dễ_chịu', 'của', 'cuộc_sống', 'trong', 'khu', 'ngoại_ô', 'không_ai', 'hay_biết', 'người', 'bà', 'người', 'mẹ', 'và', 'hai', 'con_gái', 'kết_thúc', 'mỗi', 'ngày', 'như', 'bao', 'ngày', 'trong_suốt', 'năm', 'kể', 'cho', 'nhau', 'nghe', 'chuyện', 'trong', 'ngày', 'rồi', 'thiếp', 'ngủ', 'ba', 'người', 'chúng_tôi', 'vẫn', 'chung', 'một', 'giường', '<EOS>']
# target:  ['i', 'wanted', 'to', '<UNK>', 'to', 'the', '<UNK>', 'and', 'comfort', 'of', 'life', 'in', 'an', '<UNK>', '<UNK>', 'a', 'grandmother', 'a', 'mother', 'and', 'two', 'daughters', 'ending', 'each', 'day', 'as', 'they', 'had', 'for', 'almost', 'years', 'telling', 'one', 'another', 'the', 'story', 'of', 'their', 'day', 'and', 'falling', 'asleep', 'the', 'three', 'of', 'us', 'still', 'in', 'the', '<EOS>']
# predict:  ['i', 'want', 'to', 'take', 'a', 'spin', 'about', 'everyday', 'life', 'and', 'the', 'pleasant', 'life', 'in', '<UNK>', 'nobody', 'knew', 'the', 'mothers', 'and', 'two', 'men', 'and', 'two', 'men', 'for', 'days', 'all', 'day', 'for', 'each', 'day', 'for', 'each', 'one', 'day', 'all', 'the', 'day', 'for', 'each', 'one', 'day', 'for', 'the', 'day', 'and', 'one', 'day', '<EOS>']
# source:  ['tôi', 'bảo', 'mẹ', 'là', 'tôi', 'không_thể', 'làm', 'được', '.', '<EOS>']
# target:  ['i', 'told', 'my', 'mother', 'i', 'couldn', 'apos', 't', 'do', 'it', '.', '<EOS>']
# predict:  ['i', 'said', 'quot', 'mom', 'i', 'couldn', 'apos', 't', 'do', 'it', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['mẹ', 'nhắc', 'tôi', 'là', 'bấy_giờ', 'tôi', 'cũng', 'bằng', 'tuổi', 'mẹ', 'khi', 'chúng_tôi', 'lên', 'thuyền', '.', '<EOS>']
# target:  ['she', 'reminded', 'me', 'that', 'i', 'was', 'now', 'the', 'same', 'age', 'she', 'had', 'been', 'when', 'we', '<UNK>', 'the', 'boat', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', 'at', 'the', 'age', 'of', 'my', 'mother', 'when', 'we', 'started', 'on', 'the', 'boat', '.', '<EOS>']
# source:  ['nói', "'", 'không', "'", 'chưa', 'bao_giờ', 'là', 'một', 'lựa_chọn', '.', '<EOS>']
# target:  ['no', 'had', 'never', 'been', 'an', 'option', '.', '<EOS>']
# predict:  ['say', 'quot', 'no', 'never', 'a', 'choice', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['<UNK>', 'cứ', 'làm', 'đi', 'mẹ', 'nói', 'và', 'đừng', 'cố', 'trở_thành', 'người', 'khác', '.', '<UNK>', '<EOS>']
# target:  ['<UNK>', 'quot', 'just', 'do', 'it', 'quot', 'she', 'said', 'quot', 'and', 'don', 'apos', 't', 'be', 'what', 'you', 'apos', 're', 'not', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['<UNK>', 'quot', 'go', 'quot', 'go', 'quot', 'don', 'apos', 't', 'try', 'to', 'be', 'somebody', 'else', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['thế', 'là', 'tôi', 'nói', 'về', 'nạn', 'thanh_niên', 'thất_nghiệp', 'và', 'giáo_dục', 'và', 'về', 'những', 'người', 'bị', 'xã_hội', '<UNK>', 'bị', 'mất', 'quyền_lợi', 'và', 'bỏ_rơi', '.', '<EOS>']
# target:  ['so', 'i', 'spoke', 'out', 'on', 'youth', 'unemployment', 'and', 'education', 'and', 'the', '<UNK>', 'of', 'the', '<UNK>', 'and', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['so', 'i', 'talked', 'about', 'youth', 'who', 'worked', 'and', 'education', 'and', 'about', 'the', 'social', '<UNK>', 'that', 'had', 'been', 'lost', 'and', '<UNK>', '.', '<EOS>']
# source:  ['và', 'tôi', 'càng', 'nói', 'thật_lòng', 'tôi', 'càng', 'được', 'mời', 'nói', 'nhiều', '.', '<EOS>']
# target:  ['and', 'the', 'more', '<UNK>', 'i', 'spoke', 'the', 'more', 'i', 'was', 'asked', 'to', 'speak', '.', '<EOS>']
# predict:  ['and', 'i', 'apos', 'm', 'more', 'like', 'i', 'apos', 've', 'been', 'told', 'to', 'say', 'more', '.', '<EOS>']
# source:  ['tôi', 'gặp', 'những', 'người', 'từ', 'mọi', 'tầng_lớp', 'xã_hội', 'rất', 'nhiều', 'người', 'đang', 'làm_việc', 'họ', 'yêu_thích', 'sống', 'tại', 'ranh_giới', 'của', 'cơ_hội', '.', '<EOS>']
# target:  ['i', 'met', 'people', 'from', 'all', 'walks', 'of', 'life', 'so', 'many', 'of', 'them', 'doing', 'the', 'thing', 'they', 'loved', 'living', 'on', 'the', '<UNK>', 'of', 'possibility', '.', '<EOS>']
# predict:  ['i', 'met', 'people', 'from', 'all', 'the', 'social', 'groups', 'people', 'were', 'working', 'they', 'were', 'in', 'the', 'lines', 'of', 'the', 'opportunity', '.', '<EOS>']
# source:  ['và', 'dù', 'tôi', 'tốt_nghiệp', 'tội', 'nhận', 'ra', 'rằng', 'tôi', 'không_thể', '<UNK>', 'trong', 'nghề', 'luật', '.', '<EOS>']
# target:  ['and', 'even', 'though', 'i', 'finished', 'my', 'degree', 'i', 'realized', 'i', 'could', 'not', 'settle', 'into', 'a', 'career', 'in', 'law', '.', '<EOS>']
# predict:  ['and', 'even', 'though', 'i', '<UNK>', 'guilty', 'that', 'i', 'couldn', 'apos', 't', '<UNK>', 'in', 'the', 'law', '.', '<EOS>']
# source:  ['bức', 'xếp', 'hình', 'cần', 'một', 'mảnh', 'nữa', '.', '<EOS>']
# target:  ['there', 'had', 'to', 'be', 'another', 'piece', 'of', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['the', 'one', 'is', 'the', 'one', 'that', 'takes', 'a', 'piece', 'of', 'stuff', '.', '<EOS>']
# source:  ['và', 'cùng_lúc', 'tôi', 'nhận', 'ra', 'rằng', 'làm', 'kẻ', '<UNK>', 'cũng', 'được', '<UNK>', 'người', 'mới', 'đến', 'mới', 'hiện_diện', 'và', 'không', 'chỉ', 'là', 'được', 'thôi', 'mà', 'là', 'một', 'điều', 'ta', 'cần', 'biết_ơn', 'có_thể', 'là', 'một', 'món', 'quà', 'từ', 'chiếc', 'thuyền', '.', '<EOS>']
# target:  ['and', 'i', 'realized', 'at', 'the', 'same', 'time', 'that', 'it', 'is', 'okay', 'to', 'be', 'an', '<UNK>', 'a', 'recent', '<UNK>', 'new', 'on', 'the', 'scene', 'and', 'not', 'just', 'okay', 'but', 'something', 'to', 'be', '<UNK>', 'for', 'perhaps', 'a', 'gift', 'from', 'the', 'boat', '.', '<EOS>']
# predict:  ['and', 'at', 'the', 'same', 'time', 'i', 'realized', 'that', 'the', '<UNK>', 'is', 'also', '<UNK>', 'the', 'new', '<UNK>', 'to', 'new', '<UNK>', 'and', 'not', 'just', 'like', 'that', 'we', 'need', 'to', 'be', 'grateful', 'to', 'be', 'a', 'piece', 'of', 'the', 'boat', '.', '<EOS>']
# source:  ['bời', 'vì', 'làm_người', 'đứng', 'phía', 'trong', 'có_thể', 'dễ', 'bị', 'thu_hẹp', 'tầm_nhìn', 'có_thể', 'dễ_dàng', 'chấp_nhận', 'những', 'định_kiến', 'trong', 'khu_vực', 'của', 'bạn', '.', '<EOS>']
# target:  ['because', 'being', 'an', '<UNK>', 'can', 'so', 'easily', 'mean', '<UNK>', 'the', '<UNK>', 'can', 'so', 'easily', 'mean', 'accepting', 'the', '<UNK>', 'of', 'your', '<UNK>', '.', '<EOS>']
# predict:  ['because', 'of', 'course', 'is', 'that', 'the', '<UNK>', 'itself', 'can', 'be', 'easily', '<UNK>', 'the', 'stereotypes', 'in', 'your', 'region', '.', '<EOS>']
# source:  ['giờ_đây', 'tôi', 'đã', 'bước', 'ra', 'ngoài', "'", 'vùng', 'an_toàn', "'", 'của', 'mình', 'đủ', 'đẻ', 'biết', 'rằng', 'vâng', 'thế_giới', 'có_thể', 'sụp_đổ', 'nhưng', 'không', 'theo', 'cách', 'bạn', 'sợ_hãi', 'đâu', '.', '<EOS>']
# target:  ['i', 'have', 'stepped', 'outside', 'my', 'comfort', 'zone', 'enough', 'now', 'to', 'know', 'that', 'yes', 'the', 'world', 'does', 'fall', 'apart', 'but', 'not', 'in', 'the', 'way', 'that', 'you', 'fear', '.', '<EOS>']
# predict:  ['now', 'i', 'apos', 've', 'come', 'outside', 'of', 'your', 'own', 'safe', '<UNK>', 'enough', 'to', 'know', 'that', 'the', 'world', 'may', 'be', 'collapsed', 'but', 'in', 'the', 'way', 'you', 'apos', 're', 'afraid', '.', '<EOS>']
# source:  ['những', 'khả_năng', 'mà', 'trước_đây', 'sẽ', 'không', 'được', 'cho_phép', 'được', 'khuyến_khích', 'rất', 'nhiều', '.', '<EOS>']
# target:  ['possibilities', 'that', 'would', 'not', 'have', 'been', 'allowed', 'were', '<UNK>', 'encouraged', '.', '<EOS>']
# predict:  ['the', 'possibilities', 'that', 'have', 'never', 'been', 'possible', 'to', 'be', '<UNK>', 'very', 'much', '.', '<EOS>']
# source:  ['có_một', 'nguồn', 'năng_lượng', 'ngoài', 'đó', 'một', 'niềm', 'lạc_quan', '<UNK>', 'một', 'sự', 'pha_trộn', 'kì_lạ', 'của', 'sự', 'khiêm_nhường', 'và', 'liều_lĩnh', '.', '<EOS>']
# target:  ['there', 'was', 'an', 'energy', 'there', 'an', '<UNK>', 'optimism', 'a', 'strange', 'mixture', 'of', 'humility', 'and', '<UNK>', '.', '<EOS>']
# predict:  ['there', 'apos', 's', 'an', 'energy', 'source', 'that', 'apos', 's', 'an', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'an', '<UNK>', 'of', '<UNK>', 'and', '<UNK>', '.', '<EOS>']
# source:  ['thế', 'nên', 'tôi', 'đi', 'theo', 'linh_cảm', 'của', 'mình', '.', '<EOS>']
# target:  ['so', 'i', 'followed', 'my', '<UNK>', '.', '<EOS>']
# predict:  ['so', 'i', 'went', 'in', 'my', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'thu_thập', 'được', 'một', 'đội', 'nhỏ', 'với', 'chúng_tôi', 'cái', 'tựa', 'không', 'làm', 'được', 'đâu', 'là', 'một', 'thử_thách', 'hấp_dẫn', 'không', 'cưỡng', 'được', '.', '<EOS>']
# target:  ['i', 'gathered', 'around', 'me', 'a', 'small', 'team', 'of', 'people', 'for', 'whom', 'the', 'label', 'quot', 'it', 'can', 'apos', 't', 'be', 'done', 'quot', 'was', 'an', '<UNK>', 'challenge', '.', '<EOS>']
# predict:  ['i', 'collected', 'a', 'small', 'team', 'with', 'us', 'which', 'is', 'a', '<UNK>', 'that', 'apos', 's', 'not', 'been', 'a', 'great', 'challenge', 'of', 'not', 'to', 'resist', '.', '<EOS>']
# source:  ['trong_suốt', 'một', 'năm', 'chúng_tôi', 'không', 'một', 'xu', '<UNK>', '.', '<EOS>']
# target:  ['for', 'a', 'year', 'we', 'were', '<UNK>', '.', '<EOS>']
# predict:  ['in', 'a', 'year', 'we', 'didn', 'apos', 't', 'a', '<UNK>', '.', '<EOS>']
# source:  ['hết', 'ngày', 'tôi', 'làm', 'một', 'nồi', 'súp', 'khổng_lồ', 'để', 'chúng_tôi', 'cùng', 'ăn', '.', '<EOS>']
# target:  ['at', 'the', 'end', 'of', 'each', 'day', 'i', 'made', 'a', 'huge', 'pot', 'of', 'soup', 'which', 'we', 'all', 'shared', '.', '<EOS>']
# predict:  ['and', 'i', 'do', 'it', 'every', 'day', 'i', 'do', 'a', 'giant', 'twist', 'of', 'water', 'we', 'ate', 'it', '.', '<EOS>']
# source:  ['chúng_tôi', 'làm_việc', 'đến', 'đêm', 'khuya', '.', '<EOS>']
# target:  ['we', 'worked', 'well', 'into', 'each', 'night', '.', '<EOS>']
# predict:  ['we', 'worked', 'at', 'night', 'time', '.', '<EOS>']
# source:  ['hầu', 'hết', 'ý_tưởng', 'của', 'chúng_tôi', 'đều', 'điên_khùng', 'nhưng', 'vài', 'ý_tưởng', 'vô_cùng', 'tuyệt_vời', 'và', 'chúng_tôi', 'tạo', 'ra', 'đột_phá', '.', '<EOS>']
# target:  ['most', 'of', 'our', 'ideas', 'were', 'crazy', 'but', 'a', 'few', 'were', 'brilliant', 'and', 'we', 'broke', 'through', '.', '<EOS>']
# predict:  ['all', 'of', 'our', 'ideas', 'are', 'tremendous', 'tremendous', '<UNK>', 'but', 'some', 'of', 'the', 'wonderful', 'idea', 'and', 'we', 'create', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'quyết_định', 'chuyển', 'tới_nước', 'mỹ', '<EOS>']
# target:  ['i', 'made', 'the', 'decision', 'to', 'move', 'to', 'the', 'u', '.s', '.', '<EOS>']
# predict:  ['i', 'decided', 'to', '<UNK>', 'america', '.', '<EOS>']
# source:  ['sau', 'có_một', 'chuyến', 'đi', '.', '<EOS>']
# target:  ['after', 'only', 'one', 'trip', '.', '<EOS>']
# predict:  ['after', 'there', 'apos', 's', 'a', 'trip', '.', '<EOS>']
# source:  ['lại', 'là', 'linh_cảm', '.', '<EOS>']
# target:  ['my', '<UNK>', 'again', '.', '<EOS>']
# predict:  ['it', 'apos', 's', 'a', '<UNK>', '.', '<EOS>']
# source:  ['ba', 'tháng', 'sau', 'tôi', 'chuyển', 'địa_điểm', 'và', 'chuyến', 'phiêu_lưu', 'lại', 'tiếp_diễn', '.', '<EOS>']
# target:  ['three', 'months', 'later', 'i', 'had', '<UNK>', 'and', 'the', 'adventure', 'has', 'continued', '.', '<EOS>']
# predict:  ['three', 'months', 'later', 'i', 'moved', 'my', 'own', 'and', 'drive', 'dates', '.', '<EOS>']
# source:  ['trước_khi', 'tôi', 'kết_thúc', 'hãy', 'đế', 'tôi', 'kể', 'cho', 'các', 'bạn', 'về', 'bà', 'tôi', '.', '<EOS>']
# target:  ['before', 'i', 'close', 'though', 'let', 'me', 'tell', 'you', 'about', 'my', 'grandmother', '.', '<EOS>']
# predict:  ['i', 'ended', 'up', 'let', 'me', 'tell', 'you', 'about', 'my', 'grandmother', '.', '<EOS>']
# source:  ['bà', 'lớn', 'lên', 'trong', 'thời_kì', 'mà', '<UNK>', 'là', 'chuẩn_mực', 'xã_hội', 'và', '<UNK>', 'địa_phương', 'có', 'quyền', '<UNK>', 'sát', '.', '<EOS>']
# target:  ['she', 'grew', 'up', 'at', 'a', 'time', 'when', '<UNK>', 'was', 'the', 'social', 'norm', 'and', 'the', 'local', '<UNK>', 'was', 'the', 'person', 'who', '<UNK>', '.', '<EOS>']
# predict:  ['she', 'grew', 'up', 'in', 'the', 'age', 'of', '<UNK>', 'and', '<UNK>', 'were', 'supposed', 'to', 'meet', 'her', '.', '<EOS>']
# source:  ['cuộc_sống', 'đã_là', 'như_vậy', 'trong', 'hàng', 'thế_kỷ', 'rồi', '.', '<EOS>']
# target:  ['life', 'hadn', 'apos', 't', 'changed', 'for', 'centuries', '.', '<EOS>']
# predict:  ['life', 'is', 'in', 'the', 'early', 's', '.', '<EOS>']
# source:  ['ba', 'của', 'bà', 'mất', 'ngay', 'sau', 'khi', 'bà', 'ra_đời', '.', '<EOS>']
# target:  ['her', 'father', 'died', 'soon', 'after', 'she', 'was', 'born', '.', '<EOS>']
# predict:  ['she', 'took', 'three', 'minutes', 'after', 'she', 'was', 'born', '.', '<EOS>']
# source:  ['mẹ', 'của', 'bà', 'một_mình', 'nuôi', '<UNK>', '.', '<EOS>']
# target:  ['her', 'mother', 'raised', 'her', 'alone', '.', '<EOS>']
# predict:  ['her', 'mother', 'was', '<UNK>', '.', '<EOS>']
# source:  ['năm', 'tuổi', 'bà', 'trở_thành', '<UNK>', 'của', 'một', 'ông', 'quan', '<UNK>', 'ông', 'quan', 'này', 'đánh_đập', 'bà', '.', '<EOS>']
# target:  ['at', 'she', 'became', 'the', 'second', 'wife', 'of', 'a', '<UNK>', 'whose', 'mother', 'beat', 'her', '.', '<EOS>']
# predict:  ['in', 'the', 'year', 'she', 'was', 'a', '<UNK>', 'he', 'was', 'his', '<UNK>', '<UNK>', '.', '<EOS>']
# source:  ['và', 'dầu', 'vấp', 'phải', 'sự', 'không', 'ủng_hộ', 'của', 'chồng', 'bà', 'gây', 'chấn_động', 'khi', 'kiện', 'ông', 'ta', 'ra_toà', 'và', 'tự', 'khởi_tố', 'và', 'còn', 'gây', 'chấn_động', 'mạnh', 'hơn', 'khi', 'bà', 'thắng', 'kiện', '.', '<EOS>']
# target:  ['with', 'no', 'support', 'from', 'her', 'husband', 'she', 'caused', 'a', 'sensation', 'by', 'taking', 'him', 'to', 'court', 'and', '<UNK>', 'her', 'own', 'case', 'and', 'a', 'far', 'greater', 'sensation', 'when', 'she', 'won', '.', '<EOS>']
# predict:  ['and', 'so', 'the', 'oil', '<UNK>', '<UNK>', 'her', '<UNK>', '<UNK>', 'when', '<UNK>', 'her', '<UNK>', 'and', '<UNK>', 'and', '<UNK>', 'and', '<UNK>', 'and', '<UNK>', 'and', 'more', '<UNK>', 'when', 'she', 'won', 'apos', 't', '<UNK>', '.', '<EOS>']
# source:  ['<UNK>', 'không', 'làm', 'được', 'đâu', 'bị', 'chứng_minh', 'là', 'sai', '.', '<EOS>']
# target:  ['<UNK>', 'quot', 'it', 'can', 'apos', 't', 'be', 'done', 'quot', 'was', 'shown', 'to', 'be', 'wrong', '.', '<EOS>']
# predict:  ['<UNK>', 'quot', 'no', '<UNK>', 'is', 'wrong', '.', '<EOS>']
# source:  ['tôi', 'đang', 'tắm', 'trong', 'một', 'phòng', 'khách_sạn', 'ở', 'sydney', 'vào', 'thời_khắc', 'bà', 'mất', 'cách', 'đó', 'dặm', 'ở', '<UNK>', '.', '<EOS>']
# target:  ['i', 'was', 'taking', 'a', 'shower', 'in', 'a', 'hotel', 'room', 'in', '<UNK>', 'the', 'moment', 'she', 'died', 'miles', 'away', 'in', '<UNK>', '.', '<EOS>']
# predict:  ['i', 'apos', 'm', 'shower', 'in', 'a', 'hotel', 'room', 'in', '<UNK>', 'in', '<UNK>', 'in', 'a', 'moment', 'when', 'she', 'loses', 'miles', 'away', 'from', '<UNK>', '.', '<EOS>']
# source:  ['tôi', 'nhìn', 'qua', 'tấm', '<UNK>', 'và', '<UNK>', 'đứng', 'ở', 'bên', 'kia', '<EOS>']
# target:  ['i', 'looked', 'through', 'the', 'shower', 'screen', 'and', 'saw', 'her', 'standing', 'on', 'the', 'other', 'side', '.', '<EOS>']
# predict:  ['i', 'look', 'at', 'the', '<UNK>', 'and', '<UNK>', 'stand', 'up', 'there', '.', '<EOS>']
# source:  ['tôi', 'biết', 'bà', 'đã', 'đến', 'để', 'tạm_biệt', 'tôi', '.', '<EOS>']
# target:  ['i', 'knew', 'she', 'had', 'come', 'to', 'say', 'goodbye', '.', '<EOS>']
# predict:  ['i', 'know', 'she', 'has', 'to', 'speak', 'to', 'my', 'goodbye', '.', '<EOS>']
# source:  ['vài', 'phút', 'sau', 'mẹ', 'tôi', 'gọi', 'điện', '.', '<EOS>']
# target:  ['my', 'mother', '<UNK>', 'minutes', 'later', '.', '<EOS>']
# predict:  ['there', 'are', 'some', 'minute', 'later', 'my', 'mother', 'call', 'electricity', '.', '<EOS>']
# source:  ['vài', 'ngày', 'sau', 'chúng_tôi', 'đến', 'một', 'ngôi', '<UNK>', 'đạo_phật', 'ở', '<UNK>', 'và', 'ngồi', 'quanh', 'quan_tài', 'của', 'bà', '.', '<EOS>']
# target:  ['a', 'few', 'days', 'later', 'we', 'went', 'to', 'a', 'buddhist', 'temple', 'in', '<UNK>', 'and', 'sat', 'around', 'her', '<UNK>', '.', '<EOS>']
# predict:  ['a', 'few', 'days', 'later', 'we', 'went', 'to', 'a', '<UNK>', '<UNK>', 'in', '<UNK>', 'and', 'sat', 'around', 'her', '<UNK>', '.', '<EOS>']
# source:  ['chúng_tôi', 'kể_chuyện', 'cho', 'bà', 'và', 'cam_đoan', 'với', 'bà', 'là', 'chúng_tôi', 'luôn', 'ở', 'bên', 'bà', '.', '<EOS>']
# target:  ['we', 'told', 'her', 'stories', 'and', '<UNK>', 'her', 'that', 'we', 'were', 'still', 'with', 'her', '.', '<EOS>']
# predict:  ['we', 'told', 'her', 'and', 'i', 'was', 'sure', 'we', 'were', 'all', 'connected', '.', '<EOS>']
# source:  ['lúc', 'nửa_đêm', 'một', 'nhà_sư', 'đến', 'và', 'bảo', 'chúng_tôi', 'là', 'ông', 'phải', 'đóng', 'quan_tài', 'rồi', '.', '<EOS>']
# target:  ['at', '<UNK>', 'the', '<UNK>', 'came', 'and', 'told', 'us', 'he', 'had', 'to', 'close', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['and', 'at', 'the', 'middle', 'of', 'the', 'night', 'a', 'stroke', 'goes', 'to', 'tell', 'us', 'that', 'he', 'had', 'to', 'stay', '<UNK>', '.', '<EOS>']
# source:  ['mẹ', 'bảo', 'chúng_tôi', 'cảm_nhận', 'tay', 'bà', 'tôi', '.', '<EOS>']
# target:  ['my', 'mother', 'asked', 'us', 'to', 'feel', 'her', 'hand', '.', '<EOS>']
# predict:  ['she', 'said', 'quot', 'we', 'feel', 'my', 'hands', '.', '<EOS>']
# source:  ['mẹ', 'tôi', 'hỏi', 'nhà_sư', 'tại_sao', 'tay', 'mẹ', 'tôi', 'ấm', 'thế', 'mà', 'cả', 'người', 'lại', '<UNK>', '?', '<UNK>', '<EOS>']
# target:  ['she', 'asked', 'the', '<UNK>', 'quot', 'why', 'is', 'it', 'that', 'her', 'hand', 'is', 'so', 'warm', 'and', 'the', 'rest', 'of', 'her', 'is', 'so', 'cold', '?', 'quot', '<UNK>', '<EOS>']
# predict:  ['my', 'mom', 'asked', 'me', 'quot', 'why', 'my', 'mom', '<UNK>', 'so', 'that', 'everybody', 'else', '?', 'quot', '<UNK>', '<EOS>']
# source:  ['<UNK>', 'bởi_vì', 'từ', 'sàng', 'các', 'chị', 'đã', 'cầm_tay', 'bà', 'ông', 'nói', '.', '<EOS>']
# target:  ['<UNK>', 'quot', 'because', 'you', 'have', 'been', 'holding', 'it', 'since', 'this', 'morning', 'quot', 'he', 'said', '.', '<EOS>']
# predict:  ['<UNK>', 'quot', 'because', 'the', '<UNK>', 'are', 'paid', 'attention', '.', '<EOS>']
# source:  ['<UNK>', 'các', 'chị', 'không_hề', '<UNK>', '.', '<UNK>', '<EOS>']
# target:  ['<UNK>', 'quot', 'you', 'have', 'not', 'let', 'it', 'go', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['<UNK>', 'quot', 'you', 'don', 'apos', 't', 'have', 'a', '<UNK>', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['nếu', 'có_một', 'nguồn_lực', 'trong', 'gia_đình', 'chúng_tôi', 'nguồn', 'ấy', 'truyền', 'qua', 'những', 'người', 'phụ_nữ', '.', '<EOS>']
# target:  ['if', 'there', 'is', 'a', '<UNK>', 'in', 'our', 'family', 'it', 'runs', 'through', 'the', 'women', '.', '<EOS>']
# predict:  ['if', 'there', 'is', 'a', 'force', 'in', 'our', 'family', 'we', 'have', 'the', 'source', 'of', 'the', '<UNK>', '.', '<EOS>']
# source:  ['bởi_vì', 'chúng_tôi', 'là', 'ai', 'và', 'cuộc_đời', 'đã', 'định_hình', 'chúng_tôi', 'như', 'thế_nào', 'giờ', 'chúng_tôi', 'có_thể', 'thấy', 'rằng', 'những', 'người', 'đàn_ông', 'mà', 'có_thể', 'đã', 'đi', 'vào', 'cuộc_đời', 'của', 'chúng_tôi', 'sẽ', 'ngăn_trở', 'chúng_tôi', '.', '<EOS>']
# target:  ['given', 'who', 'we', 'were', 'and', 'how', 'life', 'had', 'shaped', 'us', 'we', 'can', 'now', 'see', 'that', 'the', 'men', 'who', 'might', 'have', 'come', 'into', 'our', 'lives', 'would', 'have', '<UNK>', 'us', '.', '<EOS>']
# predict:  ['because', 'we', 'are', 'and', 'that', 'lives', 'that', 'we', 'shape', 'that', 'our', 'lives', 'are', 'now', 'we', 'can', 'see', 'that', 'men', 'who', 'can', 'have', 'been', 'in', 'our', 'lives', 'that', 'we', 'will', 'be', 'in', 'our', 'lives', '.', '<EOS>']
# source:  ['thất_bại', 'sẽ', 'đến', 'một_cách', 'dễ_dàng', '.', '<EOS>']
# target:  ['defeat', 'would', 'have', 'come', 'too', 'easily', '.', '<EOS>']
# predict:  ['it', 'apos', 's', 'going', 'to', 'be', 'easy', '.', '<EOS>']
# source:  ['giờ_đây', 'tôi', 'cũng', 'muốn', 'có_con', 'và', 'tôi', 'băn_khoăn', 'về', 'con', 'thuyền', '.', '<EOS>']
# target:  ['now', 'i', 'would', 'like', 'to', 'have', 'my', 'own', 'children', 'and', 'i', 'wonder', 'about', 'the', 'boat', '.', '<EOS>']
# ...
# source:  ['xin', 'cảm_ơn', '.', '<EOS>']
# target:  ['thank', 'you', '.', '<EOS>']
# predict:  ['thank', 'you', '.', '<EOS>']
# source:  ['tôi', 'muốn', 'nói', 'với', 'các', 'bạn', 'lý_do', 'tại_sao', 'nhiều', 'dự_án', 'y_tế', 'điện_tử', 'lại', 'thất_bại', '<EOS>']
# target:  ['i', 'would', 'like', 'to', 'talk', 'to', 'you', 'about', 'why', 'many', 'e', 'health', 'projects', 'fail', '.', '<EOS>']
# predict:  ['i', 'want', 'to', 'tell', 'you', 'why', 'many', 'of', 'the', 'medical', 'care', 'system', 'fail', '.', '<EOS>']
# source:  ['và', 'tôi', 'thực_sự', 'nghĩ', 'rằng', 'điều', 'quan_trọng', 'nhất', 'là', 'chúng_ta', 'không', 'còn', 'lắng', 'nghe', 'bệnh', 'nhân', 'nữa', '.', '<EOS>']
# target:  ['and', 'i', 'really', 'think', 'that', 'the', 'most', 'important', 'thing', 'of', 'it', 'is', 'that', 'we', 'stopped', 'listening', 'to', 'patients', '.', '<EOS>']
# predict:  ['and', 'i', 'really', 'think', 'the', 'most', 'important', 'thing', 'is', 'we', 'don', 'apos', 't', 'have', 'heard', 'of', 'the', 'other', '.', '<EOS>']
# source:  ['một', 'trong', 'những', 'điều', 'mà', 'chúng_tôi', 'thực_hiện', 'tại', 'trường', 'đại_học', '<UNK>', 'là', 'bổ_nhiệm', 'một', 'chuyên_viên', 'lắng_nghe', '<EOS>']
# target:  ['and', 'one', 'of', 'the', 'things', 'we', 'did', 'at', '<UNK>', 'university', 'is', 'we', '<UNK>', 'a', 'chief', 'listening', 'officer', '.', '<EOS>']
# predict:  ['one', 'of', 'the', 'things', 'that', 'we', 'did', 'in', 'the', 'university', 'of', '<UNK>', 'was', '<UNK>', 'was', 'an', '<UNK>', '.', '<EOS>']
# source:  ['không_phải', 'theo', 'một_cách', 'khoa_học', 'cô', 'ấy', 'đặt', 'một', 'tách', 'cà_phê', 'hoặc', 'một', 'tách', 'trà', 'nhỏ', 'và', 'hỏi', 'thăm', 'bệnh_nhân', 'gia_đình', 'và', 'họ_hàng', 'có', 'chuyện', 'gì', 'vậy', '?', '<EOS>']
# target:  ['not', 'in', 'a', 'very', 'scientific', 'way', 'she', 'puts', 'up', 'a', 'little', 'cup', 'of', 'coffee', 'or', 'cup', 'of', 'tea', 'and', 'asks', 'patients', 'family', 'relatives', 'quot', 'what', 'apos', 's', 'up', '?', '<EOS>']
# predict:  ['not', 'in', 'science', 'she', 'puts', 'a', 'coffee', 'or', 'a', 'bridge', 'and', 'ask', 'her', 'family', 'cousin', 'and', 'what', 'do', 'you', 'mean', '?', '<EOS>']
# source:  ['chúng_tôi', 'có_thể', 'giúp', 'gì', 'được', 'cho', 'bạn', '?', '<UNK>', '<EOS>']
# target:  ['how', 'could', 'we', 'help', 'you', '?', 'quot', '<UNK>', '<EOS>']
# predict:  ['what', 'can', 'we', 'help', 'you', '?', 'quot', '<UNK>', '<EOS>']
# source:  ['và', 'chúng_tôi', 'nghĩ', 'rằng', 'đây', 'là', 'một', 'trong', 'những', 'vấn_đề', 'chính', 'mà', 'tại_sao', 'tất_cả', 'có_lẽ', 'không_phải', 'tất_cả', 'nhưng', 'hầu_hết', 'các', 'dự_án', 'y_tế', 'điện_tử', 'lại', 'thất_bại', 'kể', 'từ', 'khi', 'chúng_ta', 'không', 'còn', 'lắng_nghe', 'nữa', '.', '<EOS>']
# target:  ['and', 'we', 'think', 'we', 'like', 'to', 'think', 'that', 'this', 'is', 'one', 'of', 'the', 'major', 'problems', 'why', 'all', 'maybe', 'not', 'all', 'but', 'most', 'of', 'the', 'e', 'health', 'projects', 'fail', 'since', 'we', 'stopped', 'listening', '.', '<EOS>']
# predict:  ['and', 'we', 'think', 'this', 'is', 'one', 'of', 'the', 'main', 'problems', 'why', 'all', 'of', 'these', 'things', 'don', 'apos', 't', 'all', 'but', 'most', 'expensive', 'clinical', 'trials', 'fail', 'to', 'say', 'we', 'don', 'apos', 't', 'have', 'to', 'listen', 'anymore', '.', '<EOS>']
# source:  ['đây', 'là', 'chiếc', 'cân', 'điện_tử', 'của', 'tôi', '.', 'đó', 'là', 'một', 'thiết_bị', 'rất', 'đơn_giản', '.', '<EOS>']
# target:  ['this', 'is', 'my', '<UNK>', 'scale', '.', 'it', 'apos', 's', 'a', 'very', 'simple', 'thing', '.', '<EOS>']
# predict:  ['this', 'is', 'my', 'electronics', '.', 'it', 'apos', 's', 'a', 'very', 'simple', 'device', '.', '<EOS>']
# source:  ['nó', 'có_một', 'nút_bấm', 'ở', 'giữa', 'để', 'bật', 'tắt', '.', '<EOS>']
# target:  ['it', 'apos', 's', 'got', 'one', '<UNK>', 'on', 'off', '.', '<EOS>']
# predict:  ['it', 'apos', 's', 'a', 'button', 'in', 'the', 'middle', 'to', 'turn', 'off', '.', '<EOS>']
# source:  ['vào', 'mỗi', 'buổi_sáng', 'tôi', 'đứng', '<UNK>', '.', '<EOS>']
# target:  ['and', 'every', 'morning', 'i', 'hop', 'on', 'it', '.', '<EOS>']
# predict:  ['in', 'every', 'morning', 'i', 'stand', 'up', '.', '<EOS>']
# source:  ['và', 'đúng', 'là', 'tôi', 'rất', 'lo', 'và', 'hồi_hộp', 'như', 'bạn', 'có_thể', 'thấy', '.', '<EOS>']
# target:  ['and', 'yes', 'i', 'apos', 've', 'got', 'a', 'challenge', 'as', 'you', 'might', 'see', '.', '<EOS>']
# predict:  ['and', 'yes', 'i', 'apos', 'm', 'worried', 'about', 'and', 'nervous', 'as', 'you', 'can', 'see', '.', '<EOS>']
# source:  ['tôi', 'sợ', 'rằng', 'mình', 'tăng', 'đến', 'kg', '.', '<EOS>']
# target:  ['and', 'i', 'put', 'my', 'challenge', 'on', '<UNK>', '.', '<EOS>']
# predict:  ['i', 'fear', 'that', 'i', 'apos', 'll', '<UNK>', 'up', '.', '<EOS>']
# source:  ['nhưng', 'điều', 'làm_cho', 'thiết_bị', 'này', 'đơn_giản', 'là', 'bất_cứ', 'khi', 'nào', 'tôi', 'đứng', '<UNK>', 'nó', 'đều', 'gửi', 'dữ_liệu', 'của', 'tôi', 'qua', 'google', '<UNK>', '<EOS>']
# target:  ['but', 'the', 'thing', 'is', 'that', 'it', 'apos', 's', 'made', 'this', 'simple', 'that', 'whenever', 'i', 'hop', 'on', 'it', 'sends', 'my', 'data', 'through', 'google', 'health', 'as', 'well', '.', '<EOS>']
# predict:  ['but', 'what', 'makes', 'this', 'device', 'simply', 'to', 'me', 'once', 'i', '<UNK>', 'it', 'all', 'send', 'my', 'data', 'through', 'google', '.', '<EOS>']
# source:  ['và', 'bác', 'sỹ', 'của', 'tôi', 'cũng', 'sẽ', 'thu', 'được', 'những', 'dữ_liệu', 'này', 'để', 'ông', 'có_thể', 'thấy', 'những', 'vấn_đề', 'liên_quan', 'đến', 'trọng_lượng', 'của', 'tôi', '.', 'không', 'chỉ', 'ngay', 'tại', 'thời_điểm', 'mà', 'tôi', 'cần', 'được', 'hỗ_trợ', 'về', 'tim_mạch', 'hay', 'điều', 'gì', 'khác', 'đại_loại', 'như_vậy', 'mà_còn', 'trong_suốt', 'khoảng', 'thời_gian', 'trước', 'đó', 'nữa', '<EOS>']
# target:  ['and', 'it', 'apos', 's', 'collected', 'by', 'my', 'general', '<UNK>', 'as', 'well', 'so', 'he', 'can', 'see', 'what', 'apos', 's', 'my', 'problem', 'in', 'weight', 'not', 'on', 'the', 'very', 'moment', 'that', 'i', 'need', '<UNK>', 'support', 'or', 'something', 'like', 'it', 'but', 'also', 'looking', '<UNK>', '.', '<EOS>']
# predict:  ['and', 'my', 'doctor', 'will', 'also', 'receive', 'data', 'so', 'that', 'you', 'can', 'see', 'the', 'problem', 'to', 'help', 'you', 'see', 'the', 'problem', 'with', 'my', 'weight', '.', 'not', 'just', 'at', 'the', 'time', 'i', 'need', 'to', 'help', '<UNK>', 'or', 'something', 'else', 'but', 'in', 'the', 'time', 'that', 'span', 'of', 'time', 'that', 'seems', 'too', 'much', '.']
# source:  ['nhưng', 'một', 'điều', 'khác', 'nữa', '.', '<EOS>']
# target:  ['but', 'there', 'apos', 's', 'another', 'thing', '.', '<EOS>']
# predict:  ['but', 'another', 'thing', 'is', '.', '<EOS>']
# source:  ['như', 'một_số', 'các', 'bạn', 'biết', 'rằng', 'tôi', 'có', 'hơn', 'người', 'theo_dõi', 'trên', 'trang', 'twitter', '.', '<EOS>']
# target:  ['as', 'some', 'of', 'you', 'might', 'know', 'i', 'apos', 've', 'got', 'more', 'than', '<UNK>', 'on', 'twitter', '.', '<EOS>']
# predict:  ['as', 'some', 'of', 'you', 'know', 'that', 'i', 'have', 'more', 'than', 'you', 'go', 'on', 'twitter', '.', '<EOS>']
# source:  ['vì_vậy', 'mỗi', 'buổi_sáng', 'tôi', 'đứng', 'cân', 'trên', 'chiếc', 'cân', 'wifi', 'và', 'trước_khi', 'tôi', 'bước', 'lên', 'xe', 'mọi', 'người', 'đã', 'bắt_đầu', 'nói', 'với', 'tôi', 'rằng', 'tôi', 'nghĩ', 'trưa', 'nay', 'anh', 'nên', 'ăn', 'ít', 'thôi', '<UNK>', 'à', '.', '<UNK>', '<EOS>']
# target:  ['so', 'every', 'morning', 'i', 'hop', 'on', 'my', '<UNK>', 'scale', 'and', 'before', 'i', 'apos', 'm', 'in', 'my', 'car', 'people', 'start', 'talking', 'to', 'me', 'quot', 'i', 'think', 'you', 'need', 'a', 'light', 'lunch', 'today', '<UNK>', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['so', 'every', 'morning', 'i', 'stand', 'up', 'on', 'a', 'scale', 'of', '<UNK>', 'and', 'i', 'apos', 've', 'got', 'into', 'the', 'car', 'i', 'apos', 've', 'started', 'telling', 'me', 'that', 'i', 'think', 'i', 'apos', 'll', 'have', 'a', 'little', '<UNK>', '.', 'quot', '<UNK>', '<EOS>']
# source:  ['nhưng', 'đó', 'là', 'điều', 'hay', 'nhất', 'có_thể', 'xảy_ra', 'vì', 'đây', 'gọi_là', 'áp_lực', 'đồng_đẳng', 'áp_lực', 'đồng_đẳng', 'đã', 'từng', 'giúp', 'các', 'bệnh_nhân', 'kể', 'từ', 'khi', 'nó', 'được', 'sử_dụng', 'đối_với', 'bệnh', 'béo_phì', 'nó', 'cũng', 'có_thể', 'sử_dụng', 'để', 'các', 'bệnh_nhân', 'bỏ', 'hút', 'thuốc', '.', '<EOS>']
# target:  ['but', 'that', 'apos', 's', 'the', '<UNK>', 'thing', 'that', 'could', 'happen', 'since', 'this', 'is', 'peer', 'pressure', 'peer', 'pressure', 'used', 'to', 'help', 'patients', 'since', 'this', 'could', 'be', 'used', 'for', 'obesity', 'it', 'could', 'be', 'used', 'to', 'stop', 'smoking', 'in', 'patients', '.', '<EOS>']
# predict:  ['but', 'that', 'apos', 's', 'the', 'best', 'thing', 'that', 'can', 'happen', 'because', 'this', 'is', 'called', 'through', 'the', 'patients', 'that', 'have', 'ever', 'been', 'able', 'to', 'help', 'patients', 'tell', 'the', 'patients', 'since', 'it', 'apos', 's', 'been', 'using', 'to', 'obesity', 'it', 'can', 'also', 'be', 'used', 'to', '<UNK>', '<UNK>', '.', '<EOS>']
# source:  ['mặt_khác', 'nó', 'còn', 'được', 'sử_dụng', 'để', 'kéo', 'mọi', 'người', 'ra', 'khỏi', 'ghế', 'ngồi', 'mà', 'cùng_nhau', 'tham_gia', 'một_số', 'trò_chơi', 'nhằm', 'kiểm_soát', 'tốt', 'hơn', 'sức_khoẻ', 'của', 'mình', '.', '<EOS>']
# target:  ['but', 'on', 'the', 'other', 'hand', 'it', 'also', 'could', 'be', 'used', 'to', 'get', 'people', 'from', 'out', 'of', 'their', 'chairs', 'and', 'try', 'to', 'work', 'together', 'in', 'some', 'kind', 'of', '<UNK>', 'activity', 'to', 'get', 'more', 'control', 'of', 'their', 'health', '.', '<EOS>']
# predict:  ['on', 'the', 'other', 'hand', 'it', 'apos', 's', 'used', 'to', 'pull', 'people', 'out', 'of', 'the', 'chair', 'sit', 'together', 'in', 'some', 'of', 'the', 'game', 'to', 'control', 'over', 'the', 'course', 'of', 'their', 'health', '.', '<EOS>']
# source:  ['vào', 'tuần', 'tới', 'một', 'thiết_bị', 'sẽ', 'sớm', 'được', 'ra_mắt', '.', '<EOS>']
# target:  ['as', 'of', 'next', 'week', 'it', 'will', 'soon', 'be', 'available', '.', '<EOS>']
# predict:  ['in', 'week', 'it', 'apos', 's', 'been', 'going', 'to', 'be', 'launched', '.', '<EOS>']
# source:  ['đó', 'là', 'đồng_hồ', 'đo', 'huyết_áp', 'có', 'kết_nối', 'với', 'iphone', 'hay', 'một', 'thứ', 'gì', 'khác', '.', '<EOS>']
# target:  ['there', 'will', 'be', 'this', 'little', 'blood', 'pressure', 'meter', 'connected', 'to', 'an', 'iphone', 'or', 'something', 'or', 'other', '.', '<EOS>']
# predict:  ['it', 'apos', 's', 'about', 'oxygen', '<UNK>', 'nodes', 'with', 'a', 'third', 'of', 'the', 'weight', 'or', 'something', 'else', '.', '<EOS>']
# source:  ['và', 'mọi', 'người', 'sẽ', 'có_thể', 'ở', 'tại_nhà', 'đo', 'huyết_áp', 'của', 'mình', 'rồi', 'gửi', 'dữ_liệu', 'tới', 'bác', 'sỹ', 'thậm_chí', 'có', 'thể', 'chia_sẻ', 'với', 'những', 'người', 'khác', 'chẳng_hạn', 'nó', 'có_giá', 'hơn', 'đô_la', '.', '<EOS>']
# target:  ['and', 'people', 'will', 'be', 'able', 'from', 'their', 'homes', 'to', 'take', 'their', 'blood', 'pressure', 'send', 'it', 'into', 'their', 'doctor', 'and', 'eventually', 'share', 'it', 'with', 'others', 'for', 'instance', 'for', 'over', 'a', 'hundred', 'dollars', '.', '<EOS>']
# predict:  ['and', 'everyone', 'would', 'be', 'at', 'home', 'at', 'his', 'blood', 'rate', 'and', 'send', 'data', 'to', 'doctors', 'even', 'share', 'with', 'others', 'like', 'it', 'cost', 'more', 'than', 'dollars', '.', '<EOS>']
# source:  ['và', 'đây', 'chính', 'là', 'điểm', 'mà', 'các', 'bệnh_nhân', 'có_thể', 'tự', 'kiểm_soát', 'và', 'thu_thập', 'dữ_liệu', 'liên_quan', 'đến', 'sức_khoẻ', 'của', 'mình', 'không', 'chỉ', 'để', 'tự', 'kiểm_soát', 'cho', 'riêng', 'mình', 'làm_chủ', 'tình_thế', 'của', 'mình', 'mà_còn', 'có_thể', 'giúp', 'chúng_ta', 'trong', 'chăm_sóc', 'sức_khoẻ', 'bởi', 'những', 'thách_thức', 'mà', 'chúng_ta', 'phải', 'đối_mặt', 'như', 'tăng', 'chi_phí', 'chăm_sóc', '<EOS>']
# target:  ['and', 'this', 'is', 'the', 'point', 'where', 'patients', 'get', 'into', 'position', 'and', 'can', 'collect', 'not', 'only', 'their', 'own', 'control', 'again', 'be', 'captain', 'of', 'their', 'own', 'ship', 'but', 'also', 'can', 'help', 'us', 'in', 'health', 'care', 'due', 'to', 'the', 'challenges', 'that', 'we', 'face', 'like', 'health', 'care', 'cost', 'explosion', 'doubled', 'demand', 'and', 'things', '<EOS>']
# predict:  ['and', 'these', 'are', 'the', 'patient', 'that', 'patient', 'could', 'control', 'and', 'collect', 'data', 'to', 'contribute', 'to', 'its', 'own', 'health', 'not', 'just', 'to', 'control', 'its', 'own', 'business', 'but', 'also', 'we', 'could', 'also', 'stay', 'in', 'health', 'care', 'by', 'these', 'challenges', 'we', 'face', 'our', 'patient', 'apos', 's', 'not', 'just', 'to', '<EOS>']
# source:  ['làm', 'ra', 'những', 'kỹ_thuật', 'dễ', 'sử_dụng', 'và', 'bắt_đầu', 'với', 'chúng', 'để', 'tạo', 'cảm_giác', 'dễ_chịu', 'cho', 'các', 'bệnh_nhân', 'trong', 'nhóm', '<EOS>']
# target:  ['make', 'techniques', 'that', 'are', 'easy', 'to', 'use', 'and', 'start', 'with', 'this', 'to', 'embrace', 'patients', 'in', 'the', 'team', '.', '<EOS>']
# predict:  ['so', 'these', 'techniques', 'are', 'used', 'and', 'started', 'with', 'them', 'to', 'create', 'a', 'sense', 'of', 'comfort', 'for', 'patients', 'in', 'groups', '.', '<EOS>']
# source:  ['và', 'bạn', 'không', 'chỉ', 'có_thể', 'thực_hiện', 'với', 'những', 'kỹ_thuật', 'kiểu', 'như', 'thế', 'này', 'mà_còn', 'nhờ', 'vào', 'giải_pháp', 'đám_đông', '<UNK>', '<EOS>']
# target:  ['and', 'you', 'can', 'do', 'this', 'with', 'techniques', 'like', 'this', 'but', 'also', 'by', 'crowd', '<UNK>', '.', '<EOS>']
# predict:  ['and', 'you', 'can', 'apos', 't', 'just', 'do', 'with', 'these', 'techniques', 'you', 'can', 'use', 'this', 'technique', 'but', 'also', 'on', 'a', '<UNK>', 'solution', '.', '<EOS>']
# source:  ['và', 'một', 'trong', 'số', 'những', 'điều', 'mà', 'chúng_tôi', 'đã', 'làm', 'tôi', 'xin', 'chia_sẻ', 'với', 'các', 'bạn', 'một', 'đoạn', 'phim', 'nho_nhỏ', '.', '<EOS>']
# target:  ['and', 'one', 'of', 'the', 'things', 'we', 'did', 'i', 'would', 'like', 'to', 'share', 'with', 'you', 'introduced', 'by', 'a', 'little', 'video', '.', '<EOS>']
# predict:  ['and', 'one', 'of', 'the', 'things', 'that', 'we', 'did', 'i', 'was', 'share', 'with', 'you', 'a', 'little', 'video', '.', '<EOS>']
# source:  ['chúng_ta', 'đều', 'có', 'thiết_bị', 'định_vị', 'trong', 'xe', '.', '<EOS>']
# target:  ['we', 'apos', 've', 'all', 'got', '<UNK>', 'controls', 'in', 'our', 'car', '.', '<EOS>']
# predict:  ['we', 'all', 'have', 'a', '<UNK>', 'device', 'in', 'the', 'car', '.', '<EOS>']
# source:  ['chúng_ta', 'thậm_chí', 'còn', 'có', 'nó', 'trong', 'điện_thoại', '.', '<EOS>']
# target:  ['we', 'maybe', 'even', 'have', 'it', 'in', 'our', '<UNK>', '.', '<EOS>']
# predict:  ['we', 'even', 'have', 'it', 'even', 'in', 'the', 'telephone', '.', '<EOS>']
# source:  ['chúng_ta', 'biết', 'chính_xác', 'máy', '<UNK>', 'ở', 'những', 'đâu', 'trong', 'thành_phố', '<UNK>', 'này', '.', '<EOS>']
# target:  ['we', 'know', 'perfectly', 'where', 'all', 'the', '<UNK>', 'are', 'about', 'the', 'city', 'of', '<UNK>', '.', '<EOS>']
# predict:  ['we', 'know', 'exactly', 'the', '<UNK>', 'in', 'the', 'city', 'that', 'we', 'have', 'in', 'the', 'city', '.', '<EOS>']
# source:  ['một', 'thứ', 'khác', 'nữa_là', 'chúng_ta', 'biết', 'tất_cả', 'các', 'trạm', 'xăng', 'ở', 'đâu', '.', '<EOS>']
# target:  ['the', 'other', 'thing', 'is', 'we', 'know', 'where', 'all', 'the', 'gas', 'stations', 'are', '.', '<EOS>']
# predict:  ['one', 'other', 'thing', 'we', 'know', 'all', 'of', 'gas', 'stations', '.', '<EOS>']
# source:  ['và', 'chắc_chắn', 'rằng', 'chúng_ta', 'có_thể', 'tìm_thấy', 'chuỗi', 'cửa_hàng', 'thức_ăn', 'nhanh', '.', '<EOS>']
# target:  ['and', 'sure', 'we', 'could', 'find', 'fast', 'food', 'chains', '.', '<EOS>']
# predict:  ['and', 'surely', 'we', 'can', 'find', 'the', 'food', 'fast', 'food', '.', '<EOS>']

# %%
class Sentence:
    def __init__(self, decoder_hidden, last_idx=SOS_idx, sentence_idxes=[], sentence_scores=[]):
        if(len(sentence_idxes) != len(sentence_scores)):
            raise ValueError("length of indexes and scores should be the same")
        self.decoder_hidden = decoder_hidden
        self.last_idx = last_idx
        self.sentence_idxes =  sentence_idxes
        self.sentence_scores = sentence_scores

    def avgScore(self):
        if len(self.sentence_scores) == 0:
            return -100000
            #raise ValueError("Calculate average score of sentence, but got no word")
        # return mean of sentence_score
        return sum(self.sentence_scores) / len(self.sentence_scores)

    def addTopk(self, topi, topv, decoder_hidden, beam_size):
        #topv = torch.log(topv)
        terminates, sentences = [], []
        for i in range(beam_size):
            if topi[0][i] == EOS_idx:
                terminates.append(([dataset['tgt'].idx2token[idx.item()] for idx in self.sentence_idxes] + ['<EOS>'],
                                   self.avgScore())) # tuple(word_list, score_float
                continue
            idxes = self.sentence_idxes[:] # pass by value
            scores = self.sentence_scores[:] # pass by value
            idxes.append(topi[0][i])
            scores.append(topv[0][i])
            sentences.append(Sentence(decoder_hidden, topi[0][i], idxes, scores))
        return terminates, sentences

    def toWordScore(self):
        words = []
        for i in range(len(self.sentence_idxes)):
            if self.sentence_idxes[i] == EOS_idx:
                words.append('<EOS>')
            else:
                words.append(dataset['tgt'].idx2token[self.sentence_idxes[i].item()])
        if self.sentence_idxes[-1] != EOS_idx:
            words.append('<EOS>')
        return (words, self.avgScore())

def beam_decode(decoder, decoder_hidden, encoder_outputs, beam_size, cur_batch_size, max_length=MAX_SENTENCE_LENGTH):
    terminal_sentences, prev_top_sentences, next_top_sentences = [], [], []
    prev_top_sentences.append(Sentence(decoder_hidden))
    for i in range(max_length):
        for sentence in prev_top_sentences:
            decoder_input = torch.tensor(np.array([[sentence.last_idx]]*cur_batch_size).reshape(1,cur_batch_size),device=device)
            #decoder_input = torch.LongTensor([[sentence.last_idx]])
            #decoder_input = decoder_input.to(device)
            decoder_hidden = sentence.decoder_hidden
            decoder_output, decoder_hidden, _ = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            topv, topi = decoder_output.topk(beam_size)
            term, top = sentence.addTopk(topi, topv, decoder_hidden, beam_size)
            terminal_sentences.extend(term)
            next_top_sentences.extend(top)

        next_top_sentences.sort(key=lambda s: s.avgScore(), reverse=True)
        prev_top_sentences = next_top_sentences[:beam_size]
        next_top_sentences = []

    terminal_sentences += [sentence.toWordScore() for sentence in prev_top_sentences]
    terminal_sentences.sort(key=lambda x: x[1], reverse=True)
    n = 1
    return terminal_sentences[:1]

def evaluate_beam(encoder, decoder, loader, beam_size, max_length=MAX_SENTENCE_LENGTH):
    encoder.eval()
    decoder.eval()
    input_words = []
    target_words = []
    decoded_words = []
    num_count = 0
    for i, (source, translate) in enumerate(loader):
        cur_batch_size = translate.size()[0]
        with torch.no_grad():
            encoder_hidden = encoder.init_hidden(cur_batch_size)
            
        for i in range(cur_batch_size):
            input_words.append([])
            target_words.append([])
        
        for i in range(cur_batch_size):
            for ii in range(source.size()[1]):
                if dataset['src'].idx2token[source.cpu().numpy()[i,ii]] != '<PAD>':
                    input_words[num_count].append(dataset['src'].idx2token[source.cpu().numpy()[i,ii]])
            num_count += 1
        num_count -= cur_batch_size
        for i in range(cur_batch_size):
            for ii in range(translate.size()[1]):
                if dataset['tgt'].idx2token[translate.cpu().numpy()[i,ii]] != '<PAD>':
                    target_words[num_count].append(dataset['tgt'].idx2token[translate.cpu().numpy()[i,ii]])
            num_count += 1
        
        encoder_outputs, encoder_hidden = encoder(source, encoder_hidden)
        
        decoder_hidden = encoder_hidden
        
        decoded_words.append(beam_decode(decoder, decoder_hidden, encoder_outputs, beam_size, cur_batch_size))
        
    pre_list = []
    for i in range(len(decoded_words)):
        pre_list.append("".join([" "+ i if not i.startswith("'") and i not in string.punctuation else i for i in decoded_words[i][0][0]]).strip())
    
    true_list = []
    for true_sentenc in target_words:
        true_list.append("".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in true_sentenc]).strip())
    
    score = sacrebleu.corpus_bleu(pre_list, [true_list])
    print('bleu score: ', score.score)
    
    return decoded_words, target_words, score

# %%
test_dataset2 = LanguageDataset(dataset['src'].test_idx, dataset['tgt'].test_idx)
test_loader2 = torch.utils.data.DataLoader(dataset=test_dataset2,
                                           batch_size=1,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

decoded_words = evaluate_beam(encoder, decoder, test_loader2, beam_size=2, max_length=MAX_SENTENCE_LENGTH)

# %%
from matplotlib import font_manager

fontP = font_manager.FontProperties(fname='/home/zq415/msyh.ttf')

def token_to_index(sentence, token2id):
    indicies_data = []
    for s in sentence:
        tokens = s.split(' ')
        index_list =[token2id[token] if token in token2id else UNK_idx for token in tokens]
        assert len(tokens) == len(index_list)
        indicies_data.append(index_list)
    return indicies_data

def normalizeZh(s):
    #s = s.decode("utf8")
    #s = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）％]+", " ",s)
    s = re.sub( '\s+', ' ', s )
    s = s.strip()
    return s

def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    max_len = max(len(input_sentence.split(' ')), len(output_words))
    attentions = attentions[:max_len+1, :max_len+1]
    plt.matshow(attentions.numpy())
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes .encode('utf-8').decode(
    ax.set_xticklabels([''] + [i for i in input_sentence.split(' ')] +
                       ['<EOS>'], rotation=90,fontproperties=fontP,fontsize=10)
    ax.set_yticklabels([''] + output_words,fontsize=10)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

def evaluate_visulization(encoder, decoder, source = u'Hãy tưởng tượng mảnh đầu tiên: một người đàn ông đốt cháy sự nghiệp cả đời mình'):
    encoder.eval()
    decoder.eval()
    
    norm_source = [normalizeZh(source)]
    source_idx = token_to_index(norm_source, dataset['src'].token2idx)[0]
    source_idx.append(EOS_idx)
    source_idx_pad = np.pad(np.array(source_idx),
                                pad_width=((0,MAX_SENTENCE_LENGTH-len(source_idx))),
                                mode="constant", constant_values=PAD_idx)
    
    source_idx_pad_tensor = torch.from_numpy(np.array(source_idx_pad)).unsqueeze(0).cuda()
    

    cur_batch_size = 1
    
    with torch.no_grad():
        encoder_hidden = encoder.init_hidden(cur_batch_size)

    input_tensor = source_idx_pad_tensor
    
    encoder_output, encoder_hidden = encoder(input_tensor, encoder_hidden)

    
    decoder_input = torch.tensor(np.array([[SOS_idx]]*cur_batch_size).reshape(1,cur_batch_size),device=device)
    decoder_hidden = encoder_hidden

    decoded_words = []
    decoded_att = []
    decoder_attentions = torch.zeros(MAX_SENTENCE_LENGTH, MAX_SENTENCE_LENGTH)
    cur_len = 0
    for i in range(MAX_SENTENCE_LENGTH):
        decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_output)
        decoder_attentions[cur_len] = decoder_attention.data
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()  # detach from history as input
        decoder_input = decoder_input.unsqueeze(0).reshape(1,cur_batch_size)
        
        topi = topi.squeeze().cpu().numpy()
        if cur_len == 0:
            decoded_words.append(dataset['tgt'].idx2token[topi])
            cur_len += 1
        else:
            if decoded_words[cur_len-1] == '<EOS>':
                break
            else:
                decoded_words.append(dataset['tgt'].idx2token[topi])
                cur_len += 1
                
    return decoded_words, source, decoder_attentions

# %%
decoded_words, source, decoder_attentions = evaluate_visulization(encoder,
                                                                  decoder, 
                                                                  source = u'thỉnh thoảng những ý_tưởng này cứ liên_tục xuất_hiện trong suy_nghĩ của chúng_ta rằng chúng rất quan_trọng .')

# %%
showAttention(source, decoded_words, decoder_attentions)
