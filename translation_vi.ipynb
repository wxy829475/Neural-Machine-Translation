# %%
from __future__ import unicode_literals, print_function, division
from io import open
import os
import unicodedata
import pickle
import string
import re
import random
import numpy as np
import pdb
from tqdm import tqdm
from torch.autograd import Variable
import pandas as pd
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
PAD_idx = 0
SOS_idx = 1
EOS_idx = 2
UNK_idx= 3
batch_size = 64
MAX_SENTENCE_LENGTH = 40

# %%
en_pretrained_path = './wiki-news-300d-1M.vec'
vi_pretrained_path = './cc.vi.300.vec'

# %%
train_en = open('iwslt-vi-en/train.tok.en' , encoding='utf-8').read().strip().split('\n')
val_en = open('iwslt-vi-en/dev.tok.en', encoding='utf-8').read().strip().split('\n')
test_en = open('iwslt-vi-en/test.tok.en', encoding='utf-8').read().strip().split('\n')
train_en[:5]
# Out:
# ['Rachel Pike : The science behind a climate headline',
#  'In 4 minutes , atmospheric chemist Rachel Pike provides a glimpse of the massive scientific effort behind the bold headlines on climate change , with her team -- one of thousands who contributed -- taking a risky flight over the rainforest in pursuit of data on a key molecule .',
#  'I &apos;d like to talk to you today about the scale of the scientific effort that goes into making the headlines you see in the paper .',
#  'Headlines that look like this when they have to do with climate change , and headlines that look like this when they have to do with air quality or smog .',
#  'They are both two branches of the same field of atmospheric science .']

# %%
print(len(train_en), len(val_en), len(test_en))
# Out:
# 133317 1268 1553

# %%
train_vi = open('iwslt-vi-en/train.tok.vi', encoding='utf-8').read().strip().split('\n')
val_vi = open('iwslt-vi-en/dev.tok.vi', encoding='utf-8').read().strip().split('\n')
test_vi = open('iwslt-vi-en/test.tok.vi', encoding='utf-8').read().strip().split('\n')
train_vi[:5]
# Out:
# ['Khoa_học đằng_sau một tiêu_đề về khí_hậu',
#  'Trong 4 phút , chuyên_gia hoá_học khí_quyển Rachel Pike giới_thiệu sơ_lược về những nỗ_lực khoa_học miệt_mài đằng_sau những tiêu_đề táo_bạo về biến_đổi khí_hậu , cùng với đoàn nghiên_cứu của mình - - hàng ngàn người đã cống_hiến cho dự_án này - - một chuyến bay mạo_hiểm qua rừng_già để tìm_kiếm thông_tin về một phân_tử then_chốt .',
#  'Tôi muốn cho các bạn biết về sự to_lớn của những nỗ_lực khoa_học đã góp_phần làm_nên các dòng tít bạn thường thấy trên báo .',
#  'Có những dòng trông như thế_này khi bàn về biến_đổi khí_hậu , và như thế_này khi nói về chất_lượng không_khí hay khói bụi .',
#  'Cả hai đều là một nhánh của cùng một lĩnh_vực trong ngành khoa_học khí_quyển .']

# %% [markdown]
# ### Transform data list to dataframe

# %%
def to_dataframe(en, ch, len_raio=0.95):
    en_len_list, ch_len_list = [], []
    for en_sample, ch_sample in zip(en, ch):
        en_len_list.append(len(en_sample))
        ch_len_list.append(len(ch_sample))
    df = pd.DataFrame({'en': en, 
                       'en_len': en_len_list,
                       'ch': ch,
                       'ch_len': ch_len_list
                      })
    en_len_at_ratio = sorted(en_len_list)[int(len_raio*len(en_len_list))]
    ch_len_at_ratio = sorted(ch_len_list)[int(len_raio*len(ch_len_list))]
    print ("EN length @{}: {}, CH length @{}: {}".format(len_raio, en_len_at_ratio, len_raio, ch_len_at_ratio))
    return df, max(en_len_at_ratio, ch_len_at_ratio)

# %% [markdown]
# # Data Preprocessing

# %%
def load_vectors(fname):
    """
    load the pretrained word embeddings
    param fname: the path the to the word embedding
    return: 
            a dictionary of the {word: embedding}
    """
    fin = open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    for line in tqdm(fin):
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = list(map(float, tokens[1:]))
    return data

# %%
# Get the vocabulary based on the training data
from collections import Counter

def get_vocabulary(data, VOCABULARY_SIZE=30000):
    
    en_vocab, ch_vocab = [], []
    for idx, row in data.iterrows():
        en_vocab += row['en'].split()
        ch_vocab += row['ch'].split()
    en_token_counter = Counter(en_vocab)
    ch_token_counter = Counter(ch_vocab)
    print ("Number of en words: {}, ch words: {}".format(len(en_token_counter), len(ch_token_counter)))
    en_word, _ = zip(*en_token_counter.most_common(VOCABULARY_SIZE))
    en_id2token = ['<PAD>','<SOS>','<EOS>','<UNK>'] + list(en_word)
    en_token2id = dict(zip(en_id2token, np.arange(len(en_id2token))))
    ch_word, _ = zip(*ch_token_counter.most_common(VOCABULARY_SIZE))
    ch_id2token = ['<PAD>','<SOS>','<EOS>','<UNK>'] + list(ch_word)
    ch_token2id = dict(zip(ch_id2token, np.arange(len(ch_id2token))))
    return en_id2token, en_token2id, ch_id2token, ch_token2id

# %%
def get_embedding_weights(whole_vec, id2token):
    """
    get the embeddings based on the word, create the embedding matrix
    param whole_vec: the dictionary of pretrained embeddings
    param id2token: the whole vocabulary
    return:
            embedding matrix
    """
    weight = np.zeros((len(id2token), len(whole_vec['sky'])))
    mask = np.zeros((len(id2token)))
    for i, word in enumerate(id2token[1:]):
        if i<3:
            weight[i+1] = np.array(np.random.randn(300))
        elif word in whole_vec.keys():
            weight[i+1] = np.array(whole_vec[word])
        else:
            weight[i+1] = weight[3]
            mask[i+1] = 1
            print ("Out of vocabulary word: ", word)   
    return weight, mask

# %%
def load_pickle(data_path, callback, *callback_args):
    """
    Create huge file with the callback function if not exist, otherwise load directly
    param data_path: the path of the load file if exist, otherwise the path to store the created file
    param callback: the function to generate the data if not exist
    param callback_args: the argument for the callback:
    return: 
            the data, either loaded or created by callback
    """

    data_path = data_path
    if os.path.isfile(data_path):
        print ('File exists, load from path...')
        data = pickle.load(open(data_path, 'rb'))
    else:
        print ('File not exists, creating...')
        data = callback(*callback_args)
        pickle.dump(data, open(data_path, 'wb'))
    return data

# %%
eng_pretrained = load_pickle('en_pretrained.pkl', load_vectors, en_pretrained_path)
vi_pretrained = load_pickle('vi_pretrained.pkl', load_vectors, vi_pretrained_path)
# Out:
# 0it [00:00, ?it/s]
# File not exists, creating...
# 999994it [01:42, 9775.19it/s]
# 235it [00:00, 2347.11it/s]
# File not exists, creating...
# 2000000it [03:50, 8663.69it/s]

# %%
def normalizeVi(s):
    s = s.lower().strip()
    s =re.sub(r"[-()\"#/@;:<>{}`+=~|,]", "", s)
    s = re.sub(r"[0-9]","",s)
    s = re.sub( '\s+', ' ', s)
    return s

# %%
#Turn a Unicode string to plain ASCII
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s =' '.join([word.replace('&apos',' ') for word in s.split()])
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
def token_to_index(sentence, token2id):
    indicies_data = []
    for s in sentence:
        tokens = s.split(' ')
        index_list =[token2id[token] if token in token2id else UNK_idx for token in tokens]
        assert len(tokens) == len(index_list)
        indicies_data.append(index_list)
    return indicies_data

# %% [markdown]
# ## Enlgish

# %%
normalize_train_en = [normalizeString(s) for s in train_en]
normalize_val_en = [normalizeString(s) for s in val_en]
normalize_test_en = [normalizeString(s) for s in test_en]
normalize_train_en[:5]
# Out:
# ['rachel pike the science behind a climate headline',
#  'in minutes atmospheric chemist rachel pike provides a glimpse of the massive scientific effort behind the bold headlines on climate change with her team one of thousands who contributed taking a risky flight over the rainforest in pursuit of data on a key molecule .',
#  'i d like to talk to you today about the scale of the scientific effort that goes into making the headlines you see in the paper .',
#  'headlines that look like this when they have to do with climate change and headlines that look like this when they have to do with air quality or smog .',
#  'they are both two branches of the same field of atmospheric science .']

# %% [markdown]
# ## Vietnamese

# %%
normalize_train_vi = [normalizeVi(s) for s in train_vi]
normalize_val_vi = [normalizeVi(s) for s in val_vi]
normalize_test_vi = [normalizeVi(s) for s in test_vi]
normalize_train_vi[0]
# Out:
# 'khoa_học đằng_sau một tiêu_đề về khí_hậu'

# %%
train_df, pad_len = to_dataframe(normalize_train_en, normalize_train_vi)
val_df, _ = to_dataframe(normalize_val_en, normalize_val_vi)
test_df, _ = to_dataframe(normalize_test_en, normalize_test_vi)
# Out:
# EN length @0.95: 228, CH length @0.95: 235
# EN length @0.95: 230, CH length @0.95: 238
# EN length @0.95: 187, CH length @0.95: 192

# %%
en_id2token, en_token2id, vi_id2token, vi_token2id = get_vocabulary(train_df)
# Out:
# Number of en words: 41266, ch words: 33913

# %%
train_en_indicies = token_to_index(normalize_train_en, en_token2id)
val_en_indicies = token_to_index(normalize_val_en, en_token2id)
test_en_indicies = token_to_index(normalize_test_en, en_token2id)

# %%
train_vi_indicies = token_to_index(normalize_train_vi, vi_token2id)
val_vi_indicies = token_to_index(normalize_val_vi, vi_token2id)
test_vi_indicies = token_to_index(normalize_test_vi, vi_token2id)

# %%
train_vi_indicies[0]
# Out:
# [183, 1259, 8, 3129, 29, 807]

# %%
print ('-'*100)
eng_embedding, _ = load_pickle('eng_embedding_3.pkl', get_embedding_weights, eng_pretrained, en_id2token)

print ('-'*100)
vi_embedding, _ = load_pickle('vi_embedding_3.pkl', get_embedding_weights, vi_pretrained, vi_id2token)
# Out:
# ----------------------------------------------------------------------------------------------------
# File not exists, creating...
# Out of vocabulary word:  norden
# Out of vocabulary word:  rosling
# Out of vocabulary word:  tedtalks
# Out of vocabulary word:  tedtalk
# Out of vocabulary word:  teszler
# Out of vocabulary word:  tedglobal
# Out of vocabulary word:  ushahidi
# Out of vocabulary word:  tedsters
# Out of vocabulary word:  tedx
# Out of vocabulary word:  lesters
# Out of vocabulary word:  lakota
# Out of vocabulary word:  nanopatch
# Out of vocabulary word:  .q
# Out of vocabulary word:  kiribati
# Out of vocabulary word:  sobule
# Out of vocabulary word:  lesterland
# Out of vocabulary word:  tedmed
# Out of vocabulary word:  foxo
# Out of vocabulary word:  rsw
# Out of vocabulary word:  tedwomen
# Out of vocabulary word:  gando
# Out of vocabulary word:  gehry
# Out of vocabulary word:  kibera
# Out of vocabulary word:  .j
# Out of vocabulary word:  thula
# Out of vocabulary word:  tarahumara
# Out of vocabulary word:  fmri
# Out of vocabulary word:  darpa
# Out of vocabulary word:  rezero
# Out of vocabulary word:  broadmoor
# Out of vocabulary word:  bageye
# Out of vocabulary word:  tedster
# Out of vocabulary word:  schwarzschild
# Out of vocabulary word:  gapminder
# Out of vocabulary word:  accenture
# Out of vocabulary word:  odysseus
# Out of vocabulary word:  zipcar
# Out of vocabulary word:  incra
# Out of vocabulary word:  sheryl
# Out of vocabulary word:  rockett
# Out of vocabulary word:  gayla
# Out of vocabulary word:  esg
# Out of vocabulary word:  zetas
# Out of vocabulary word:  faiza
# Out of vocabulary word:  eames
# Out of vocabulary word:  clonie
# Out of vocabulary word:  najmuddin
# Out of vocabulary word:  robicsek
# Out of vocabulary word:  micrornas
# Out of vocabulary word:  ariely
# Out of vocabulary word:  kiteflyer
# Out of vocabulary word:  mcchrystal
# Out of vocabulary word:  whitacre
# Out of vocabulary word:  pranav
# Out of vocabulary word:  marduk
# Out of vocabulary word:  sagmeister
# Out of vocabulary word:  budrus
# Out of vocabulary word:  enceladus
# Out of vocabulary word:  rossy
# Out of vocabulary word:  derartu
# Out of vocabulary word:  janine
# Out of vocabulary word:  duolingo
# Out of vocabulary word:  gowanus
# Out of vocabulary word:  hirshhorn
# Out of vocabulary word:  kaluza
# Out of vocabulary word:  cargill
# Out of vocabulary word:  giffords
# Out of vocabulary word:  mcgonigal
# Out of vocabulary word:  gladwell
# Out of vocabulary word:  myhrvold
# Out of vocabulary word:  matthieu
# Out of vocabulary word:  pauling
# Out of vocabulary word:  electrolux
# Out of vocabulary word:  shirky
# Out of vocabulary word:  laramie
# Out of vocabulary word:  gymnosophist
# Out of vocabulary word:  maslow
# Out of vocabulary word:  hurtigruten
# Out of vocabulary word:  hany
# Out of vocabulary word:  unilever
# Out of vocabulary word:  drori
# Out of vocabulary word:  allosphere
# Out of vocabulary word:  aicha
# Out of vocabulary word:  mcluhan
# Out of vocabulary word:  chimborazo
# Out of vocabulary word:  decompiculture
# Out of vocabulary word:  kipp
# Out of vocabulary word:  denisovans
# Out of vocabulary word:  ornish
# Out of vocabulary word:  torosaurus
# Out of vocabulary word:  usain
# Out of vocabulary word:  greenville
# Out of vocabulary word:  resnick
# Out of vocabulary word:  licklider
# Out of vocabulary word:  shreddies
# Out of vocabulary word:  curitiba
# Out of vocabulary word:  tahltan
# Out of vocabulary word:  krosoczka
# Out of vocabulary word:  makoko
# Out of vocabulary word:  berners
# Out of vocabulary word:  michoacan
# Out of vocabulary word:  microrna
# Out of vocabulary word:  quixote
# Out of vocabulary word:  postsecret
# Out of vocabulary word:  sisyphus
# Out of vocabulary word:  mizzone
# Out of vocabulary word:  dietrich
# Out of vocabulary word:  mcmurdo
# Out of vocabulary word:  pmtct
# Out of vocabulary word:  oldenburg
# Out of vocabulary word:  meyerowitz
# Out of vocabulary word:  dennett
# Out of vocabulary word:  kuznets
# Out of vocabulary word:  seligman
# Out of vocabulary word:  sunitha
# Out of vocabulary word:  atala
# Out of vocabulary word:  feki
# Out of vocabulary word:  luria
# Out of vocabulary word:  sivers
# Out of vocabulary word:  ecosia
# Out of vocabulary word:  tncs
# Out of vocabulary word:  cousteau
# Out of vocabulary word:  dracorex
# Out of vocabulary word:  shephelah
# Out of vocabulary word:  worldchanging
# Out of vocabulary word:  burkina
# Out of vocabulary word:  kurzweil
# Out of vocabulary word:  prospera
# Out of vocabulary word:  parikrma
# Out of vocabulary word:  dereck
# Out of vocabulary word:  dmca
# Out of vocabulary word:  durkheim
# Out of vocabulary word:  ladenism
# Out of vocabulary word:  swaptree
# Out of vocabulary word:  alisa
# Out of vocabulary word:  erez
# Out of vocabulary word:  haidt
# Out of vocabulary word:  barbaria
# Out of vocabulary word:  sandberg
# Out of vocabulary word:  beijerinck
# Out of vocabulary word:  wofford
# Out of vocabulary word:  toraja
# Out of vocabulary word:  engelbart
# Out of vocabulary word:  sughar
# Out of vocabulary word:  khadija
# Out of vocabulary word:  carrocas
# Out of vocabulary word:  democracyos
# Out of vocabulary word:  tonya
# Out of vocabulary word:  hasbro
# Out of vocabulary word:  austen
# Out of vocabulary word:  mildred
# Out of vocabulary word:  joplin
# Out of vocabulary word:  attenborough
# Out of vocabulary word:  starck
# Out of vocabulary word:  brene
# Out of vocabulary word:  sixthsense
# Out of vocabulary word:  hosni
# Out of vocabulary word:  crimer
# Out of vocabulary word:  mcnuggets
# Out of vocabulary word:  gever
# Out of vocabulary word:  tulley
# Out of vocabulary word:  lothar
# Out of vocabulary word:  meggendorfer
# Out of vocabulary word:  coleridge
# Out of vocabulary word:  enriquez
# Out of vocabulary word:  hatzalah
# Out of vocabulary word:  risd
# Out of vocabulary word:  herbie
# Out of vocabulary word:  jurvetson
# Out of vocabulary word:  kohn
# Out of vocabulary word:  chekhov
# Out of vocabulary word:  cronin
# Out of vocabulary word:  ghraib
# Out of vocabulary word:  wurman
# Out of vocabulary word:  frans
# Out of vocabulary word:  barricelli
# Out of vocabulary word:  shereen
# Out of vocabulary word:  drybath
# Out of vocabulary word:  wangari
# Out of vocabulary word:  bolte
# Out of vocabulary word:  vermeer
# Out of vocabulary word:  yunus
# Out of vocabulary word:  grameen
# Out of vocabulary word:  hazleton
# Out of vocabulary word:  biofabrication
# Out of vocabulary word:  gandhian
# Out of vocabulary word:  yochai
# Out of vocabulary word:  shbab
# Out of vocabulary word:  claron
# Out of vocabulary word:  avelile
# Out of vocabulary word:  svalbard
# Out of vocabulary word:  koolhaas
# Out of vocabulary word:  moskowitz
# Out of vocabulary word:  kamkwamba
# Out of vocabulary word:  shackleton
# Out of vocabulary word:  ashdown
# Out of vocabulary word:  elyn
# Out of vocabulary word:  autodesk
# Out of vocabulary word:  pallotta
# Out of vocabulary word:  xdr
# Out of vocabulary word:  kasparov
# Out of vocabulary word:  pierson
# Out of vocabulary word:  karmapa
# Out of vocabulary word:  athabasca
# Out of vocabulary word:  dharamsala
# Out of vocabulary word:  dunlap
# Out of vocabulary word:  grier
# Out of vocabulary word:  zullinger
# Out of vocabulary word:  blakley
# Out of vocabulary word:  napot
# Out of vocabulary word:  bartok
# Out of vocabulary word:  milliken
# Out of vocabulary word:  toonchi
# Out of vocabulary word:  jeanny
# Out of vocabulary word:  torajans
# Out of vocabulary word:  zabbaleen
# Out of vocabulary word:  igf
# Out of vocabulary word:  carrillo
# Out of vocabulary word:  blackawton
# Out of vocabulary word:  klee
# Out of vocabulary word:  goering
# Out of vocabulary word:  meegeren
# Out of vocabulary word:  capgras
# Out of vocabulary word:  apophis
# Out of vocabulary word:  schlaug
# Out of vocabulary word:  carroca
# Out of vocabulary word:  filmclub
# Out of vocabulary word:  genspace
# Out of vocabulary word:  diybio
# Out of vocabulary word:  sitopia
# Out of vocabulary word:  negroponte
# Out of vocabulary word:  schulz
# Out of vocabulary word:  belshazzar
# Out of vocabulary word:  zappos
# Out of vocabulary word:  ghonim
# Out of vocabulary word:  hippocrates
# Out of vocabulary word:  guizhou
# Out of vocabulary word:  mckean
# Out of vocabulary word:  synecdochically
# Out of vocabulary word:  maeda
# Out of vocabulary word:  whewell
# Out of vocabulary word:  lessig
# Out of vocabulary word:  widder
# Out of vocabulary word:  minsky
# Out of vocabulary word:  lindbergh
# Out of vocabulary word:  steffen
# Out of vocabulary word:  ensler
# Out of vocabulary word:  giacometti
# Out of vocabulary word:  wislawa
# Out of vocabulary word:  szymborska
# Out of vocabulary word:  renny
# Out of vocabulary word:  gleeson
# Out of vocabulary word:  paravicini
# Out of vocabulary word:  xiaoping
# Out of vocabulary word:  hockenberry
# Out of vocabulary word:  batiuk
# Out of vocabulary word:  maathai
# Out of vocabulary word:  detroiters
# Out of vocabulary word:  atacama
# Out of vocabulary word:  malthus
# Out of vocabulary word:  .mt
# Out of vocabulary word:  jansky
# Out of vocabulary word:  pierpont
# Out of vocabulary word:  buckminster
# Out of vocabulary word:  jehane
# Out of vocabulary word:  noujaim
# Out of vocabulary word:  berkley
# Out of vocabulary word:  sandel
# Out of vocabulary word:  berlow
# Out of vocabulary word:  gourley
# Out of vocabulary word:  novocure
# Out of vocabulary word:  gbm
# Out of vocabulary word:  mris
# Out of vocabulary word:  jetman
# Out of vocabulary word:  merckx
# Out of vocabulary word:  stygimoloch
# Out of vocabulary word:  reuther
# Out of vocabulary word:  smits
# Out of vocabulary word:  unaids
# Out of vocabulary word:  mankoff
# Out of vocabulary word:  zimbardo
# Out of vocabulary word:  thrun
# Out of vocabulary word:  legadema
# Out of vocabulary word:  hexene
# Out of vocabulary word:  lxd
# Out of vocabulary word:  myesha
# Out of vocabulary word:  poupon
# Out of vocabulary word:  bennington
# Out of vocabulary word:  wujec
# Out of vocabulary word:  wikihouse
# Out of vocabulary word:  kuiper
# Out of vocabulary word:  ekg
# Out of vocabulary word:  kwabena
# Out of vocabulary word:  christakis
# Out of vocabulary word:  mapendo
# Out of vocabulary word:  huaorani
# Out of vocabulary word:  ikigai
# Out of vocabulary word:  tibbits
# Out of vocabulary word:  galvani
# Out of vocabulary word:  susana
# Out of vocabulary word:  forer
# Out of vocabulary word:  vanier
# Out of vocabulary word:  osorio
# Out of vocabulary word:  okolloh
# Out of vocabulary word:  tombo
# Out of vocabulary word:  taniyama
# Out of vocabulary word:  alisch
# Out of vocabulary word:  brck
# Out of vocabulary word:  bhutanese
# Out of vocabulary word:  gnh
# Out of vocabulary word:  angeline
# Out of vocabulary word:  sanccob
# Out of vocabulary word:  chagall
# Out of vocabulary word:  lamanites
# Out of vocabulary word:  bueller
# Out of vocabulary word:  benefield
# Out of vocabulary word:  achill
# Out of vocabulary word:  khalida
# Out of vocabulary word:  brohi
# Out of vocabulary word:  vasconcelos
# Out of vocabulary word:  lowline
# Out of vocabulary word:  ommm
# Out of vocabulary word:  mellody
# Out of vocabulary word:  kpis
# Out of vocabulary word:  biohacker
# Out of vocabulary word:  geert
# Out of vocabulary word:  chatrou
# Out of vocabulary word:  eddi
# Out of vocabulary word:  muruganantham
# Out of vocabulary word:  bionicles
# Out of vocabulary word:  hodgman
# Out of vocabulary word:  pratury
# Out of vocabulary word:  rowdie
# Out of vocabulary word:  ballbot
# Out of vocabulary word:  tedindia
# Out of vocabulary word:  rosalie
# Out of vocabulary word:  tanzanian
# Out of vocabulary word:  rachelle
# Out of vocabulary word:  garniez
# Out of vocabulary word:  knopf
# Out of vocabulary word:  wafi
# Out of vocabulary word:  zacarias
# Out of vocabulary word:  mikko
# Out of vocabulary word:  hypponen
# Out of vocabulary word:  godin
# Out of vocabulary word:  safeway
# Out of vocabulary word:  herschel
# Out of vocabulary word:  vusi
# Out of vocabulary word:  nabokov
# Out of vocabulary word:  barcia
# Out of vocabulary word:  hillis
# Out of vocabulary word:  larsson
# Out of vocabulary word:  karolinska
# Out of vocabulary word:  elysees
# Out of vocabulary word:  gagarin
# Out of vocabulary word:  tilson
# Out of vocabulary word:  ricard
# Out of vocabulary word:  blaise
# Out of vocabulary word:  jaclyn
# Out of vocabulary word:  bigelow
# Out of vocabulary word:  kohler
# Out of vocabulary word:  ockelford
# Out of vocabulary word:  orville
# Out of vocabulary word:  dishman
# Out of vocabulary word:  robocup
# Out of vocabulary word:  baraniuk
# Out of vocabulary word:  reykjavik
# Out of vocabulary word:  mairead
# Out of vocabulary word:  weiffenbach
# Out of vocabulary word:  ayelet
# Out of vocabulary word:  foxp
# Out of vocabulary word:  wyss
# Out of vocabulary word:  paley
# Out of vocabulary word:  mowgli
# Out of vocabulary word:  nyad
# Out of vocabulary word:  nachtwey
# Out of vocabulary word:  camfed
# Out of vocabulary word:  wernicke
# Out of vocabulary word:  ferriss
# Out of vocabulary word:  ghemawat
# Out of vocabulary word:  globaloney
# Out of vocabulary word:  jobrani
# Out of vocabulary word:  lovegrove
# Out of vocabulary word:  vishna
# Out of vocabulary word:  garone
# Out of vocabulary word:  sinek
# Out of vocabulary word:  ostrow
# Out of vocabulary word:  tzvika
# Out of vocabulary word:  libeskind
# Out of vocabulary word:  brynjolfsson
# Out of vocabulary word:  pranitha
# Out of vocabulary word:  dodi
# Out of vocabulary word:  grandin
# Out of vocabulary word:  mashelkar
# Out of vocabulary word:  leadbeater
# Out of vocabulary word:  debora
# Out of vocabulary word:  pachycephalosaurus
# Out of vocabulary word:  biophony
# Out of vocabulary word:  aparna
# Out of vocabulary word:  soren
# Out of vocabulary word:  damasio
# Out of vocabulary word:  verinsky
# Out of vocabulary word:  sharmeen
# Out of vocabulary word:  liespotters
# Out of vocabulary word:  mckinsey
# Out of vocabulary word:  parusharam
# Out of vocabulary word:  joubert
# Out of vocabulary word:  recaptcha
# Out of vocabulary word:  heatherwick
# Out of vocabulary word:  duflo
# Out of vocabulary word:  saima
# Out of vocabulary word:  geraldine
# Out of vocabulary word:  depthx
# Out of vocabulary word:  tandon
# Out of vocabulary word:  superbetter
# Out of vocabulary word:  yann
# Out of vocabulary word:  maasai
# Out of vocabulary word:  saks
# Out of vocabulary word:  beatjazz
# Out of vocabulary word:  umbc
# Out of vocabulary word:  thwaites
# Out of vocabulary word:  eliasson
# Out of vocabulary word:  bamiyan
# Out of vocabulary word:  cyark
# Out of vocabulary word:  merz
# Out of vocabulary word:  yentl
# Out of vocabulary word:  juanderson
# Out of vocabulary word:  charmian
# Out of vocabulary word:  etete
# Out of vocabulary word:  nicklen
# Out of vocabulary word:  bolin
# Out of vocabulary word:  scalia
# Out of vocabulary word:  teeb
# Out of vocabulary word:  limor
# Out of vocabulary word:  rovs
# Out of vocabulary word:  pshoo
# Out of vocabulary word:  ganson
# Out of vocabulary word:  anatomage
# Out of vocabulary word:  theodoor
# Out of vocabulary word:  velde
# Out of vocabulary word:  upsuck
# Out of vocabulary word:  heffernan
# Out of vocabulary word:  skylar
# Out of vocabulary word:  hetain
# Out of vocabulary word:  keats
# Out of vocabulary word:  abrahams
# Out of vocabulary word:  santee
# Out of vocabulary word:  sandor
# Out of vocabulary word:  pacak
# Out of vocabulary word:  siyathemba
# Out of vocabulary word:  birke
# Out of vocabulary word:  waal
# Out of vocabulary word:  leyla
# Out of vocabulary word:  markham
# Out of vocabulary word:  melies
# Out of vocabulary word:  krista
# Out of vocabulary word:  jinsop
# Out of vocabulary word:  rupal
# Out of vocabulary word:  rony
# Out of vocabulary word:  deqo
# Out of vocabulary word:  homaro
# Out of vocabulary word:  michaela
# Out of vocabulary word:  magellanic
# Out of vocabulary word:  aremeyaw
# Out of vocabulary word:  shaffi
# Out of vocabulary word:  apollonian
# Out of vocabulary word:  guttenberg
# Out of vocabulary word:  sakkaf
# Out of vocabulary word:  cymatic
# Out of vocabulary word:  saxe
# Out of vocabulary word:  strudwick
# Out of vocabulary word:  frieda
# Out of vocabulary word:  kandinsky
# Out of vocabulary word:  zizzing
# Out of vocabulary word:  vannevar
# Out of vocabulary word:  agarikon
# Out of vocabulary word:  juilliard
# Out of vocabulary word:  britlin
# Out of vocabulary word:  waterhouse
# Out of vocabulary word:  wasichu
# Out of vocabulary word:  hutchison
# Out of vocabulary word:  siza
# Out of vocabulary word:  nephites
# Out of vocabulary word:  longden
# Out of vocabulary word:  aidg
# Out of vocabulary word:  samboja
# Out of vocabulary word:  lestari
# Out of vocabulary word:  shermer
# Out of vocabulary word:  sangu
# Out of vocabulary word:  danone
# Out of vocabulary word:  aravena
# Out of vocabulary word:  bercken
# Out of vocabulary word:  summerwear
# Out of vocabulary word:  talithia
# Out of vocabulary word:  tajfel
# Out of vocabulary word:  swenson
# Out of vocabulary word:  munroe
# Out of vocabulary word:  kalenjin
# Out of vocabulary word:  kilian
# Out of vocabulary word:  emdin
# Out of vocabulary word:  swartz
# Out of vocabulary word:  perony
# Out of vocabulary word:  complicatedness
# Out of vocabulary word:  schindler
# Out of vocabulary word:  elizabethan
# Out of vocabulary word:  cbgb
# Out of vocabulary word:  mahler
# Out of vocabulary word:  ronny
# Out of vocabulary word:  edry
# Out of vocabulary word:  michal
# Out of vocabulary word:  arunachalam
# Out of vocabulary word:  wmap
# Out of vocabulary word:  hogwart
# Out of vocabulary word:  jungian
# Out of vocabulary word:  octavio
# Out of vocabulary word:  cambodians
# Out of vocabulary word:  perel
# Out of vocabulary word:  proust
# Out of vocabulary word:  nalini
# Out of vocabulary word:  seuss
# Out of vocabulary word:  wozniak
# Out of vocabulary word:  olpc
# Out of vocabulary word:  nicolelis
# Out of vocabulary word:  ecorock
# Out of vocabulary word:  shigeru
# Out of vocabulary word:  pompidou
# Out of vocabulary word:  nebuchadnezzar
# Out of vocabulary word:  caledonian
# Out of vocabulary word:  eggers
# Out of vocabulary word:  howey
# Out of vocabulary word:  rahm
# Out of vocabulary word:  jayant
# Out of vocabulary word:  arusha
# Out of vocabulary word:  brahimi
# Out of vocabulary word:  spack
# Out of vocabulary word:  shriram
# Out of vocabulary word:  amundsen
# Out of vocabulary word:  mullis
# Out of vocabulary word:  matreyek
# Out of vocabulary word:  klin
# Out of vocabulary word:  moussaoui
# Out of vocabulary word:  alhurra
# Out of vocabulary word:  boyden
# Out of vocabulary word:  gerhard
# Out of vocabulary word:  ueli
# Out of vocabulary word:  gegenschatz
# Out of vocabulary word:  freeflying
# Out of vocabulary word:  skysurfing
# Out of vocabulary word:  copacabana
# Out of vocabulary word:  tirana
# Out of vocabulary word:  dictionaried
# Out of vocabulary word:  muniz
# Out of vocabulary word:  killingsworth
# Out of vocabulary word:  ambucycles
# Out of vocabulary word:  wallajeh
# Out of vocabulary word:  arby
# Out of vocabulary word:  pisani
# Out of vocabulary word:  capetown
# Out of vocabulary word:  emiliano
# Out of vocabulary word:  glennie
# Out of vocabulary word:  tedxusc
# Out of vocabulary word:  schacht
# Out of vocabulary word:  inventables
# Out of vocabulary word:  chiat
# Out of vocabulary word:  eisner
# Out of vocabulary word:  appalachians
# Out of vocabulary word:  lascaux
# Out of vocabulary word:  canaletto
# Out of vocabulary word:  kowan
# Out of vocabulary word:  insideoutproject
# Out of vocabulary word:  providencia
# Out of vocabulary word:  monrovia
# Out of vocabulary word:  tedxsummit
# Out of vocabulary word:  shalan
# Out of vocabulary word:  neshat
# Out of vocabulary word:  vanengelsdorp
# Out of vocabulary word:  wonderbread
# Out of vocabulary word:  ndd
# Out of vocabulary word:  bukavu
# Out of vocabulary word:  faron
# Out of vocabulary word:  leibniz
# Out of vocabulary word:  markoff
# Out of vocabulary word:  hiroshi
# Out of vocabulary word:  ishii
# Out of vocabulary word:  futured
# Out of vocabulary word:  usaid
# Out of vocabulary word:  disenthrall
# Out of vocabulary word:  kimbo
# Out of vocabulary word:  southam
# Out of vocabulary word:  schelling
# Out of vocabulary word:  interaxon
# Out of vocabulary word:  safdie
# Out of vocabulary word:  romela
# Out of vocabulary word:  corbusier
# Out of vocabulary word:  arup
# Out of vocabulary word:  zeisel
# Out of vocabulary word:  manspace
# Out of vocabulary word:  manspaces
# Out of vocabulary word:  tillett
# Out of vocabulary word:  steindl
# Out of vocabulary word:  schizophonia
# Out of vocabulary word:  ananthaswamy
# Out of vocabulary word:  petrus
# Out of vocabulary word:  tribeca
# Out of vocabulary word:  penzias
# Out of vocabulary word:  mcgrew
# Out of vocabulary word:  skoll
# Out of vocabulary word:  kilimanjaro
# Out of vocabulary word:  agusta
# Out of vocabulary word:  justicemakers
# Out of vocabulary word:  schaefer
# Out of vocabulary word:  missmahl
# Out of vocabulary word:  maezza
# Out of vocabulary word:  pagel
# Out of vocabulary word:  svante
# Out of vocabulary word:  vaclav
# Out of vocabulary word:  hawkes
# Out of vocabulary word:  khrushchev
# Out of vocabulary word:  zedong
# Out of vocabulary word:  sonicate
# Out of vocabulary word:  quyen
# Out of vocabulary word:  nirenberg
# Out of vocabulary word:  gopnik
# Out of vocabulary word:  cristine
# Out of vocabulary word:  demetrios
# Out of vocabulary word:  kymaerica
# Out of vocabulary word:  cranbrook
# Out of vocabulary word:  glattfelder
# Out of vocabulary word:  geary
# Out of vocabulary word:  deavere
# Out of vocabulary word:  perasa
# Out of vocabulary word:  mulgan
# Out of vocabulary word:  dodson
# Out of vocabulary word:  anatotitan
# Out of vocabulary word:  nanotyrannus
# Out of vocabulary word:  buechley
# Out of vocabulary word:  tedyouth
# Out of vocabulary word:  pors
# Out of vocabulary word:  hofstadter
# Out of vocabulary word:  pepfar
# Out of vocabulary word:  diffee
# Out of vocabulary word:  piazzolla
# Out of vocabulary word:  mathemagician
# Out of vocabulary word:  tapscott
# Out of vocabulary word:  mcdougall
# Out of vocabulary word:  hazlewood
# Out of vocabulary word:  paraorchestra
# Out of vocabulary word:  khayelitsha
# Out of vocabulary word:  obaid
# Out of vocabulary word:  chinoy
# Out of vocabulary word:  sadik
# Out of vocabulary word:  liespotting
# Out of vocabulary word:  liespotter
# Out of vocabulary word:  mirren
# Out of vocabulary word:  atlassian
# Out of vocabulary word:  taymor
# Out of vocabulary word:  frida
# Out of vocabulary word:  caliban
# Out of vocabulary word:  asner
# Out of vocabulary word:  sherwin
# Out of vocabulary word:  mallifert
# Out of vocabulary word:  terkel
# Out of vocabulary word:  koblin
# Out of vocabulary word:  yorke
# Out of vocabulary word:  alessandro
# Out of vocabulary word:  ashburn
# Out of vocabulary word:  bma
# Out of vocabulary word:  shapshak
# Out of vocabulary word:  dolos
# Out of vocabulary word:  uncopyable
# Out of vocabulary word:  lawler
# Out of vocabulary word:  maersk
# Out of vocabulary word:  livermore
# Out of vocabulary word:  bolinsky
# Out of vocabulary word:  aurasma
# Out of vocabulary word:  smartbird
# Out of vocabulary word:  neuroprosthesis
# Out of vocabulary word:  ngozi
# Out of vocabulary word:  yemenis
# Out of vocabulary word:  villeneuve
# Out of vocabulary word:  lepage
# Out of vocabulary word:  whitesides
# Out of vocabulary word:  goget
# Out of vocabulary word:  lupashin
# Out of vocabulary word:  tecture
# Out of vocabulary word:  metcalfe
# Out of vocabulary word:  bangoora
# Out of vocabulary word:  koshalek
# Out of vocabulary word:  boothe
# Out of vocabulary word:  selinger
# Out of vocabulary word:  qalandar
# Out of vocabulary word:  spivak
# Out of vocabulary word:  shimon
# Out of vocabulary word:  oort
# Out of vocabulary word:  bolitics
# Out of vocabulary word:  sankofa
# Out of vocabulary word:  griscom
# Out of vocabulary word:  volkman
# Out of vocabulary word:  declan
# Out of vocabulary word:  meyerhoff
# Out of vocabulary word:  sevitha
# Out of vocabulary word:  holladay
# Out of vocabulary word:  bronte
# Out of vocabulary word:  freeland
# Out of vocabulary word:  kartikeya
# Out of vocabulary word:  hejaz
# Out of vocabulary word:  balasubramaniam
# Out of vocabulary word:  frederic
# Out of vocabulary word:  piff
# Out of vocabulary word:  kacyra
# Out of vocabulary word:  tikal
# Out of vocabulary word:  todorov
# Out of vocabulary word:  sietas
# Out of vocabulary word:  sebastiao
# Out of vocabulary word:  pratham
# Out of vocabulary word:  obiang
# Out of vocabulary word:  boahen
# Out of vocabulary word:  debevec
# Out of vocabulary word:  pretor
# Out of vocabulary word:  pinney
# Out of vocabulary word:  cloudspotting
# Out of vocabulary word:  mccallum
# Out of vocabulary word:  doolittle
# Out of vocabulary word:  hieronymus
# Out of vocabulary word:  deskbar
# Out of vocabulary word:  milgram
# Out of vocabulary word:  yossi
# Out of vocabulary word:  vardi
# Out of vocabulary word:  bodygroom
# Out of vocabulary word:  estelle
# Out of vocabulary word:  breazeal
# Out of vocabulary word:  amazonas
# Out of vocabulary word:  botero
# Out of vocabulary word:  etheridge
# Out of vocabulary word:  takaungu
# Out of vocabulary word:  bavelier
# Out of vocabulary word:  dougherty
# Out of vocabulary word:  washburn
# Out of vocabulary word:  monotasking
# Out of vocabulary word:  papandreou
# Out of vocabulary word:  melcher
# Out of vocabulary word:  burstein
# Out of vocabulary word:  velazquez
# Out of vocabulary word:  sussman
# Out of vocabulary word:  christien
# Out of vocabulary word:  buettner
# Out of vocabulary word:  yuyu
# Out of vocabulary word:  mackinnon
# Out of vocabulary word:  rospil
# Out of vocabulary word:  kallikuppam
# Out of vocabulary word:  beloit
# Out of vocabulary word:  tammet
# Out of vocabulary word:  airpix
# Out of vocabulary word:  hanczyc
# Out of vocabulary word:  schwartzberg
# Out of vocabulary word:  cartaya
# Out of vocabulary word:  baehr
# Out of vocabulary word:  dozo
# Out of vocabulary word:  alaveteli
# Out of vocabulary word:  restrepo
# Out of vocabulary word:  housman
# Out of vocabulary word:  wolpert
# Out of vocabulary word:  managua
# Out of vocabulary word:  thandie
# Out of vocabulary word:  musallam
# Out of vocabulary word:  sokoto
# Out of vocabulary word:  pasteurii
# Out of vocabulary word:  pettengill
# Out of vocabulary word:  wildscape
# Out of vocabulary word:  iloveyou
# Out of vocabulary word:  mechai
# Out of vocabulary word:  aziza
# Out of vocabulary word:  hercles
# Out of vocabulary word:  praagh
# Out of vocabulary word:  remotion
# Out of vocabulary word:  hobsbawm
# Out of vocabulary word:  slavin
# Out of vocabulary word:  slutkin
# Out of vocabulary word:  palu
# Out of vocabulary word:  marcin
# Out of vocabulary word:  harbisson
# Out of vocabulary word:  gneezy
# Out of vocabulary word:  rustichini
# Out of vocabulary word:  tavi
# Out of vocabulary word:  gevinson
# Out of vocabulary word:  pollan
# Out of vocabulary word:  soler
# Out of vocabulary word:  exl
# Out of vocabulary word:  loftus
# Out of vocabulary word:  harford
# Out of vocabulary word:  shilale
# Out of vocabulary word:  .school
# Out of vocabulary word:  kenyon
# Out of vocabulary word:  dionysian
# Out of vocabulary word:  eileen
# Out of vocabulary word:  remixable
# Out of vocabulary word:  rotich
# Out of vocabulary word:  kaminsky
# Out of vocabulary word:  nicolaus
# Out of vocabulary word:  hirshberg
# Out of vocabulary word:  crockett
# Out of vocabulary word:  schwaitzberg
# Out of vocabulary word:  kuhl
# Out of vocabulary word:  kibaki
# Out of vocabulary word:  piarco
# Out of vocabulary word:  heuser
# Out of vocabulary word:  chladni
# Out of vocabulary word:  beckstrom
# Out of vocabulary word:  mybo
# Out of vocabulary word:  ntaiya
# Out of vocabulary word:  maasais
# Out of vocabulary word:  dassen
# Out of vocabulary word:  toole
# Out of vocabulary word:  khanfar
# Out of vocabulary word:  salgado
# Out of vocabulary word:  wehrli
# Out of vocabulary word:  magritte
# Out of vocabulary word:  yitzhak
# Out of vocabulary word:  chinanet
# Out of vocabulary word:  stamets
# Out of vocabulary word:  prototaxites
# Out of vocabulary word:  sophal
# Out of vocabulary word:  phnom
# Out of vocabulary word:  penh
# Out of vocabulary word:  pursat
# Out of vocabulary word:  custer
# Out of vocabulary word:  rasselas
# Out of vocabulary word:  michoacana
# Out of vocabulary word:  dysmorphophobia
# Out of vocabulary word:  lehi
# Out of vocabulary word:  tunguska
# Out of vocabulary word:  burntisland
# Out of vocabulary word:  auenbrugger
# Out of vocabulary word:  laennec
# Out of vocabulary word:  mwenda
# Out of vocabulary word:  gottfried
# Out of vocabulary word:  mccune
# Out of vocabulary word:  outsights
# Out of vocabulary word:  culturomics
# Out of vocabulary word:  heerden
# Out of vocabulary word:  khatanga
# Out of vocabulary word:  patternicity
# Out of vocabulary word:  patternicities
# Out of vocabulary word:  agenticity
# Out of vocabulary word:  boniface
# Out of vocabulary word:  mwangi
# Out of vocabulary word:  stawi
# Out of vocabulary word:  radjou
# Out of vocabulary word:  megaffic
# Out of vocabulary word:  dweck
# Out of vocabulary word:  hellum
# Out of vocabulary word:  hibridos
# Out of vocabulary word:  constitucion
# Out of vocabulary word:  fotokite
# Out of vocabulary word:  bodnar
# Out of vocabulary word:  kanwisher
# Out of vocabulary word:  cukier
# Out of vocabulary word:  reichental
# Out of vocabulary word:  uldus
# Out of vocabulary word:  gafic
# Out of vocabulary word:  rcif
# Out of vocabulary word:  kwong
# Out of vocabulary word:  takei
# Out of vocabulary word:  cmu
# Out of vocabulary word:  telecomix
# Out of vocabulary word:  finkel
# Out of vocabulary word:  beauvoir
# Out of vocabulary word:  hobson
# Out of vocabulary word:  artemia
# Out of vocabulary word:  ferren
# Out of vocabulary word:  hadrian
# Out of vocabulary word:  hadfield
# Out of vocabulary word:  pavna
# Out of vocabulary word:  cacilda
# Out of vocabulary word:  morieux
# Out of vocabulary word:  varty
# Out of vocabulary word:  firestein
# Out of vocabulary word:  attia
# Out of vocabulary word:  pholeros
# Out of vocabulary word:  decharms
# Out of vocabulary word:  beeban
# Out of vocabulary word:  kidron
# Out of vocabulary word:  jorgensen
# Out of vocabulary word:  tananger
# Out of vocabulary word:  breel
# Out of vocabulary word:  gurion
# Out of vocabulary word:  cheapside
# Out of vocabulary word:  smithfield
# Out of vocabulary word:  ambrogio
# Out of vocabulary word:  lorenzetti
# Out of vocabulary word:  teruo
# Out of vocabulary word:  krane
# Out of vocabulary word:  jumpmasters
# Out of vocabulary word:  mahalakshmi
# Out of vocabulary word:  machado
# Out of vocabulary word:  achor
# Out of vocabulary word:  sisyphic
# Out of vocabulary word:  nargis
# Out of vocabulary word:  mekong
# Out of vocabulary word:  imja
# Out of vocabulary word:  salif
# Out of vocabulary word:  buchwald
# Out of vocabulary word:  emmart
# Out of vocabulary word:  uniview
# Out of vocabulary word:  nadkarni
# Out of vocabulary word:  hansmeyer
# Out of vocabulary word:  manwani
# Out of vocabulary word:  wharton
# Out of vocabulary word:  theodor
# Out of vocabulary word:  hewlett
# Out of vocabulary word:  wolpe
# Out of vocabulary word:  snuppy
# Out of vocabulary word:  sanjiv
# Out of vocabulary word:  suny
# Out of vocabulary word:  vacanti
# Out of vocabulary word:  fankhauser
# Out of vocabulary word:  galactosyl
# Out of vocabulary word:  surace
# Out of vocabulary word:  metz
# Out of vocabulary word:  roald
# Out of vocabulary word:  macgregor
# Out of vocabulary word:  xenophon
# Out of vocabulary word:  skinnerian
# Out of vocabulary word:  balagadde
# Out of vocabulary word:  arvs
# Out of vocabulary word:  srdja
# Out of vocabulary word:  popovic
# Out of vocabulary word:  neda
# Out of vocabulary word:  olof
# Out of vocabulary word:  weetjens
# Out of vocabulary word:  taiping
# Out of vocabulary word:  supercriminal
# Out of vocabulary word:  eppasod
# Out of vocabulary word:  bracy
# Out of vocabulary word:  .codeforamerica
# Out of vocabulary word:  simhanandini
# Out of vocabulary word:  gilley
# Out of vocabulary word:  unama
# Out of vocabulary word:  joann
# Out of vocabulary word:  kuchera
# Out of vocabulary word:  biogenerative
# Out of vocabulary word:  golesworthy
# Out of vocabulary word:  marfan
# Out of vocabulary word:  brompton
# Out of vocabulary word:  bittman
# Out of vocabulary word:  aykroyd
# Out of vocabulary word:  mcdonough
# Out of vocabulary word:  amory
# Out of vocabulary word:  lovins
# Out of vocabulary word:  bogatanos
# Out of vocabulary word:  kary
# Out of vocabulary word:  laskey
# Out of vocabulary word:  katharine
# Out of vocabulary word:  houdin
# Out of vocabulary word:  pearlman
# Out of vocabulary word:  marlene
# Out of vocabulary word:  augusten
# Out of vocabulary word:  huhh
# Out of vocabulary word:  updike
# Out of vocabulary word:  taryn
# Out of vocabulary word:  hymenoplasty
# Out of vocabulary word:  channelrhodopsins
# Out of vocabulary word:  eiger
# Out of vocabulary word:  matterhorn
# Out of vocabulary word:  xkeyscore
# Out of vocabulary word:  skydrive
# Out of vocabulary word:  dilma
# Out of vocabulary word:  rousseff
# Out of vocabulary word:  mazzucato
# Out of vocabulary word:  kafkian
# Out of vocabulary word:  sbir
# Out of vocabulary word:  oates
# Out of vocabulary word:  diamandis
# Out of vocabulary word:  emts
# Out of vocabulary word:  meshugenah
# Out of vocabulary word:  solidariot
# Out of vocabulary word:  rohwedder
# Out of vocabulary word:  kreme
# Out of vocabulary word:  gortari
# Out of vocabulary word:  porfirio
# Out of vocabulary word:  masiosare
# Out of vocabulary word:  gandhis
# Out of vocabulary word:  sadowsky
# Out of vocabulary word:  harbormasters
# Out of vocabulary word:  coppola
# Out of vocabulary word:  suslick
# Out of vocabulary word:  bloomingdale
# Out of vocabulary word:  morandi
# Out of vocabulary word:  moca
# Out of vocabulary word:  concertgebouw
# Out of vocabulary word:  alessi
# Out of vocabulary word:  danziger
# Out of vocabulary word:  hokusai
# Out of vocabulary word:  astaire
# Out of vocabulary word:  chauvet
# Out of vocabulary word:  acheulian
# Out of vocabulary word:  mahlasela
# Out of vocabulary word:  maira
# Out of vocabulary word:  kalman
# Out of vocabulary word:  gershwin
# Out of vocabulary word:  barricini
# Out of vocabulary word:  bellotto
# Out of vocabulary word:  dumais
# Out of vocabulary word:  rensink
# Out of vocabulary word:  janna
# Out of vocabulary word:  roslings
# Out of vocabulary word:  ishijima
# Out of vocabulary word:  davenhall
# Out of vocabulary word:  ramallah
# Out of vocabulary word:  raptopoulos
# Out of vocabulary word:  matternet
# Out of vocabulary word:  uavs
# Out of vocabulary word:  astrochimp
# Out of vocabulary word:  volkswagon
# Out of vocabulary word:  opisthenar
# Out of vocabulary word:  fiorenzo
# Out of vocabulary word:  omenetto
# Out of vocabulary word:  yorick
# Out of vocabulary word:  aamodt
# Out of vocabulary word:  pariser
# Out of vocabulary word:  jebr
# Out of vocabulary word:  biddle
# Out of vocabulary word:  lalitesh
# Out of vocabulary word:  katragadda
# Out of vocabulary word:  ferran
# Out of vocabulary word:  adria
# Out of vocabulary word:  boghuma
# Out of vocabulary word:  kabisen
# Out of vocabulary word:  titanji
# Out of vocabulary word:  rhim
# Out of vocabulary word:  albemarle
# Out of vocabulary word:  agnor
# Out of vocabulary word:  csikszentmihalyi
# Out of vocabulary word:  annmarie
# Out of vocabulary word:  belk
# Out of vocabulary word:  dobrynin
# Out of vocabulary word:  solzhenitsyn
# Out of vocabulary word:  niese
# Out of vocabulary word:  panzi
# Out of vocabulary word:  delano
# Out of vocabulary word:  oppenheimer
# Out of vocabulary word:  marston
# Out of vocabulary word:  murchison
# Out of vocabulary word:  paganini
# Out of vocabulary word:  lomborg
# Out of vocabulary word:  suheir
# Out of vocabulary word:  hammad
# Out of vocabulary word:  gulfstream
# Out of vocabulary word:  ekman
# Out of vocabulary word:  schoonover
# Out of vocabulary word:  cajal
# Out of vocabulary word:  massella
# Out of vocabulary word:  siegfried
# Out of vocabulary word:  woldhek
# Out of vocabulary word:  mobisante
# Out of vocabulary word:  gamley
# Out of vocabulary word:  rogier
# Out of vocabulary word:  heide
# Out of vocabulary word:  renzo
# Out of vocabulary word:  bassler
# Out of vocabulary word:  stefon
# Out of vocabulary word:  regenesis
# Out of vocabulary word:  ury
# Out of vocabulary word:  lozano
# Out of vocabulary word:  tomasdottir
# Out of vocabulary word:  audur
# Out of vocabulary word:  margonelli
# Out of vocabulary word:  tarbell
# Out of vocabulary word:  ludwick
# Out of vocabulary word:  marishane
# Out of vocabulary word:  nirmalya
# Out of vocabulary word:  phanish
# Out of vocabulary word:  viagras
# Out of vocabulary word:  schumpeter
# Out of vocabulary word:  rangoon
# Out of vocabulary word:  baikal
# Out of vocabulary word:  prestero
# Out of vocabulary word:  guier
# Out of vocabulary word:  harald
# Out of vocabulary word:  lublin
# Out of vocabulary word:  shafak
# Out of vocabulary word:  meddah
# Out of vocabulary word:  chaucer
# Out of vocabulary word:  rabassa
# Out of vocabulary word:  mayassa
# Out of vocabulary word:  astley
# Out of vocabulary word:  harger
# Out of vocabulary word:  javan
# Out of vocabulary word:  tarja
# Out of vocabulary word:  giler
# Out of vocabulary word:  witricity
# Out of vocabulary word:  soljacic
# Out of vocabulary word:  underkoffler
# Out of vocabulary word:  shand
# Out of vocabulary word:  omidyar
# Out of vocabulary word:  hanlon
# Out of vocabulary word:  animaris
# Out of vocabulary word:  schramm
# Out of vocabulary word:  bellevue
# Out of vocabulary word:  tedactive
# Out of vocabulary word:  fdi
# Out of vocabulary word:  dianna
# Out of vocabulary word:  sheraton
# Out of vocabulary word:  wuhahaha
# Out of vocabulary word:  smileygirl
# Out of vocabulary word:  swaziland
# Out of vocabulary word:  gorgens
# Out of vocabulary word:  hoen
# Out of vocabulary word:  otwoma
# Out of vocabulary word:  unitaid
# Out of vocabulary word:  aydah
# Out of vocabulary word:  nabati
# Out of vocabulary word:  pdas
# Out of vocabulary word:  oefner
# Out of vocabulary word:  rudyard
# Out of vocabulary word:  godiva
# Out of vocabulary word:  gnp
# Out of vocabulary word:  forgacs
# Out of vocabulary word:  khader
# Out of vocabulary word:  adrienne
# Out of vocabulary word:  rko
# Out of vocabulary word:  niels
# Out of vocabulary word:  diffrient
# Out of vocabulary word:  chatfield
# Out of vocabulary word:  entropia
# Out of vocabulary word:  yasheng
# Out of vocabulary word:  dharavi
# Out of vocabulary word:  yoav
# Out of vocabulary word:  gammaknife
# Out of vocabulary word:  speras
# Out of vocabulary word:  conneally
# Out of vocabulary word:  rosalind
# Out of vocabulary word:  gamow
# Out of vocabulary word:  polyphenylalanine
# Out of vocabulary word:  wigler
# Out of vocabulary word:  bradner
# Out of vocabulary word:  undruggable
# Out of vocabulary word:  farber
# Out of vocabulary word:  brigham
# Out of vocabulary word:  blicket
# Out of vocabulary word:  kymaerican
# Out of vocabulary word:  gretel
# Out of vocabulary word:  palti
# Out of vocabulary word:  bundi
# Out of vocabulary word:  tnc
# Out of vocabulary word:  zainab
# Out of vocabulary word:  salbi
# Out of vocabulary word:  wessling
# Out of vocabulary word:  abani
# Out of vocabulary word:  biafran
# Out of vocabulary word:  lucille
# Out of vocabulary word:  ohanian
# Out of vocabulary word:  horseshoer
# Out of vocabulary word:  carlock
# Out of vocabulary word:  tedxcairo
# Out of vocabulary word:  aldous
# Out of vocabulary word:  satchidananda
# Out of vocabulary word:  ucsf
# Out of vocabulary word:  kantian
# Out of vocabulary word:  fiske
# Out of vocabulary word:  jodrell
# Out of vocabulary word:  shanda
# Out of vocabulary word:  meattle
# Out of vocabulary word:  stefana
# Out of vocabulary word:  broadbent
# Out of vocabulary word:  burchfield
# Out of vocabulary word:  cowley
# Out of vocabulary word:  tarawa
# Out of vocabulary word:  mpas
# Out of vocabulary word:  melendez
# Out of vocabulary word:  wolmetz
# Out of vocabulary word:  brakarz
# Out of vocabulary word:  sangin
# Out of vocabulary word:  malem
# Out of vocabulary word:  kamenj
# Out of vocabulary word:  semple
# Out of vocabulary word:  edmontosaurus
# Out of vocabulary word:  montanans
# Out of vocabulary word:  loggable
# Out of vocabulary word:  elah
# Out of vocabulary word:  krause
# Out of vocabulary word:  anthrophony
# Out of vocabulary word:  biophonies
# Out of vocabulary word:  doren
# Out of vocabulary word:  asdfasdf
# Out of vocabulary word:  asshead
# Out of vocabulary word:  stickybot
# Out of vocabulary word:  christoph
# Out of vocabulary word:  avidians
# Out of vocabulary word:  gahr
# Out of vocabulary word:  arianna
# Out of vocabulary word:  skylife
# Out of vocabulary word:  balakrishnan
# Out of vocabulary word:  mcewen
# Out of vocabulary word:  jessa
# Out of vocabulary word:  maajid
# Out of vocabulary word:  usfda
# Out of vocabulary word:  andraka
# Out of vocabulary word:  pshhh
# Out of vocabulary word:  esterhazy
# Out of vocabulary word:  austro
# Out of vocabulary word:  baumgardner
# Out of vocabulary word:  feministing
# Out of vocabulary word:  steinem
# Out of vocabulary word:  granholm
# Out of vocabulary word:  runnion
# Out of vocabulary word:  lovelock
# Out of vocabulary word:  trafalgar
# Out of vocabulary word:  thurman
# Out of vocabulary word:  leilei
# Out of vocabulary word:  chiho
# Out of vocabulary word:  ghez
# Out of vocabulary word:  sharman
# Out of vocabulary word:  lucianne
# Out of vocabulary word:  walkowicz
# Out of vocabulary word:  diebedo
# Out of vocabulary word:  thucydides
# Out of vocabulary word:  krastev
# Out of vocabulary word:  alanna
# Out of vocabulary word:  duncker
# Out of vocabulary word:  glucksberg
# Out of vocabulary word:  tzemach
# Out of vocabulary word:  lemmon
# Out of vocabulary word:  batur
# Out of vocabulary word:  arredondo
# Out of vocabulary word:  akyol
# Out of vocabulary word:  rinaudo
# Out of vocabulary word:  romotive
# Out of vocabulary word:  iima
# Out of vocabulary word:  youssou
# Out of vocabulary word:  pasaporte
# Out of vocabulary word:  ldl
# Out of vocabulary word:  aditi
# Out of vocabulary word:  shankardass
# Out of vocabulary word:  cooperman
# Out of vocabulary word:  eetwidomayloh
# Out of vocabulary word:  severin
# Out of vocabulary word:  herzing
# Out of vocabulary word:  mugsy
# Out of vocabulary word:  makau
# Out of vocabulary word:  paulette
# Out of vocabulary word:  sadoway
# Out of vocabulary word:  heterodoxies
# Out of vocabulary word:  heroult
# Out of vocabulary word:  nescafe
# Out of vocabulary word:  pepsis
# Out of vocabulary word:  ragus
# Out of vocabulary word:  panisse
# Out of vocabulary word:  selanikio
# Out of vocabulary word:  zambian
# Out of vocabulary word:  lydmar
# Out of vocabulary word:  acquisti
# Out of vocabulary word:  wudunn
# Out of vocabulary word:  mahabuba
# Out of vocabulary word:  berns
# Out of vocabulary word:  mcrae
# Out of vocabulary word:  spca
# Out of vocabulary word:  hotz
# Out of vocabulary word:  centcom
# Out of vocabulary word:  vodacom
# Out of vocabulary word:  merrifield
# Out of vocabulary word:  mdgs
# Out of vocabulary word:  exploratorium
# Out of vocabulary word:  vilayanur
# Out of vocabulary word:  ramachandran
# Out of vocabulary word:  rizzolatti
# Out of vocabulary word:  attiya
# Out of vocabulary word:  chade
# Out of vocabulary word:  tillemann
# Out of vocabulary word:  flolan
# Out of vocabulary word:  wakulla
# Out of vocabulary word:  auv
# Out of vocabulary word:  zacaton
# Out of vocabulary word:  roukaerts
# Out of vocabulary word:  jorgen
# Out of vocabulary word:  bismark
# Out of vocabulary word:  gregoire
# Out of vocabulary word:  courtine
# Out of vocabulary word:  okonjo
# Out of vocabulary word:  iweala
# Out of vocabulary word:  alamieyeseigha
# Out of vocabulary word:  alams
# Out of vocabulary word:  shabaab
# Out of vocabulary word:  kenichi
# Out of vocabulary word:  ebina
# Out of vocabulary word:  exupery
# Out of vocabulary word:  brancusi
# Out of vocabulary word:  botsman
# Out of vocabulary word:  rondoron
# Out of vocabulary word:  shinerama
# Out of vocabulary word:  koyczan
# Out of vocabulary word:  raffaello
# Out of vocabulary word:  quadrocopters
# Out of vocabulary word:  goetz
# Out of vocabulary word:  flupsy
# Out of vocabulary word:  epicurus
# Out of vocabulary word:  gigabases
# Out of vocabulary word:  crohn
# Out of vocabulary word:  zalaznick
# Out of vocabulary word:  gomer
# Out of vocabulary word:  serfaas
# Out of vocabulary word:  bjarke
# Out of vocabulary word:  ingels
# Out of vocabulary word:  haibao
# Out of vocabulary word:  weiwei
# Out of vocabulary word:  dicaprio
# Out of vocabulary word:  lekuton
# Out of vocabulary word:  diller
# Out of vocabulary word:  idealab
# Out of vocabulary word:  pachter
# Out of vocabulary word:  marder
# Out of vocabulary word:  gehrig
# Out of vocabulary word:  frankl
# Out of vocabulary word:  kartick
# Out of vocabulary word:  satyanarayan
# Out of vocabulary word:  tedu
# Out of vocabulary word:  echelman
# Out of vocabulary word:  safina
# Out of vocabulary word:  parvin
# Out of vocabulary word:  strangelove
# Out of vocabulary word:  seyi
# Out of vocabulary word:  oyesola
# Out of vocabulary word:  annalisa
# Out of vocabulary word:  wardeh
# Out of vocabulary word:  mafundikwa
# Out of vocabulary word:  ethiopic
# Out of vocabulary word:  diop
# Out of vocabulary word:  garvey
# Out of vocabulary word:  gorking
# Out of vocabulary word:  duluth
# Out of vocabulary word:  ikaria
# Out of vocabulary word:  tedpad
# Out of vocabulary word:  hrabowski
# Out of vocabulary word:  cilliers
# Out of vocabulary word:  leded
# Out of vocabulary word:  mobsoft
# Out of vocabulary word:  tedattendees
# Out of vocabulary word:  midon
# Out of vocabulary word:  tanagra
# Out of vocabulary word:  chrystia
# Out of vocabulary word:  furstenberg
# Out of vocabulary word:  mracek
# Out of vocabulary word:  terrafugia
# Out of vocabulary word:  devdutt
# Out of vocabulary word:  pattanaik
# Out of vocabulary word:  bahubali
# Out of vocabulary word:  iliad
# Out of vocabulary word:  renata
# Out of vocabulary word:  salecl
# Out of vocabulary word:  groucho
# Out of vocabulary word:  velib
# Out of vocabulary word:  argyll
# Out of vocabulary word:  tedistan
# Out of vocabulary word:  golia
# Out of vocabulary word:  sartre
# Out of vocabulary word:  otherizing
# Out of vocabulary word:  odonil
# Out of vocabulary word:  mbubi
# Out of vocabulary word:  winona
# Out of vocabulary word:  xdrtb
# Out of vocabulary word:  epfl
# Out of vocabulary word:  foldit
# Out of vocabulary word:  goldin
# Out of vocabulary word:  olafur
# Out of vocabulary word:  iib
# Out of vocabulary word:  tedxmidatlantic
# Out of vocabulary word:  genji
# Out of vocabulary word:  riker
# Out of vocabulary word:  smolin
# Out of vocabulary word:  bairey
# Out of vocabulary word:  marineris
# Out of vocabulary word:  hellas
# Out of vocabulary word:  arthus
# Out of vocabulary word:  nakuru
# Out of vocabulary word:  taio
# Out of vocabulary word:  mobutu
# Out of vocabulary word:  seko
# Out of vocabulary word:  abacha
# Out of vocabulary word:  zakouma
# Out of vocabulary word:  rauf
# Out of vocabulary word:  compassionating
# Out of vocabulary word:  angur
# Out of vocabulary word:  eneb
# Out of vocabulary word:  turkle
# Out of vocabulary word:  mcwhorter
# Out of vocabulary word:  bidialectal
# Out of vocabulary word:  monash
# Out of vocabulary word:  lynchburg
# Out of vocabulary word:  fehr
# Out of vocabulary word:  gachter
# Out of vocabulary word:  suzana
# Out of vocabulary word:  herculano
# Out of vocabulary word:  houzel
# Out of vocabulary word:  blanton
# Out of vocabulary word:  russert
# Out of vocabulary word:  coron
# Out of vocabulary word:  papercutter
# Out of vocabulary word:  etienne
# Out of vocabulary word:  approtec
# Out of vocabulary word:  nitrosothiols
# Out of vocabulary word:  mancuso
# Out of vocabulary word:  hembrey
# Out of vocabulary word:  clausen
# Out of vocabulary word:  uvulites
# Out of vocabulary word:  yudhisthira
# Out of vocabulary word:  avalokiteshvara
# Out of vocabulary word:  bohannon
# Out of vocabulary word:  .ds
# Out of vocabulary word:  nexi
# Out of vocabulary word:  mebot
# Out of vocabulary word:  autom
# Out of vocabulary word:  niparko
# Out of vocabulary word:  beardyman
# Out of vocabulary word:  mamet
# Out of vocabulary word:  alcorn
# Out of vocabulary word:  johanson
# Out of vocabulary word:  pablos
# Out of vocabulary word:  annunziata
# Out of vocabulary word:  sukhdev
# Out of vocabulary word:  lenz
# Out of vocabulary word:  thelma
# Out of vocabulary word:  golub
# Out of vocabulary word:  colescott
# Out of vocabulary word:  somaly
# Out of vocabulary word:  meisner
# Out of vocabulary word:  humphreys
# Out of vocabulary word:  tamdin
# Out of vocabulary word:  paldin
# Out of vocabulary word:  yadira
# Out of vocabulary word:  mengatoue
# Out of vocabulary word:  doolikahn
# Out of vocabulary word:  ollantaytambo
# Out of vocabulary word:  elahi
# Out of vocabulary word:  peloponnesian
# Out of vocabulary word:  jacek
# Out of vocabulary word:  utko
# Out of vocabulary word:  senghor
# Out of vocabulary word:  blis
# Out of vocabulary word:  kuriyama
# Out of vocabulary word:  seckel
# Out of vocabulary word:  holbein
# ...
# Out of vocabulary word:  sardania
# Out of vocabulary word:  nakamoto
# Out of vocabulary word:  banksy
# Out of vocabulary word:  nêu_cao
# Out of vocabulary word:  edelman
# Out of vocabulary word:  chất_tẩy_rửa
# Out of vocabulary word:  procter
# Out of vocabulary word:  phát_ngôn_viên
# Out of vocabulary word:  mồ_hôi_của
# Out of vocabulary word:  fuelband
# Out of vocabulary word:  fakka
# Out of vocabulary word:  batsry
# Out of vocabulary word:  johann
# Out of vocabulary word:  cadnano
# Out of vocabulary word:  crambin
# Out of vocabulary word:  stratasys
# Out of vocabulary word:  geosyntec
# Out of vocabulary word:  authur
# Out of vocabulary word:  dầu_nhờn
# Out of vocabulary word:  máy_hàn
# Out of vocabulary word:  quan_thoại
# Out of vocabulary word:  một_lời_khuyên
# Out of vocabulary word:  itếp
# Out of vocabulary word:  francine
# Out of vocabulary word:  tách_rời_khỏi
# Out of vocabulary word:  búa_bổ
# Out of vocabulary word:  chân_đều
# Out of vocabulary word:  thư_thái
# Out of vocabulary word:  yên_lành
# Out of vocabulary word:  thậm_chí_thiết
# Out of vocabulary word:  anthon
# Out of vocabulary word:  patagonia
# Out of vocabulary word:  semco
# Out of vocabulary word:  hàng_hoa
# Out of vocabulary word:  interflora
# Out of vocabulary word:  tillie
# Out of vocabulary word:  da_trắng_trong
# Out of vocabulary word:  washinawatok
# Out of vocabulary word:  menominee
# Out of vocabulary word:  quản_gia
# Out of vocabulary word:  mặt_tối
# Out of vocabulary word:  thất_học
# Out of vocabulary word:  suraj
# Out of vocabulary word:  sudhakar
# Out of vocabulary word:  mathare
# Out of vocabulary word:  aslam
# Out of vocabulary word:  tasneem
# Out of vocabulary word:  saddiqui
# Out of vocabulary word:  josephat
# Out of vocabulary word:  byaruhanga
# Out of vocabulary word:  quốcmỗi
# Out of vocabulary word:  thùm_thụp
# Out of vocabulary word:  bằng_khen
# Out of vocabulary word:  đàn_ông_lớn
# Out of vocabulary word:  cụt_tay
# Out of vocabulary word:  rì_rào
# Out of vocabulary word:  ewing
# Out of vocabulary word:  nhiều_chân
# Out of vocabulary word:  bóng_bàn_chân
# Out of vocabulary word:  cheyl
# Out of vocabulary word:  tussauds
# Out of vocabulary word:  đôi_ba
# Out of vocabulary word:  đê_mê
# Out of vocabulary word:  zyprexa
# Out of vocabulary word:  chìm_nghỉm
# Out of vocabulary word:  redfield
# Out of vocabulary word:  jamison
# Out of vocabulary word:  vì_vậy_mà
# Out of vocabulary word:  macitosh
# Out of vocabulary word:  pulizer
# Out of vocabulary word:  facebookistan
# Out of vocabulary word:  amamou
# Out of vocabulary word:  riadh
# Out of vocabulary word:  guerfali
# Out of vocabulary word:  đưawikileaks
# Out of vocabulary word:  tedprize.org
# Out of vocabulary word:  nữai
# Out of vocabulary word:  trú_chân
# Out of vocabulary word:  hết_trơn
# Out of vocabulary word:  có_môn
# Out of vocabulary word:  các_bà_cụ
# Out of vocabulary word:  góc_quay
# Out of vocabulary word:  negropontea
# Out of vocabulary word:  đường_hào
# Out of vocabulary word:  diggles
# Out of vocabulary word:  sole.
# Out of vocabulary word:  bốn_bể
# Out of vocabulary word:  lẽo_đẽo
# Out of vocabulary word:  danh_nhân
# Out of vocabulary word:  martinus
# Out of vocabulary word:  chi_chít
# Out of vocabulary word:  cheknhov
# Out of vocabulary word:  thơ_lại
# Out of vocabulary word:  cho_phép_cộng
# Out of vocabulary word:  âm_đầu
# Out of vocabulary word:  mẫu_biểu
# Out of vocabulary word:  hungginn
# Out of vocabulary word:  cải_huấn
# Out of vocabulary word:  đưa_chân
# Out of vocabulary word:  challege
# Out of vocabulary word:  se_sẽ
# Out of vocabulary word:  trường_đua
# Out of vocabulary word:  federistas
# Out of vocabulary word:  roccobono
# Out of vocabulary word:  cuộc_gọi
# Out of vocabulary word:  môi_trường_học_tập
# Out of vocabulary word:  lên_hơi
# Out of vocabulary word:  blackley
# Out of vocabulary word:  miucha
# Out of vocabulary word:  balenciaga
# Out of vocabulary word:  cho_rồi
# Out of vocabulary word:  vivienne
# Out of vocabulary word:  weitzman
# Out of vocabulary word:  bebôp
# Out of vocabulary word:  gallianos
# Out of vocabulary word:  pháo_bông
# Out of vocabulary word:  cái_bầu
# Out of vocabulary word:  cái_thế
# Out of vocabulary word:  readytoshare
# Out of vocabulary word:  jauriqui
# Out of vocabulary word:  kết_nghĩa
# Out of vocabulary word:  cowen
# Out of vocabulary word:  rối_mù
# Out of vocabulary word:  jugo
# Out of vocabulary word:  eisen
# Out of vocabulary word:  shakerism
# Out of vocabulary word:  mếch_lòng
# Out of vocabulary word:  vải_bông
# Out of vocabulary word:  pastie
# Out of vocabulary word:  chẳng_ra_gì
# Out of vocabulary word:  sustein
# Out of vocabulary word:  ogilvy
# Out of vocabulary word:  cầu_tiêu
# Out of vocabulary word:  chesterton
# Out of vocabulary word:  như_thường_lệ
# Out of vocabulary word:  ra_miệng
# Out of vocabulary word:  ngược_xuôi
# Out of vocabulary word:  akal
# Out of vocabulary word:  peshwar
# Out of vocabulary word:  meher
# Out of vocabulary word:  irim
# Out of vocabulary word:  gilgit
# Out of vocabulary word:  kailash
# Out of vocabulary word:  khyber
# Out of vocabulary word:  papusay
# Out of vocabulary word:  xán_lạn
# Out of vocabulary word:  jeevan
# Out of vocabulary word:  duyên_kiếp
# Out of vocabulary word:  dunlaps
# Out of vocabulary word:  miklos
# Out of vocabulary word:  jancso
# Out of vocabulary word:  woffford
# Out of vocabulary word:  tuỳ_tùng
# Out of vocabulary word:  thương_nghiệp
# Out of vocabulary word:  nhà_máy_dệt_kim
# Out of vocabulary word:  mề_đay
# Out of vocabulary word:  spelberg
# Out of vocabulary word:  máy_dệt_kim
# Out of vocabulary word:  spartanburg
# Out of vocabulary word:  tezler
# Out of vocabulary word:  ignmar
# Out of vocabulary word:  bergman
# Out of vocabulary word:  cavalerria
# Out of vocabulary word:  bluebeard
# Out of vocabulary word:  asheville
# Out of vocabulary word:  hartsdale
# Out of vocabulary word:  sóng_triều
# Out of vocabulary word:  mortha
# Out of vocabulary word:  giẫm_đạp
# Out of vocabulary word:  lố_lăng
# Out of vocabulary word:  tác_chiến
# Out of vocabulary word:  kế_nhiệm
# Out of vocabulary word:  trò_cười
# Out of vocabulary word:  què_quặt
# Out of vocabulary word:  bandunda
# Out of vocabulary word:  theo_thời_gian
# Out of vocabulary word:  lập_loè
# Out of vocabulary word:  tướng_lĩnh
# Out of vocabulary word:  diễn_kịch
# Out of vocabulary word:  xa_gần
# Out of vocabulary word:  máy_chiếu_phim
# Out of vocabulary word:  cây_vợt
# Out of vocabulary word:  nói_suông
# Out of vocabulary word:  quản_chế
# Out of vocabulary word:  xuất_ngoại
# Out of vocabulary word:  quân_chủng
# Out of vocabulary word:  urruela
# Out of vocabulary word:  vetsports
# Out of vocabulary word:  duckworth
# Out of vocabulary word:  mcenroe
# Out of vocabulary word:  chứng_minh_điều
# Out of vocabulary word:  tổng_số_lượng
# Out of vocabulary word:  tytôi
# Out of vocabulary word:  tí_nữa
# Out of vocabulary word:  nâu_nâu
# Out of vocabulary word:  bozenman
# Out of vocabulary word:  missisipi
# Out of vocabulary word:  xách_tay_trong
# Out of vocabulary word:  đầu_tầu
# Out of vocabulary word:  tembisa
# Out of vocabulary word:  chớp_chớp
# Out of vocabulary word:  tazania
# Out of vocabulary word:  zolli
# Out of vocabulary word:  biloxi
# Out of vocabulary word:  shandra
# Out of vocabulary word:  calhound
# Out of vocabulary word:  luebkeman
# Out of vocabulary word:  sinh_lợi_nhuận
# Out of vocabulary word:  đa_ngôn_ngữ
# Out of vocabulary word:  hoàn_mĩ
# Out of vocabulary word:  biovisions
# Out of vocabulary word:  nguồn_cội
# Out of vocabulary word:  bào_quan
# Out of vocabulary word:  benedictine
# Out of vocabulary word:  tha_hồ
# Out of vocabulary word:  đã_lại
# Out of vocabulary word:  khi_hồi
# Out of vocabulary word:  vật_tư
# Out of vocabulary word:  vutter
# Out of vocabulary word:  cafos.
# Out of vocabulary word:  salatin
# Out of vocabulary word:  keener
# Out of vocabulary word:  sequachie
# Out of vocabulary word:  rau_sạch
# Out of vocabulary word:  lidell
# Out of vocabulary word:  cheskin
# Out of vocabulary word:  masten
# Out of vocabulary word:  bữc
# Out of vocabulary word:  nakilia
# Out of vocabulary word:  nikilia
# Out of vocabulary word:  reuben
# Out of vocabulary word:  ngất_ngây
# Out of vocabulary word:  quyểng
# Out of vocabulary word:  kenyatunes
# Out of vocabulary word:  lê_thê
# Out of vocabulary word:  o_ép
# Out of vocabulary word:  lấp_liếm
# Out of vocabulary word:  aarhus
# Out of vocabulary word:  cấp_nước
# Out of vocabulary word:  kì_kèo
# Out of vocabulary word:  ăn_vạ
# Out of vocabulary word:  birgitta
# Out of vocabulary word:  jónsdóttir
# Out of vocabulary word:  ém_nhẹm
# Out of vocabulary word:  truyện_cổ
# Out of vocabulary word:  macrobot
# Out of vocabulary word:  decibot
# Out of vocabulary word:  cơ_điện
# Out of vocabulary word:  nand.
# Out of vocabulary word:  cho_đang
# Out of vocabulary word:  mỗi_một_bước
# Out of vocabulary word:  chạy_máy_phát_điện
# Out of vocabulary word:  cáo_cấp
# Out of vocabulary word:  xuất_xưởng
# Out of vocabulary word:  độ_sinh
# Out of vocabulary word:  đoó
# Out of vocabulary word:  ngoại_khoa
# Out of vocabulary word:  duựng
# Out of vocabulary word:  peano
# Out of vocabulary word:  đaã
# Out of vocabulary word:  haudorff
# Out of vocabulary word:  gơờ
# Out of vocabulary word:  fatou
# Out of vocabulary word:  số_thực
# Out of vocabulary word:  số_ảo
# Out of vocabulary word:  số_phức
# Out of vocabulary word:  tiền_đồn
# Out of vocabulary word:  khoái_trá
# Out of vocabulary word:  ụ_súng
# Out of vocabulary word:  tiền_phương
# Out of vocabulary word:  quanh_quất
# Out of vocabulary word:  hetherington
# Out of vocabulary word:  góc_lệch
# Out of vocabulary word:  trầm_tư
# Out of vocabulary word:  tổ_trưởng
# Out of vocabulary word:  mũ_sắt
# Out of vocabulary word:  xô_ngã
# Out of vocabulary word:  bỏ_mạng
# Out of vocabulary word:  lục_chiến
# Out of vocabulary word:  pakista
# Out of vocabulary word:  tuscaloosa
# Out of vocabulary word:  dẹp_loạn
# Out of vocabulary word:  yểm_trợ
# Out of vocabulary word:  ăn_chung
# Out of vocabulary word:  trầy_trụa
# Out of vocabulary word:  dửng_dưng
# Out of vocabulary word:  rộng_thùng_thình
# Out of vocabulary word:  cà_nhắc
# Out of vocabulary word:  vừa_khéo
# Out of vocabulary word:  mauritus
# Out of vocabulary word:  thuế_quan
# Out of vocabulary word:  sayed
# Out of vocabulary word:  nhân_sinh_học
# Out of vocabulary word:  tedxbrussels
# Out of vocabulary word:  shropshire
# Out of vocabulary word:  phản_biện_lại
# Out of vocabulary word:  zedong
# Out of vocabulary word:  sang_tay
# Out of vocabulary word:  ãu
# Out of vocabulary word:  nếu_cần_thiết
# Out of vocabulary word:  vấp_váp
# Out of vocabulary word:  hàm_nghĩa
# Out of vocabulary word:  mắc_dịch
# Out of vocabulary word:  hồng_quân
# Out of vocabulary word:  một_mất
# Out of vocabulary word:  một_số_phận
# Out of vocabulary word:  nghịi
# Out of vocabulary word:  ba_hồi
# Out of vocabulary word:  applebaum
# Out of vocabulary word:  phối_nhạc
# Out of vocabulary word:  ellsey
# Out of vocabulary word:  beastie
# Out of vocabulary word:  jheri
# Out of vocabulary word:  mrs.
# Out of vocabulary word:  patmore
# Out of vocabulary word:  hotstepper
# Out of vocabulary word:  hypnotize
# Out of vocabulary word:  cóp_nhặt
# Out of vocabulary word:  tự_biên
# Out of vocabulary word:  da_di
# Out of vocabulary word:  temblor
# Out of vocabulary word:  khuynh_đảo
# Out of vocabulary word:  pannison
# Out of vocabulary word:  tí_nữa_là
# Out of vocabulary word:  spokeo
# Out of vocabulary word:  ggiống
# Out of vocabulary word:  mực_độ
# Out of vocabulary word:  trường_thiên_chúa
# Out of vocabulary word:  đeo_đẳng
# Out of vocabulary word:  trúc_trắc
# Out of vocabulary word:  vô_ngã
# Out of vocabulary word:  vị_thế_nào
# Out of vocabulary word:  thương_nhân_từ
# Out of vocabulary word:  phục_sức
# Out of vocabulary word:  guadalajara
# Out of vocabulary word:  mourid
# Out of vocabulary word:  barghouti
# Out of vocabulary word:  cung_tên
# Out of vocabulary word:  steinbeck
# Out of vocabulary word:  gaitskill
# Out of vocabulary word:  okoloma
# Out of vocabulary word:  mukta
# Out of vocabulary word:  bakaray
# Out of vocabulary word:  fela
# Out of vocabulary word:  nollywood
# Out of vocabulary word:  bện_tóc
# Out of vocabulary word:  chạnh_lòng
# Out of vocabulary word:  farafina
# Out of vocabulary word:  méliè
# Out of vocabulary word:  tột_bậc
# Out of vocabulary word:  lumiere
# Out of vocabulary word:  giambattista
# Out of vocabulary word:  neapolitan
# Out of vocabulary word:  safti
# Out of vocabulary word:  ra_đám_đông
# Out of vocabulary word:  méliès
# Out of vocabulary word:  mặt_mũi
# Out of vocabulary word:  dubuque
# Out of vocabulary word:  dấu_chấm_lửng
# Out of vocabulary word:  rầu_rĩ
# Out of vocabulary word:  sốt_xuất_huyết
# Out of vocabulary word:  aegyptis
# Out of vocabulary word:  deet
# Out of vocabulary word:  oxitec
# Out of vocabulary word:  có_thể_nhân
# Out of vocabulary word:  trợ_thủ
# Out of vocabulary word:  gian_lao
# Out of vocabulary word:  đi_ngược_lại
# Out of vocabulary word:  ma_quái
# Out of vocabulary word:  ác_ôn
# Out of vocabulary word:  xe_thồ
# Out of vocabulary word:  chạy_thoát
# Out of vocabulary word:  cctv.
# Out of vocabulary word:  rầy_rà
# Out of vocabulary word:  khụt_khịt
# Out of vocabulary word:  dùì
# Out of vocabulary word:  emmalou
# Out of vocabulary word:  bắt_đầu_xanh
# Out of vocabulary word:  vi_sinh_học
# Out of vocabulary word:  dejong
# Out of vocabulary word:  bì_thư
# Out of vocabulary word:  tafoni
# Out of vocabulary word:  pricky
# Out of vocabulary word:  đĩa_từ
# Out of vocabulary word:  số_chẵn
# Out of vocabulary word:  số_lẻ
# Out of vocabulary word:  treemaker
# Out of vocabulary word:  koryo
# Out of vocabulary word:  eyeglass
# Out of vocabulary word:  cùng_quẫn
# Out of vocabulary word:  phúc_thẩm
# Out of vocabulary word:  hoàn_thành_án
# Out of vocabulary word:  cựu_chiến_binh_bị
# Out of vocabulary word:  lương_y
# Out of vocabulary word:  giới_thuyết
# Out of vocabulary word:  hiệu_dụng
# Out of vocabulary word:  cáp_điện
# Out of vocabulary word:  gian_phụ
# Out of vocabulary word:  luận_đề
# Out of vocabulary word:  xanh_lè
# Out of vocabulary word:  dây_nói
# Out of vocabulary word:  calabi
# Out of vocabulary word:  zwyiec
# Out of vocabulary word:  vòng_vo
# Out of vocabulary word:  khăn_trắng
# Out of vocabulary word:  lại_mặt
# Out of vocabulary word:  điều_kinh
# Out of vocabulary word:  sùng_kính
# Out of vocabulary word:  campolo
# Out of vocabulary word:  con_chiên
# Out of vocabulary word:  mông_quạnh
# Out of vocabulary word:  tự_dẫn
# Out of vocabulary word:  grafitti
# Out of vocabulary word:  mù_khơi
# Out of vocabulary word:  meatpacking
# Out of vocabulary word:  đinh_ninh
# Out of vocabulary word:  đồng_bang
# Out of vocabulary word:  động_thổ
# Out of vocabulary word:  đem_lòng
# Out of vocabulary word:  mcmafia
# Out of vocabulary word:  thông_tín_viên
# Out of vocabulary word:  ngườiđáng
# Out of vocabulary word:  trọng_dụng
# Out of vocabulary word:  tiệnn
# Out of vocabulary word:  liêm_sỉ
# Out of vocabulary word:  thụ_án
# Out of vocabulary word:  chức_trách_nào
# Out of vocabulary word:  mua_dâm
# Out of vocabulary word:  sicili
# Out of vocabulary word:  automony
# Out of vocabulary word:  hyrdo
# Out of vocabulary word:  mầu_mè
# Out of vocabulary word:  goodsell
# Out of vocabulary word:  scripps
# Out of vocabulary word:  bởi_vậy_mà
# Out of vocabulary word:  phân_giới
# Out of vocabulary word:  chợ_nổi
# Out of vocabulary word:  thảo_nào
# Out of vocabulary word:  iud
# Out of vocabulary word:  vasectomy
# Out of vocabulary word:  quốc_khánh
# Out of vocabulary word:  triệt_sản
# Out of vocabulary word:  bohm
# Out of vocabulary word:  usaid.
# Out of vocabulary word:  hỏi_mượn
# Out of vocabulary word:  tụ_điểm
# Out of vocabulary word:  tơ_tằm
# Out of vocabulary word:  tippett
# Out of vocabulary word:  tippet
# Out of vocabulary word:  malka
# Out of vocabulary word:  fenyvesi
# Out of vocabulary word:  bạn_lòng
# Out of vocabulary word:  mắt_xích
# Out of vocabulary word:  tikkun
# Out of vocabulary word:  định_lí
# Out of vocabulary word:  schottsboro
# Out of vocabulary word:  quí_báu
# Out of vocabulary word:  franicis
# Out of vocabulary word:  einsstein
# Out of vocabulary word:  mặc_niệm
# Out of vocabulary word:  không_tập
# Out of vocabulary word:  lụther
# Out of vocabulary word:  phong_thánh
# Out of vocabulary word:  robeson
# Out of vocabulary word:  aấm
# Out of vocabulary word:  stuckey
# Out of vocabulary word:  nhiên_nhiên
# Out of vocabulary word:  phế_bỏ
# Out of vocabulary word:  cửa_nhà_vệ_sinh
# Out of vocabulary word:  hèn_gì

# %%
vi_embedding.shape
# Out:
# (30004, 300)

# %% [markdown]
# ## Data Loader

# %%
class LanguageDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """

    def __init__(self, source_lan, translate_lan):
        """
        @param data_list: list of character
        @param target_list: list of targets

        """
        self.source_lan = source_lan
        self.translate_lan = translate_lan
        
        assert (len(self.source_lan) == len(self.translate_lan))

    def __len__(self):
        return len(self.source_lan)

    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        source_lan_idx = self.source_lan[key][:MAX_SENTENCE_LENGTH-1]
        translation_lan_idx = self.translate_lan[key][:MAX_SENTENCE_LENGTH-1]
        source_lan_idx.append(EOS_idx)
        translation_lan_idx.append(EOS_idx)
        
        return [source_lan_idx, translation_lan_idx, len(source_lan_idx), len(translation_lan_idx)]

# %%
def vocab_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all
    data have the same length
    """
    source_list = []
    translate_list = []
    length_list = []
    
    # padding
    for datum in batch:
        
        length_list.append(datum[2])
        s_padded_vec = np.pad(np.array(datum[0]),
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[2])),
                                mode="constant", constant_values=PAD_idx)
        source_list.append(s_padded_vec)
        t_padded_vec = np.pad(np.array(datum[1]),
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[3])),
                                mode="constant", constant_values=PAD_idx)
        translate_list.append(t_padded_vec)
        
    ind_dec_order = np.argsort(length_list)[::-1]
    source_list = np.array(source_list)[ind_dec_order]
    length_list = np.array(length_list)[ind_dec_order]
    translate_list = np.array(translate_list)[ind_dec_order]
    
    if torch.cuda.is_available and torch.has_cudnn:
        return [torch.from_numpy(np.array(source_list)).cuda(),torch.from_numpy(np.array(translate_list)).cuda()]
    else:
        return [torch.from_numpy(np.array(source_list)),torch.from_numpy(np.array(translate_list))]

# %%
#Build train, valid and test dataloaders
train_dataset = LanguageDataset(train_vi_indicies, train_en_indicies)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=True)


val_dataset = LanguageDataset(val_vi_indicies, val_en_indicies )
val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

test_dataset = LanguageDataset(test_vi_indicies, test_en_indicies)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False)

# %% [markdown]
# ## Rnn Encoder

# %%
class EncoderRNN(nn.Module):
    def __init__(self, emb_dim, hid_dim):
        super(EncoderRNN, self).__init__()
        
        self.hid_dim = hid_dim
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(vi_embedding), freeze=False)
        
        self.dropout = nn.Dropout(p=0.3)
        self.gru = nn.GRU(emb_dim, self.hid_dim, batch_first=True, bidirectional= True)
        

    def forward(self, inputs, hidden):
        batch_size, length = inputs.size()
        embedded = self.dropout(self.embedding(inputs).float()) # the size -1 is inferred from other dimensions
        hidden = torch.cat((hidden, hidden))
        encoder_out, hidden = self.gru(embedded, hidden)
        hidden = self._cat_directions(hidden)
        return hidden
    def _cat_directions(self, hidden):
        
        def _cat(h):
            return torch.cat([h[0:h.size(0):2], h[1:h.size(0):2]], 2)   
        hidden = _cat(hidden)  
        return hidden

    def init_hidden(self, batch_size):
        return torch.rand(1, batch_size, self.hid_dim, device=device)

# %% [markdown]
# ## Decoder w/o Attention

# %%
class DecoderRNN(nn.Module):
    def __init__(self, emb_dim, hid_dim, output_dim):
        super(DecoderRNN, self).__init__()
        self.hid_dim = hid_dim *2 
        self.output_dim = output_dim
        self.dropout = nn.Dropout(p=0.3)
        self.embedding = nn.Embedding.from_pretrained(torch.from_numpy(eng_embedding), freeze=True)
        self.gru = nn.GRU(emb_dim + self.hid_dim, self.hid_dim)
        self.out = nn.Linear(self.hid_dim, output_dim)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, inputs, hidden, context):
        #input = [1, batch size]
        #hidden = [1, batch size, hid dim]
        #context = [batch size, sen len, hid dim]
        emb = self.dropout(self.embedding(inputs).float())
        emb_con = torch.cat((emb, context), dim=2)
        #emb_con =[1, batch_size, emb dim+ hid dim]
        emb_con = F.relu(emb_con)
        
        output, hidden = self.gru(emb_con, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

# %%
teacher_forcing_ratio = 1
#input_tensor: list of sentence tensor
def train(source, translate, encoder, decoder, encoder_optimizer, decoder_optimizer,
          criterion):
    
    batch_size, input_length = source.size()
    batch_size, target_length = translate.size()
    encoder_hidden = encoder.init_hidden(batch_size)
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    loss = 0
    
    #hidden = [1, batch size, hid dim]
    #encoder_output = [batch size, sen len, hid dim]
    
    encoder_hidden = encoder(source, encoder_hidden)

    decoder_input = torch.tensor(np.array([[SOS_idx]]*batch_size).reshape(1,batch_size),device=device)
    decoder_hidden = encoder_hidden
    
    #last hidden state of the encoder is the context
    context = encoder_hidden
    
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for i in range(target_length):
            
            #decoder_input: previous output of decoder
            #decoder_hidden: previous hidden state of decoder
            #encoder_output: last hidden layer of encoder
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, context)
            loss += criterion(decoder_output, translate[:,i])
            decoder_input = translate[:,i].unsqueeze(0)  # Teacher forcing
            
    else:
        # Without teacher forcing: use its own predictions as the next input
        for i in range(target_length):
            decoder_output, decoder_hidden= decoder(decoder_input, decoder_hidden, context)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            #decoder_input [1, batch size] 
            decoder_input = decoder_input.unsqueeze(0)
 
            loss += criterion(decoder_output, translate[:,i])

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
from nltk.translate.bleu_score import corpus_bleu
import sacrebleu
def evaluate(encoder, decoder, loader):
    encoder.eval()
    decoder.eval()
    input_words = []
    target_words = []
    decoded_words = []
    num_count = 0
    num_count = 0
    for i, (source, translate) in enumerate(loader):

        cur_batch_size = translate.size()[0]
            
        with torch.no_grad():
            encoder_hidden = encoder.init_hidden(cur_batch_size)
        
        input_tensor = source
        target_tensor = translate
        target_length = target_tensor.size()[1]
        encoder_hidden = encoder(input_tensor, encoder_hidden)

        decoder_input = torch.tensor(np.array([[SOS_idx]]*cur_batch_size).reshape(1,cur_batch_size),device=device)
        decoder_hidden = encoder_hidden
        
        for i in range(cur_batch_size):
            decoded_words.append([])
            input_words.append([])
            target_words.append([])
        
        for i in range(cur_batch_size):
            for ii in range(input_tensor.size()[1]):
                if vi_id2token[input_tensor.cpu().numpy()[i,ii]] != '<PAD>':
                    input_words[num_count].append(vi_id2token[input_tensor.cpu().numpy()[i,ii]])
            num_count += 1
        num_count -= cur_batch_size
        for i in range(cur_batch_size):
            for ii in range(target_tensor.size()[1]):
                if en_id2token[target_tensor.cpu().numpy()[i,ii]] != '<PAD>':
                    target_words[num_count].append(en_id2token[target_tensor.cpu().numpy()[i,ii]])
            num_count += 1
        num_count -= cur_batch_size      
        
        cur_len = np.zeros(cur_batch_size, dtype=int)
        #pdb.set_trace()
        for i in range(target_length):
            decoder_output, decoder_hidden= decoder(decoder_input, decoder_hidden, encoder_hidden)
            
            #decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_output)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            decoder_input = decoder_input.unsqueeze(0)
            
            topi = topi.squeeze().cpu().numpy()
            if cur_len[0] == 0:
                for i in range(len(topi)):
                    decoded_words[num_count+i].append(en_id2token[topi[i]])
                    cur_len[i] += 1
            
            else:
                for i in range(len(topi)):
                    if decoded_words[num_count+i][cur_len[i]-1] == '<EOS>':
                        continue
                    decoded_words[num_count+i].append(en_id2token[topi[i]])
                    cur_len[i] += 1
        num_count += cur_batch_size
    pre_list = []
    for pre_sentenc in decoded_words:
        pre_list.append("".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in pre_sentenc]).strip())

    true_list = []
    for true_sentenc in target_words:
        true_list.append("".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in true_sentenc]).strip())
    
    true_list2 = []
    true_list2.append(true_list)        
    score = sacrebleu.corpus_bleu(pre_list, true_list2)
    print('bleu score: ', score.score)
    return decoded_words,input_words, target_words, score.score

# %%
EN_EMB_DIM = 300
ZH_EMB_DIM = 300
HID_DIM = 256
OUTPUT_DIM = len(vi_id2token)
validation_score_history = []
train_loss_history = []
learning_rate=0.001
num_epoch = 10
best_score = None


encoder = EncoderRNN(ZH_EMB_DIM, HID_DIM).to(device)
decoder = DecoderRNN(EN_EMB_DIM, HID_DIM, OUTPUT_DIM).to(device)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()

for epoch in tqdm(range(num_epoch)):
    train_loss = 0 
    for i, (source, translate) in enumerate(train_loader):
        
        encoder.train()
        decoder.train()

        loss = train(source, translate, encoder, decoder,
                     encoder_optimizer, decoder_optimizer, criterion)
        
        train_loss += loss
        
        if i >0 and i % 500 ==0:
            
            _, _, _, val_score = evaluate(encoder, decoder, val_loader)
            
            print('Epoch: [{}/{}], Step: [{}/{}],  Train Loss: {},   Validation Score: {}'.format(
                  epoch+1, num_epoch, i+1, len(train_loader),  train_loss/500, val_score))
            
            train_loss_history.append(train_loss/500)
            train_loss =0
            validation_score_history.append(val_score)  
            # check if we need to earily stop the model
            stop=False
            repeat=0
            t =5
            if best_score is None:
                best_score = val_score
            elif val_score < best_score:
                repeat += 1

                if repeat >= t:
                    stop =True
                    break
            else:
                best_score = val_score
                repeat = 0
            if stop:
                print("earily stop triggered")
                break
                
    # because of the the nested loop
    if stop:
        break
    
    torch.save(encoder.state_dict(), 'vi_encoder_10.pt')
    torch.save(decoder.state_dict(), 'vi_decoder_10.pt')
    
train_loss_df = pd.DataFrame(data={"train_loss": train_loss_history})
train_loss_df.to_csv("vi_10_train_loss.csv",index=False)
val_score_df = pd.DataFrame(data={"val_score": validation_score_history})
val_score_df.to_csv('vi_10_val_score.csv',index =False)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/tqdm-4.19.4-py3.6.egg/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/xy990/pytorch-cpu/py3.6.3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# bleu score:  10.360703923199841
# Epoch: [1/10], Step: [501/2084],  Train Loss: 2.964506969451902,   Validation Score: 10.360703923199841
# bleu score:  12.645041043734077
# Epoch: [1/10], Step: [1001/2084],  Train Loss: 2.4682235786438005,   Validation Score: 12.645041043734077
# bleu score:  13.607893399692527
# Epoch: [1/10], Step: [1501/2084],  Train Loss: 2.312620716094971,   Validation Score: 13.607893399692527
# bleu score:  13.761001689930126
# Epoch: [1/10], Step: [2001/2084],  Train Loss: 2.2183939117431617,   Validation Score: 13.761001689930126
#  10%|█         | 1/10 [06:21<57:11, 381.30s/it]
# bleu score:  12.137557051485473
# Epoch: [2/10], Step: [501/2084],  Train Loss: 2.0964323282241804,   Validation Score: 12.137557051485473
# bleu score:  13.87807778821509
# Epoch: [2/10], Step: [1001/2084],  Train Loss: 2.0149701494216923,   Validation Score: 13.87807778821509
# bleu score:  13.975168259451305
# Epoch: [2/10], Step: [1501/2084],  Train Loss: 1.993139010238647,   Validation Score: 13.975168259451305
# bleu score:  15.211011137022506
# Epoch: [2/10], Step: [2001/2084],  Train Loss: 1.944983475303651,   Validation Score: 15.211011137022506
#  20%|██        | 2/10 [12:42<50:51, 381.40s/it]
# bleu score:  15.22581442208546
# Epoch: [3/10], Step: [501/2084],  Train Loss: 1.8068420978546138,   Validation Score: 15.22581442208546
# bleu score:  16.5900992933173
# Epoch: [3/10], Step: [1001/2084],  Train Loss: 1.8006541448593143,   Validation Score: 16.5900992933173
# bleu score:  17.4176220866847
# Epoch: [3/10], Step: [1501/2084],  Train Loss: 1.7918600631713852,   Validation Score: 17.4176220866847
# bleu score:  15.262965922272832
# Epoch: [3/10], Step: [2001/2084],  Train Loss: 1.771346390914916,   Validation Score: 15.262965922272832
#  30%|███       | 3/10 [19:03<44:29, 381.31s/it]
# bleu score:  16.382646124027026
# Epoch: [4/10], Step: [501/2084],  Train Loss: 1.6302462965011597,   Validation Score: 16.382646124027026
# bleu score:  16.822147528404994
# Epoch: [4/10], Step: [1001/2084],  Train Loss: 1.6360900842666632,   Validation Score: 16.822147528404994
# bleu score:  16.784208502081444
# Epoch: [4/10], Step: [1501/2084],  Train Loss: 1.6353959854125988,   Validation Score: 16.784208502081444
# bleu score:  17.005187680538018
# Epoch: [4/10], Step: [2001/2084],  Train Loss: 1.6503977321624752,   Validation Score: 17.005187680538018
#  40%|████      | 4/10 [25:25<38:07, 381.31s/it]
# bleu score:  17.194325313025224
# Epoch: [5/10], Step: [501/2084],  Train Loss: 1.486302209472656,   Validation Score: 17.194325313025224
# bleu score:  16.963841956519737
# Epoch: [5/10], Step: [1001/2084],  Train Loss: 1.522441272735597,   Validation Score: 16.963841956519737
# bleu score:  16.767587520991736
# Epoch: [5/10], Step: [1501/2084],  Train Loss: 1.5354338392257683,   Validation Score: 16.767587520991736
# bleu score:  17.577415903369513
# Epoch: [5/10], Step: [2001/2084],  Train Loss: 1.5323884815216064,   Validation Score: 17.577415903369513
#  50%|█████     | 5/10 [31:46<31:46, 381.37s/it]
# bleu score:  17.237987791804034
# Epoch: [6/10], Step: [501/2084],  Train Loss: 1.4064562837600698,   Validation Score: 17.237987791804034
# bleu score:  18.357197621700966
# Epoch: [6/10], Step: [1001/2084],  Train Loss: 1.426186099243164,   Validation Score: 18.357197621700966
# bleu score:  17.529015759913932
# Epoch: [6/10], Step: [1501/2084],  Train Loss: 1.4495862936019899,   Validation Score: 17.529015759913932
# bleu score:  16.92303178420871
# Epoch: [6/10], Step: [2001/2084],  Train Loss: 1.437520096015931,   Validation Score: 16.92303178420871
#  60%|██████    | 6/10 [38:08<25:25, 381.39s/it]
# bleu score:  17.73759858552509
# Epoch: [7/10], Step: [501/2084],  Train Loss: 1.336022355461121,   Validation Score: 17.73759858552509
# bleu score:  18.530488282488076
# Epoch: [7/10], Step: [1001/2084],  Train Loss: 1.352622618293762,   Validation Score: 18.530488282488076
# bleu score:  17.57938283436292
# Epoch: [7/10], Step: [1501/2084],  Train Loss: 1.383679906272888,   Validation Score: 17.57938283436292
# bleu score:  17.43324670382229
# Epoch: [7/10], Step: [2001/2084],  Train Loss: 1.391019430351257,   Validation Score: 17.43324670382229
#  70%|███████   | 7/10 [44:29<19:04, 381.36s/it]
# bleu score:  17.7235673944246
# Epoch: [8/10], Step: [501/2084],  Train Loss: 1.2813248920440667,   Validation Score: 17.7235673944246
# bleu score:  18.092261279508996
# Epoch: [8/10], Step: [1001/2084],  Train Loss: 1.302189985275269,   Validation Score: 18.092261279508996
# bleu score:  18.27604565268951
# Epoch: [8/10], Step: [1501/2084],  Train Loss: 1.3235209808349602,   Validation Score: 18.27604565268951
# bleu score:  17.93218329832515
# Epoch: [8/10], Step: [2001/2084],  Train Loss: 1.3496232500076284,   Validation Score: 17.93218329832515
#  80%|████████  | 8/10 [50:50<12:42, 381.36s/it]
# bleu score:  17.61006612128958
# Epoch: [9/10], Step: [501/2084],  Train Loss: 1.2424012481689455,   Validation Score: 17.61006612128958
# bleu score:  18.7446497658419
# Epoch: [9/10], Step: [1001/2084],  Train Loss: 1.2568412813186651,   Validation Score: 18.7446497658419
# bleu score:  18.735242952798494
# Epoch: [9/10], Step: [1501/2084],  Train Loss: 1.2886739810943602,   Validation Score: 18.735242952798494
# bleu score:  17.6280763754076
# Epoch: [9/10], Step: [2001/2084],  Train Loss: 1.2913117082595835,   Validation Score: 17.6280763754076
#  90%|█████████ | 9/10 [57:12<06:21, 381.34s/it]
# bleu score:  18.807501017526928
# Epoch: [10/10], Step: [501/2084],  Train Loss: 1.195767869567873,   Validation Score: 18.807501017526928
# bleu score:  18.40295705690919
# Epoch: [10/10], Step: [1001/2084],  Train Loss: 1.2297134784698487,   Validation Score: 18.40295705690919
# bleu score:  18.585939957029876
# Epoch: [10/10], Step: [1501/2084],  Train Loss: 1.252232156562805,   Validation Score: 18.585939957029876
# bleu score:  18.322974043158226
# Epoch: [10/10], Step: [2001/2084],  Train Loss: 1.2631096220016478,   Validation Score: 18.322974043158226
# 100%|██████████| 10/10 [1:03:33<00:00, 381.32s/it]

# %%
fig = plt.figure()
plt.plot(train_loss_history)

plt.xlabel('step')
plt.ylabel('train loss')
plt.title('Train Loss of Vi-En Translation without attention')
plt.show()
fig.savefig('train_loss_vi_10.png')

# %%
fig = plt.figure()
plt.plot(validation_score_history)
plt.xlabel('step')
plt.ylabel('validation bleu score')
plt.title('BLEU Score of Vi-En Translation without attention')
fig.savefig('val_score_vi_10.png')

plt.show()

# %%
encoder.load_state_dict(torch.load('vi_encoder_10.pt'))
decoder.load_state_dict(torch.load('vi_decoder_10.pt'))
encoder.to(device)
decoder.to(device)
# Out:
# DecoderRNN(
#   (dropout): Dropout(p=0.3)
#   (embedding): Embedding(30004, 300)
#   (gru): GRU(812, 512)
#   (out): Linear(in_features=512, out_features=30004, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
decoded_words,input_words, target_words, score = evaluate(encoder, decoder, test_loader)
# Out:
# bleu score:  21.00726720202513

# %%
for i in range(len(decoded_words)):
    print('input: ', input_words[i])
    print('target: ', target_words[i])
    print('predict: ', decoded_words[i])
    print('-----------------------------------------------')
    print()
# Out:
# input:  ['tôi', 'muốn', 'rút', 'về', 'cái', 'lề_thói', 'hàng_ngày', 'và', 'sự', 'dễ_chịu', 'của', 'cuộc_sống', 'trong', 'khu', 'ngoại_ô', 'không_ai', 'hay_biết', 'người', 'bà', 'người', 'mẹ', 'và', 'hai', 'con_gái', 'kết_thúc', 'mỗi', 'ngày', 'như', 'bao', 'ngày', 'trong_suốt', 'năm', 'kể', 'cho', 'nhau', 'nghe', 'chuyện', 'trong', 'ngày', '<EOS>']
# target:  ['i', 'wanted', 'to', 'retreat', 'to', 'the', 'routines', 'and', 'comfort', 'of', 'life', 'in', 'an', '<UNK>', 'suburb', 'a', 'grandmother', 'a', 'mother', 'and', 'two', 'daughters', 'ending', 'each', 'day', 'as', 'they', 'had', 'for', 'almost', 'years', 'telling', 'one', 'another', 'the', 'story', 'of', 'their', 'day', '<EOS>']
# predict:  ['i', 'wanted', 'to', 'understand', 'the', 'story', 'of', 'the', 'mystic', 'and', 'the', 'gesture', 'of', 'the', 'everyday', 'and', 'the', 'mother', 'of', 'the', 'mother', 'and', 'the', 'mother', 'of', 'the', 'mother', 'and', 'the', 'mother', 'was', 'a', 'mother', 'and', 'she', 'was', 'able', 'to', 'do', 'the']
# -----------------------------------------------
#
# input:  ['tan', 'le', 'cư_dân', 'vô_danh', 'ở', 'khu', '<UNK>', 'giờ', 'là', 'tan', 'le', 'người', 'tị_nạn', 'và', 'hoạt_động', 'xã_hội', 'được', 'mời', 'nói_chuyện', 'ở', 'các', 'địa_điểm', 'cô', 'chưa', 'bao_giờ', 'nghe', 'tới', 'được', 'mời', 'vào', 'những', 'nhà', 'mà', 'cô', 'chưa', 'bao_giờ', 'tưởng_tượng', 'được', 'là', '<EOS>']
# target:  ['tan', 'le', 'anonymous', '<UNK>', 'resident', 'was', 'now', 'tan', 'le', 'refugee', 'and', 'social', 'activist', 'invited', 'to', 'speak', 'in', 'venues', 'she', 'had', 'never', 'heard', 'of', 'and', 'into', 'homes', 'whose', 'existence', 'she', 'could', 'never', 'have', 'imagined', '.', '<EOS>']
# predict:  ['ali', 'le', 'ali', '<UNK>', 'was', 'in', 'a', 'western', 'democratic', 'republic', 'and', 'she', 'was', 'never', 'captured', 'to', 'the', '<UNK>', 'and', 'she', 'was', 'never', 'invited', 'to', 'talk', 'to', 'say', 'to', 'you', 'd', 'never', 'heard', 'here', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'không', 'nhớ', 'lũ', 'cướp', 'biến', 'đã', 'đến', 'rất', 'nhiều', 'lần', 'nhưng', 'bị', 'lừa', 'bỏ_đi', 'bởi', 'sự', '<UNK>', 'càm', 'của', 'những', 'người', 'đàn_ông', 'trên', 'thuyền', 'hay_là', 'khi', 'máy', 'tàu', 'bị', 'chết', 'và', 'không', 'khởi_động', 'được', 'trong_suốt', 'sáu', 'tiếng', 'đồng_hồ', '<EOS>']
# target:  ['i', 'don', 't', 'remember', 'the', 'pirates', 'who', 'came', 'many', 'times', 'but', 'were', '<UNK>', 'by', 'the', '<UNK>', 'of', 'the', 'men', 'on', 'our', 'boat', 'or', 'the', 'engine', 'dying', 'and', 'failing', 'to', 'start', 'for', 'six', 'hours', '.', '<EOS>']
# predict:  ['i', 'bet', 'not', 'a', 'lot', 'of', 'people', 'to', 'die', 'but', 'for', 'the', 'first', 'time', 'the', '<UNK>', 'caught', 'in', 'the', 'ship', 'and', 'the', '<UNK>', 'was', 'not', 'eaten', 'by', 'the', 'man', 'who', 'were', 'caught', 'in', 'the', 'boat', 'and', 'the', '<UNK>', 'was', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'tôi', 'nhớ', 'được', 'ánh', 'đèn', 'từ', 'giàn', 'khoan', 'dầu', 'ngoài', 'bờ_biển', 'malaysia', 'và', 'một', 'anh', 'thanh_niên', 'đã', 'quỵ', 'ngã', 'rồi', 'qua_đời', 'cái', 'kết', 'của', 'cuộc', 'hành_trình', 'là', 'quá_sức', 'chịu_đựng', 'với', 'anh', 'và', 'quả', 'táo', 'đầu_tiên', 'tôi', 'được', 'nếm', '<EOS>']
# target:  ['but', 'i', 'do', 'remember', 'the', 'lights', 'on', 'the', 'oil', 'rig', 'off', 'the', '<UNK>', 'coast', 'and', 'the', 'young', 'man', 'who', 'collapsed', 'and', 'died', 'the', 'journey', 's', 'end', 'too', 'much', 'for', 'him', 'and', 'the', 'first', 'apple', 'i', 'tasted', 'given', 'to', 'me', '<EOS>']
# predict:  ['but', 'i', 'remember', 'the', 'first', 'bp', 'oil', 'spill', 'in', 'the', 'caribbean', 'and', 'then', 'you', 'get', 'a', '<UNK>', 'for', 'the', 'first', 'time', 'to', 'tell', 'you', 'the', 'story', 'of', 'the', 'first', 'lady', 'and', 'the', 'first', 'time', 'of', 'the', 'first', '<EOS>']
# -----------------------------------------------
#
# input:  ['từng', 'đồng_tiền', 'đều', 'được', 'cân_nhắc', 'và', 'tiền', 'học', 'thêm', 'tiếng', 'anh', 'và', 'toán', 'được', 'đặt', 'riêng', 'ra', 'bất_kể', 'việc', 'khoản', 'nào', 'phải', 'trừ', 'bớt', 'đi', 'thường', 'thì', 'đó', 'là', 'quần_áo', 'mới', 'quần_áo', 'chúng_tôi', 'lúc', 'nào', 'cũng', 'là', 'đồ', 'cũ', '<EOS>']
# target:  ['all', 'the', 'dollars', 'were', 'allocated', 'and', 'extra', '<UNK>', 'in', 'english', 'and', 'mathematics', 'was', '<UNK>', 'for', 'regardless', 'of', 'what', 'missed', 'out', 'which', 'was', 'usually', 'new', 'clothes', 'they', 'were', 'always', '<UNK>', '.', '<EOS>']
# predict:  ['every', 'time', 'you', 'had', 'to', 'go', 'and', 'and', 'it', 'was', 'to', 'be', 'a', 'little', 'bit', 'and', 'it', 'was', 'to', 'be', 'any', 'given', 'to', 'any', 'other', 'kind', 'of', 'credit', 'except', 'that', 'you', 'were', 'in', 'the', 'same', 'way', 'you', 'were', 'totally', 'surprised']
# -----------------------------------------------
#
# input:  ['làm_sao', 'tôi', 'có_thể', 'trình_bày', 'trong', 'phút', 'về', 'sợi', 'dây', 'liên_kết', 'những', 'người', 'phụ_nữ', 'qua', 'ba', 'thế_hệ', 'về', 'việc_làm', 'thế_nào', 'những', 'sợi', 'dây', 'mạnh_mẽ', 'đáng', 'kinh_ngạc', 'ấy', 'đã', 'níu', 'chặt', 'lấy', 'cuộc_sống', 'của', 'một', 'cô', 'bé', 'bốn', 'tuổi', '<UNK>', 'với', '<EOS>']
# target:  ['how', 'can', 'i', 'speak', 'in', 'minutes', 'about', 'the', 'bonds', 'of', 'women', 'over', 'three', 'generations', 'about', 'how', 'the', 'astonishing', 'strength', 'of', 'those', 'bonds', 'took', 'hold', 'in', 'the', 'life', 'of', 'a', 'four', 'year', 'old', 'girl', 'huddled', 'with', 'her', 'young', 'sister', 'her', '<EOS>']
# predict:  ['i', 'can', 'begin', 'to', 'the', 'last', 'three', 'years', 'of', 'the', 'world', 's', 'deep', 'deep', '<UNK>', 'with', 'the', 'incredible', '<UNK>', 'that', 'i', 've', 'been', 'able', 'to', 'capture', 'the', 'first', 'four', 'of', 'the', 'women', 'who', 'have', 'been', 'able', 'to', 'do', 'this', 'special']
# -----------------------------------------------
#
# input:  ['nhiệm_vụ', 'của', 'tôi', 'là', 'không', 'để', 'cuộc_đời', 'ấy', 'qua', 'trong', 'vô_vọng', 'và', 'bài_học', 'của', 'tôi', 'là', 'nhận', 'ra', 'rằng', 'vâng', 'lịch_sử', 'đã', 'cố', '<UNK>', 'chúng_tôi', 'nhưng', 'chúng_tôi', 'đã', 'chịu_đựng', 'được', '.', '<EOS>']
# target:  ['my', 'duty', 'was', 'not', 'to', 'allow', 'it', 'to', 'have', 'been', 'in', 'vain', 'and', 'my', 'lesson', 'was', 'to', 'learn', 'that', 'yes', 'history', 'tried', 'to', 'crush', 'us', 'but', 'we', 'endured', '.', '<EOS>']
# predict:  ['my', 'job', 'is', 'not', 'to', 'try', 'to', 'find', 'that', 'the', 'history', 'of', 'the', 'history', 'but', 'i', 've', 'been', 'trying', 'to', 'find', 'that', 'our', 'lives', 'but', 'we', 've', 'been', 'trying', 'to', 'be', 'able', 'to', 'find', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'rồi', 'bao', 'người', 'phụ_nữ', 'đến', 'kể', 'câu_chuyện', 'của', 'họ', 'về', 'những', 'gã', 'đàn_ông', 'không_thể', 'hoà_nhập', 'với', 'cuộc_sống', 'mới', 'giận_dữ', 'và', 'cứng_nhắc', 'và', 'những', 'đứa', 'trẻ', '<UNK>', 'giữa', 'hai', 'thế_giới', '.', '<EOS>']
# target:  ['and', 'the', 'women', 'came', 'with', 'their', 'stories', 'about', 'men', 'who', 'could', 'not', 'make', 'the', 'transition', 'angry', 'and', 'inflexible', 'and', 'troubled', 'children', 'caught', 'between', 'two', 'worlds', '.', '<EOS>']
# predict:  ['and', 'then', 'people', 'who', 'are', 'interested', 'to', 'talk', 'about', 'their', 'grandparents', 'and', 'the', 'idea', 'of', 'the', 'unhappy', 'men', 'are', 'not', 'between', 'the', '<UNK>', 'and', 'the', 'men', 'between', 'the', 'world', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi', 'mai', 'mới', 'tuổi', 'khi', 'ba', 'của', 'mẹ', 'mất', 'đã', 'lập', 'gia_đình', 'một', 'cuộc', 'hôn_nhân', 'sắp_đặt', 'trước', 'đã', 'có', 'hai', 'cô', 'con', 'gái', 'nhỏ', '.', '<EOS>']
# target:  ['my', 'mother', '<UNK>', 'was', 'when', 'her', 'father', 'died', 'already', 'in', 'an', 'arranged', 'marriage', 'already', 'with', 'two', 'small', 'girls', '.', '<EOS>']
# predict:  ['my', 'mother', 'had', 'gone', 'to', 'her', 'mother', 'had', 'a', 'child', 'in', 'a', 'third', 'grade', 'of', 'her', 'family', 'she', 'had', 'a', 'little', 'girl', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['kí_ức', 'sớm', 'nhất', 'tôi', 'nhớ', 'được', 'là', 'từ', 'cái', 'thuyền', 'tiếng', 'động_cơ', 'đều_đều', 'mạn', 'tiền', 'con', 'thuyền', 'chìm', 'vào', 'mỗi', 'đợt', 'sóng', 'chân_trời', 'mênh_mông', 'trống_trải', '.', '<EOS>']
# target:  ['my', 'first', 'memories', 'are', 'from', 'the', 'boat', 'the', 'steady', 'beat', 'of', 'the', 'engine', 'the', 'bow', 'dipping', 'into', 'each', 'wave', 'the', 'vast', 'and', 'empty', 'horizon', '.', '<EOS>']
# predict:  ['the', 'most', 'memorable', 'i', 'clicked', 'from', 'the', 'olympics', 'i', 'was', 'sent', 'from', 'the', '<UNK>', 'to', 'the', '<UNK>', 'to', 'the', '<UNK>', 'to', 'the', '<UNK>', 'to', 'the', '<UNK>', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['thỉnh_thoảng', 'dù', 'ít', 'tôi', 'nghe_thấy', 'tràng', 'chế_giễu', 'xé', 'lòng', 'đồ', 'mắt', '<UNK>', 'và', 'thỉnh_thoảng', 'có', 'hình_vẽ', 'trên', 'tường', 'lũ', 'châu', 'á', '<UNK>', 'về', 'nhà', '.', '<UNK>', '<EOS>']
# target:  ['and', 'there', 'were', 'rare', 'but', 'searing', '<UNK>', 'of', 'quot', 'slit', 'eye', 'quot', 'and', 'the', 'occasional', 'graffiti', 'quot', 'asian', 'go', 'home', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['sometimes', 'sometimes', 'i', 'sometimes', 'hear', 'them', 'eyes', 'and', 'i', 'cut', 'them', 'up', 'with', 'them', 'and', 'i', 'm', 'going', 'to', 'see', 'the', 'chimps', 'and', 'the', 'right', 'in', 'the', 'middle', 'of', 'the', 'house', '.', 'quot', '<UNK>', '<EOS>']
# -----------------------------------------------
#
# input:  ['không', 'như', 'những', 'vùng', 'ngoại_ô', 'ổn_định', 'cho', 'giai_cấp', 'trung_lưu', 'mà', 'tôi', 'không', 'hề', 'biết', 'là', 'có', 'tồn_tại', 'chẳng', 'có', 'tí', 'quyền_lợi', 'nào', 'ở', '<UNK>', '.', '<EOS>']
# target:  ['unlike', 'the', 'settled', 'middle', 'class', 'suburbs', 'whose', 'existence', 'i', 'was', 'oblivious', 'of', 'there', 'was', 'no', 'sense', 'of', 'entitlement', 'in', '<UNK>', '.', '<EOS>']
# predict:  ['unlike', 'the', 'middle', 'of', 'the', 'temples', 'are', 'not', 'the', 'middle', 'east', 'i', 'know', 'what', 's', 'not', 'there', 'is', 'the', 'middle', 'of', 'the', 'country', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'những', 'mảnh', 'tiếng', 'anh', 'đứt_quãng', 'trong', 'cuộc', 'hội_thoại', 'giữa', 'những', 'con_người', 'có', 'duy', 'một', 'điểm', 'chung', 'họ', 'đang', 'bắt_đầu', 'lại', 'từ', 'đầu', '.', '<EOS>']
# target:  ['and', 'the', 'snippets', 'of', '<UNK>', 'english', 'were', 'exchanged', 'between', 'people', 'who', 'had', 'one', 'thing', 'in', 'common', 'they', 'were', 'starting', 'again', '.', '<EOS>']
# predict:  ['and', 'the', 'people', 'who', 'were', 'in', 'the', 'room', 'the', 'people', 'who', 'were', 'randomly', 'in', 'the', 'same', 'way', 'they', 'were', 'starting', 'to', 'happen', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi_tối', 'nào', 'cũng', 'kiệt_sức', 'nhưng', 'chúng_tôi', 'kể', 'cho', 'nhau', 'nghe', 'chuyện', 'trong', 'ngày', 'và', 'nghe_tiếng', 'bà', 'tôi', 'đi', 'lại', 'quanh', 'nhà', '.', '<EOS>']
# target:  ['my', 'mother', 'was', 'exhausted', 'each', 'night', 'but', 'we', 'told', 'one', 'another', 'about', 'our', 'day', 'and', 'listened', 'to', 'the', 'movements', 'of', 'my', 'grandmother', 'around', 'the', 'house', '.', '<EOS>']
# predict:  ['mother', 'mother', 'mother', 'and', 'we', 'all', 'heard', 'the', 'same', 'day', 'and', 'she', 'goes', 'back', 'to', 'the', 'house', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ông', 'là', 'nhà_thơ', 'nhà', 'viết', 'kịch', 'một', 'người', 'mà_cả', 'cuộc_đời', 'chênh_vênh', 'trên', 'tia', 'hi_vọng', 'duy_nhất', 'rằng', 'đất_nước', 'ông', 'sẽ', 'độc_lập', 'tự_do', '.', '<EOS>']
# target:  ['he', 'is', 'a', 'poet', 'a', 'playwright', 'a', 'man', 'whose', 'whole', 'life', 'had', 'been', 'balanced', 'on', 'the', 'single', 'hope', 'of', 'his', 'country', 's', 'unity', 'and', 'freedom', '.', '<EOS>']
# predict:  ['he', 'was', 'a', 'writer', 'who', 'was', 'a', 'professor', 'in', 'the', 'world', 'who', 'was', 'a', 'false', 'that', 'he', 'would', 'be', 'afraid', 'to', 'be', 'able', 'to', 'live', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['thế_là', 'sau', 'bốn', 'năm', 'một', '<UNK>', 'đằng_đẵng', 'hơn_cả', 'trong', 'truyện', 'một', 'chiếc', 'thuyền', 'trườn', 'ra', 'biển', 'nguỵ_trang', 'là', 'thuyền', 'đánh_cá', '.', '<EOS>']
# target:  ['so', 'after', 'a', 'four', 'year', 'saga', 'that', 'defies', 'fiction', 'a', 'boat', 'slipped', 'out', 'to', 'sea', 'disguised', 'as', 'a', 'fishing', 'vessel', '.', '<EOS>']
# predict:  ['so', 'after', 'five', 'years', 'a', 'half', 'of', 'the', 'half', '<UNK>', 'in', 'the', 'sea', '<UNK>', '<UNK>', '<UNK>', 'a', '<UNK>', 'in', 'the', 'sea', 'sea', 'of', 'sea', 'was', 'a', 'sea', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'vì', 'công_tác', 'đó', 'khi', 'tôi', 'là', 'sinh_viên', 'luật', 'năm', 'cuối', 'tôi', 'được', 'bầu', 'là', 'thanh_niên', 'úc', 'của', 'năm', '.', '<EOS>']
# target:  ['and', 'for', 'that', 'work', 'when', 'i', 'was', 'a', 'final', 'year', 'law', 'student', 'i', 'was', 'chosen', 'as', 'the', 'young', 'australian', 'of', 'the', 'year', '.', '<EOS>']
# predict:  ['and', 'as', 'i', 'started', 'to', 'call', 'the', 'last', 'year', 'the', 'student', 'was', 'the', 'privilege', 'of', 'the', 'year', 'i', 'was', 'a', 'year', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'tôi', 'bị', 'phóng', 'từ', 'mảnh_ghép', 'xếp', 'hình', 'này', 'sang', 'mảnh', 'khác', 'nhưng', 'chúng', 'không', 'ghép', 'vừa', 'với', 'nhau', '.', '<EOS>']
# target:  ['and', 'i', 'was', 'catapulted', 'from', 'one', 'piece', 'of', 'the', 'jigsaw', 'to', 'another', 'and', 'their', 'edges', 'didn', 't', 'fit', '.', '<EOS>']
# predict:  ['and', 'i', 'was', 'coming', 'from', 'these', 'pieces', 'but', 'they', 're', 'not', 'just', 'different', 'but', 'they', 're', 'not', 'going', 'to', 'be', 'different', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['chúng_tôi', 'định_cư', 'ở', '<UNK>', 'vùng', 'ngoại_ô', 'cho', 'dân', 'lao_động', 'trong', 'đó', 'dân', 'số', 'là', 'các', 'tầng_lớp', 'người', 'nhập_cư', '.', '<EOS>']
# target:  ['we', 'settled', 'in', '<UNK>', 'a', 'working', 'class', 'suburb', 'whose', 'demographic', 'is', 'layers', 'of', 'immigrants', '.', '<EOS>']
# predict:  ['we', 'went', 'in', 'the', 'suburbs', 'of', 'the', 'mall', 'in', 'the', 'neighborhood', 'of', 'the', 'people', 'that', 'are', 'located', 'in', 'the', 'area', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['với', 'mẹ', 'cuộc_đời', 'cô_đọng', 'vào', 'nhiệm_vụ', 'duy_nhất', 'để', 'gia_đình', 'mẹ', 'trốn', 'thoát', 'và', 'bắt_đầu', 'cuộc_sống', 'mới', 'ở', 'úc', '.', '<EOS>']
# target:  ['for', 'her', 'life', 'had', 'distilled', 'itself', 'into', 'one', 'task', 'the', 'escape', 'of', 'her', 'family', 'and', 'a', 'new', 'life', 'in', 'australia', '.', '<EOS>']
# predict:  ['with', 'my', 'mother', 'mother', 'mother', 'in', 'the', 'life', 'of', 'my', 'mother', 's', 'begun', 'to', 'go', 'back', 'to', 'the', 'u', '.s', '.', 'and', 'she', 's', 'got', 'the', 'outside', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['trong', 'thế_giới', 'kia', 'tôi', 'vướng_mắc', 'trong', 'những', 'mảnh', 'đời', 'bấp_bênh', 'bị', 'tổn_thương', 'bi_thảm', 'vì', 'bạo_lực', 'nghiện_ngập', 'và', '<UNK>', '.', '<EOS>']
# target:  ['in', 'the', 'other', 'i', 'was', '<UNK>', 'in', 'lives', 'that', 'were', 'precarious', 'tragically', '<UNK>', 'by', 'violence', 'drug', 'abuse', 'and', 'isolation', '.', '<EOS>']
# predict:  ['in', 'the', 'world', 'i', 've', 'been', 'making', 'the', 'inner', 'inner', 'of', 'the', 'nasty', 'toxic', 'sexuality', 'in', 'the', 'depression', 'and', 'sexuality', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['niềm', 'quyết_tâm', 'tụ', 'lại', 'và', 'một', 'giọng', 'lặng_lẽ', 'nói', 'tôi', 'sẽ', 'đi', 'vòng', 'qua', 'mọi', 'trở_ngại', '.', '<UNK>', '<EOS>']
# target:  ['there', 'was', 'a', 'gathering', 'of', 'resolve', 'and', 'a', 'quiet', 'voice', 'saying', 'quot', 'i', 'will', 'bypass', 'you', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['and', 'so', 'the', 'voice', 'and', 'says', 'quot', 'i', 'm', 'going', 'to', 'go', 'through', 'the', 'whole', 'voice', '.', 'quot', '<UNK>', '<EOS>']
# -----------------------------------------------
#
# input:  ['hãy', 'tưởng_tượng', 'ông', 'một', 'người', 'cộng_sản', 'tiến', 'vào', '<UNK>', 'đối_diện', 'sự_thật', 'rằng', 'cả', 'cuộc_đời', 'ông', 'đã', '<UNK>', '.', '<EOS>']
# target:  ['imagine', 'him', 'as', 'the', 'communists', 'enter', '<UNK>', 'confronting', 'the', 'fact', 'that', 'his', 'life', 'had', 'been', 'a', 'complete', 'waste', '.', '<EOS>']
# predict:  ['imagine', 'a', 'contemporary', 'person', 'who', 's', 'attending', 'his', 'own', 'identity', 'and', 'indeed', 'he', 's', 'destined', 'to', 'be', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'mảnh_ghép', 'tiếp_theo', 'của', 'bức', 'tranh', 'là', 'về', 'bốn', 'người', 'phụ_nữ', 'ba', 'thế_hệ', 'cùng_nhau', 'định_hình', 'cuộc_sống', 'mới', '.', '<EOS>']
# target:  ['and', 'the', 'next', 'piece', 'of', 'the', 'jigsaw', 'is', 'about', 'four', 'women', 'across', 'three', 'generations', 'shaping', 'a', 'new', 'life', 'together', '.', '<EOS>']
# predict:  ['and', 'the', 'next', 'picture', 'is', 'the', 'next', 'three', 'picture', 'of', 'the', 'women', 'who', 'are', 'three', 'times', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mảnh_ghép', 'tiếp_theo', 'của', 'tấm', 'hình', 'là', 'một', 'con', 'thuyền', 'trong', 'sớm', 'hoàng_hôn', 'lặng_lẽ', 'trườn', 'ra', 'biển', '.', '<EOS>']
# target:  ['the', 'next', 'piece', 'of', 'the', 'jigsaw', 'is', 'of', 'a', 'boat', 'in', 'the', 'early', 'dawn', 'slipping', 'silently', 'out', 'to', 'sea', '.', '<EOS>']
# predict:  ['the', 'next', 'one', 'is', 'a', 'boat', 'on', 'a', 'boat', 'in', 'the', 'boat', 'of', 'the', 'boat', 'in', 'the', 'boat', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nếu', 'chúng_tôi', 'bị', 'bắt', 'đầu_tiên', 'là', 'em', 'tôi', 'và', 'tôi', 'rồi', 'mẹ', 'và', 'bà', 'sẽ', 'uống', '.', '<EOS>']
# target:  ['if', 'we', 'were', 'captured', 'first', 'my', 'sister', 'and', 'i', 'then', 'she', 'and', 'my', 'grandmother', 'would', 'drink', '.', '<EOS>']
# predict:  ['if', 'we', 'were', 'first', 'i', 'was', 'going', 'to', 'take', 'my', 'first', 'and', 'i', 'would', 'like', 'to', 'go', 'and', 'she', 's', 'gonna', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi', 'làm_việc', 'trong', 'trang_trại', 'rồi', 'trong', 'dây_chuyền', 'sản_xuất', 'ô_tô', 'làm_việc', 'tuần', 'sáu', 'ngày', 'hai', 'ca', '.', '<EOS>']
# target:  ['my', 'mother', 'worked', 'on', 'farms', 'then', 'on', 'a', 'car', 'assembly', 'line', 'working', 'six', 'days', 'double', 'shifts', '.', '<EOS>']
# predict:  ['my', 'mom', 'worked', 'in', 'six', 'weeks', 'six', 'weeks', 'and', 'she', 'worked', 'in', 'a', 'second', 'six', 'hours', 'six', 'weeks', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhiệm_vụ', 'của', 'tôi', 'là', 'thức', 'đến', 'khi', 'mẹ', 'bị', 'ác_mộng', 'hành_hạ', 'để', 'gọi', 'mẹ', 'dậy', '.', '<EOS>']
# target:  ['and', 'my', 'job', 'was', 'to', 'stay', 'awake', 'until', 'her', 'nightmares', 'came', 'so', 'i', 'could', 'wake', 'her', '.', '<EOS>']
# predict:  ['my', 'mother', 'was', 'to', 'go', 'to', 'the', 'clinic', 'to', 'call', 'my', 'mother', 'to', 'call', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ngôn_từ', 'qua', 'bao', 'năm', 'tháng', 'là', 'bạn', 'đồng_hành', 'với', 'ông', 'giờ', 'quay', 'ra', 'chế_giễu', 'ông', '.', '<EOS>']
# target:  ['words', 'for', 'so', 'long', 'his', 'friends', 'now', 'mocked', 'him', '.', '<EOS>']
# predict:  ['twenty', 'months', 'later', 'in', 'the', 'u', '.k', '.', 'now', 'he', 's', 'interacting', 'with', 'him', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'mở', 'cửa_hàng', 'máy_tính', 'rồi', 'học', 'nghề', 'chuyên_viên', 'thẩm_mĩ', 'và', 'mở', 'một', 'cơ_sở', 'kinh_doanh', 'khác', '.', '<EOS>']
# target:  ['she', 'opened', 'a', 'computer', 'store', 'then', 'studied', 'to', 'be', 'a', '<UNK>', 'and', 'opened', 'another', 'business', '.', '<EOS>']
# predict:  ['she', 'went', 'through', 'the', 'computer', 'and', 'open', 'her', 'open', 'and', 'open', 'her', 'open', 'a', 'business', 'and', 'open', 'the', 'other', 'business', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['trong', 'một', 'thế_giới', 'tôi', 'là', 'học_sinh', 'gốc', 'á', 'điển_hình', 'đòi_hỏi', 'khắc_nghiệt', 'từ', 'chính', 'mình', '.', '<EOS>']
# target:  ['in', 'one', 'i', 'was', 'the', 'classic', 'asian', 'student', 'relentless', 'in', 'the', 'demands', 'that', 'i', 'made', 'on', 'myself', '.', '<EOS>']
# predict:  ['in', 'a', 'world', 'i', 'was', 'a', 'word', 'of', 'the', 'word', 'quot', 'the', 'root', 'quot', 'which', 'is', 'the', 'right', 'path', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['hai', 'đôi', 'tất', 'để', 'đi', 'học', 'mỗi', 'đôi', 'để', 'che', 'lỗ_thủng', 'trên', 'đôi', 'kia', '.', '<EOS>']
# target:  ['two', 'pairs', 'of', 'stockings', 'for', 'school', 'each', 'to', 'hide', 'the', 'holes', 'in', 'the', 'other', '.', '<EOS>']
# predict:  ['two', 'of', 'them', 'are', 'going', 'to', 'get', 'the', 'ball', 'on', 'the', 'belly', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['như', 'hầu_hết', 'người_lớn', 'trên', 'thuyền', 'mẹ', 'tôi', 'mang', 'theo', 'một', 'chai', 'thuốc_độc', 'nhỏ', '.', '<EOS>']
# target:  ['like', 'most', 'adults', 'on', 'the', 'boat', 'my', 'mother', 'carried', 'a', 'small', 'bottle', 'of', 'poison', '.', '<EOS>']
# predict:  ['as', 'most', 'of', 'my', 'grandmother', 'rode', 'on', 'a', 'boat', 'i', 'sold', 'a', 'little', 'frog', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['thế_mà', 'mẹ', 'vẫn', 'kiếm', 'ra', 'thời_gian', 'học', 'tiếng', 'anh', 'và', 'lấy', 'bằng', 'công_nghệ_thông_tin', '.', '<EOS>']
# target:  ['somehow', 'she', 'found', 'time', 'to', 'study', 'english', 'and', 'gain', 'it', 'qualifications', '.', '<EOS>']
# predict:  ['so', 'she', 'takes', 'time', 'to', 'take', 'a', 'mom', 'and', 'he', 's', 'got', 'a', 'tech', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['một', 'bộ', 'đồng_phục', 'dài', 'tới', 'mắt_cá', 'vì', 'phải', 'dành', 'mặc', 'đến', 'sáu', 'năm', '.', '<EOS>']
# target:  ['a', 'school', 'uniform', 'down', 'to', 'the', 'ankles', 'because', 'it', 'had', 'to', 'last', 'for', 'six', 'years', '.', '<EOS>']
# predict:  ['a', 'year', 'old', 'foot', 'is', 'a', 'foot', 'to', 'walk', 'to', 'the', 'foot', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'cuộc_đời', 'ta', 'nhiều', 'hơn', 'những', 'gì', 'ta', 'lưu', 'trong', 'kí_ức', 'nhiều', '.', '<EOS>']
# target:  ['but', 'our', 'lives', 'are', 'much', 'more', 'than', 'our', 'memories', '.', '<EOS>']
# predict:  ['but', 'we', 'can', 'do', 'anything', 'more', 'than', 'in', 'our', 'lives', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['hãy', 'tưởng_tượng', 'mảnh', 'đầu_tiên', 'một', 'người', 'đàn_ông', 'đốt_cháy', 'sự_nghiệp', 'cả', 'đời', 'mình', '.', '<EOS>']
# target:  ['imagine', 'the', 'first', 'piece', 'a', 'man', 'burning', 'his', 'life', 's', 'work', '.', '<EOS>']
# predict:  ['imagine', 'a', 'story', 'of', 'the', 'first', 'one', 'of', 'the', 'first', 'one', 'of', 'the', 'first', 'person', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['hãy', 'để', 'tôi', 'kể', 'cho', 'các', 'bạn', 'về', 'vài', 'mảnh_ghép', 'nhé', '.', '<EOS>']
# target:  ['let', 'me', 'tell', 'you', 'about', 'some', 'of', 'the', 'pieces', '.', '<EOS>']
# predict:  ['let', 'me', 'tell', 'you', 'some', 'of', 'the', 'first', 'few', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi', 'em_gái', 'và', 'tôi', 'ngủ', 'chung', 'trên', 'một', 'chiếc', 'giường', '.', '<EOS>']
# target:  ['my', 'mother', 'my', 'sister', 'and', 'i', 'slept', 'in', 'the', 'same', 'bed', '.', '<EOS>']
# predict:  ['my', 'mom', 'and', 'my', 'mom', 's', 'sleep', 'in', 'a', 'bed', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['sau', 'ba', 'tháng', 'trong', 'trại', 'tị_nạn', 'tập_trung', 'chúng_tôi', 'đặt_chân', 'tới', 'melbourne', '.', '<EOS>']
# target:  ['after', 'three', 'months', 'in', 'a', 'refugee', 'camp', 'we', 'landed', 'in', 'melbourne', '.', '<EOS>']
# predict:  ['after', 'three', 'months', 'of', 'the', 'month', 'we', 'went', 'to', 'the', 'prison', 'to', 'rwanda', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['bà', 'tôi', 'chưa', 'bao_giờ', 'cho_phép', 'tôi', 'quên', 'cuộc_đời', 'của', 'ông', '.', '<EOS>']
# target:  ['my', 'grandmother', 'never', 'let', 'me', 'forget', 'his', 'life', '.', '<EOS>']
# predict:  ['she', 'never', 'never', 'told', 'me', 'to', 'forget', 'my', 'life', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nỗi', 'sợ_hãi', 'lớn', 'nhất_là', 'cướp_biển', 'nạn', 'cưỡng_hiếp', 'và', 'cái', 'chết', '.', '<EOS>']
# target:  ['the', 'greatest', 'fear', 'was', 'of', 'pirates', 'rape', 'and', 'death', '.', '<EOS>']
# predict:  ['the', 'fear', 'death', 'is', 'that', 'the', 'death', 'of', 'death', 'and', 'death', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nó', 'là', 'một', 'trò_chơi', 'ghép', 'hình', 'vẫn', 'đang', 'được', 'xếp', '.', '<EOS>']
# target:  ['it', 'is', 'a', 'jigsaw', 'puzzle', 'still', 'being', 'put', 'together', '.', '<EOS>']
# predict:  ['it', 's', 'a', 'game', 'that', 's', 'still', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'không', 'bao_giờ', 'chấp_nhận', 'được', 'là', 'mẹ', 'sẽ', 'không', 'thành_công', '.', '<EOS>']
# target:  ['it', 'was', 'inconceivable', 'to', 'her', 'that', 'she', 'would', 'not', 'succeed', '.', '<EOS>']
# predict:  ['she', 'was', 'never', 'going', 'to', 'be', 'successful', '.', 'she', 'never', 'succeed', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'qua', 'năm_tháng', 'rất', 'nhiều', 'em', 'đã', 'được', 'giúp_đỡ', '.', '<EOS>']
# target:  ['but', 'so', 'many', 'over', 'the', 'years', 'were', 'helped', '.', '<EOS>']
# predict:  ['but', 'over', 'a', 'few', 'years', 'she', 'has', 'been', 'working', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['không', 'có', 'quả', 'táo', 'nào', 'ngon', 'được', 'đến', 'thế', '.', '<EOS>']
# target:  ['no', 'apple', 'has', 'ever', 'tasted', 'the', 'same', '.', '<EOS>']
# predict:  ['no', 'apples', 'apples', 'apples', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi', 'bị', 'bao_nhiêu', 'ác_mộng', 'về', 'chiếc', 'thuyền', '.', '<EOS>']
# target:  ['my', 'mother', 'suffered', 'from', 'nightmares', 'all', 'about', 'the', 'boat', '.', '<EOS>']
# predict:  ['my', 'mom', 'was', 'how', 'much', 'was', 'the', 'vessel', 'of', 'the', 'vessel', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['chúng_tôi', 'kiếm', 'tìm', 'trợ_cấp', 'và', 'những', 'nhà', 'tài_trợ', '.', '<EOS>']
# target:  ['grants', 'and', 'sponsors', 'were', 'sought', '.', '<EOS>']
# predict:  ['we', 'looked', 'at', 'the', 'vocational', 'and', 'the', 'producers', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mùi', 'từ', 'các', 'cửa_hàng', 'đến', 'từ', 'khắp', 'thế_giới', '.', '<EOS>']
# target:  ['the', 'smells', 'from', 'shop', 'doors', 'were', 'from', 'the', 'rest', 'of', 'the', 'world', '.', '<EOS>']
# predict:  ['the', 'word', 'from', 'the', 'world', 'from', 'all', 'around', 'the', 'world', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['có', 'chút', 'gì', 'cứng', 'lại', 'trong', 'tôi', '.', '<EOS>']
# target:  ['something', '<UNK>', 'inside', 'me', '.', '<EOS>']
# predict:  ['there', 's', 'a', 'little', 'bit', 'of', 'my', 'throat', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'chưa', 'bao_giờ', 'gặp', 'ông', 'ngoài', 'đời', '.', '<EOS>']
# target:  ['i', 'never', 'knew', 'him', 'in', 'real', 'life', '.', '<EOS>']
# predict:  ['i', 'never', 'met', 'him', 'in', 'his', 'life', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'không', 'biết', 'nói', 'về', 'cái_gì', 'hết', '.', '<EOS>']
# target:  ['i', 'didn', 't', 'know', 'how', 'to', 'talk', 'about', 'anything', '.', '<EOS>']
# predict:  ['i', 'don', 't', 'know', 'what', 's', 'going', 'on', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'không', 'biết', 'cách', 'dùng', 'thìa', 'dĩa', '.', '<EOS>']
# target:  ['i', 'didn', 't', 'know', 'how', 'to', 'use', 'the', 'cutlery', '.', '<EOS>']
# predict:  ['i', 'don', 't', 'know', 'how', 'to', 'use', 'the', 'needle', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tất_cả', 'những', 'người_lớn', 'đều', 'biết', 'các', 'rủi_ro', '.', '<EOS>']
# target:  ['all', 'the', 'adults', 'knew', 'the', 'risks', '.', '<EOS>']
# predict:  ['all', 'of', 'these', 'kids', 'are', 'highly', 'stressed', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'không', 'biết', 'nói_chuyện', 'về', 'rượu', '.', '<EOS>']
# target:  ['i', 'didn', 't', 'know', 'how', 'to', 'talk', 'about', 'wine', '.', '<EOS>']
# predict:  ['i', 'don', 't', 'know', 'what', 'i', 'm', 'talking', 'about', 'the', 'wine', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'sống', 'trong', 'hai', 'thế_giới', 'song_song', '.', '<EOS>']
# target:  ['i', 'lived', 'in', 'parallel', 'worlds', '.', '<EOS>']
# predict:  ['i', 'was', 'living', 'in', 'the', 'world', 'world', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ông', 'là', 'ông', 'của', 'tôi', '.', '<EOS>']
# target:  ['he', 'is', 'my', 'grandfather', '.', '<EOS>']
# predict:  ['he', 'was', 'my', 'grandfather', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ông', 'qua_đời', 'bị', 'lịch_sử', '<UNK>', '.', '<EOS>']
# target:  ['he', 'died', 'broken', 'by', 'history', '.', '<EOS>']
# predict:  ['he', 'was', 'born', 'in', 'the', 'present', 'of', 'history', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'không', 'biết', 'các', 'qui_trình', '.', '<EOS>']
# target:  ['i', 'didn', 't', 'know', 'the', 'protocols', '.', '<EOS>']
# predict:  ['i', 'don', 't', 'know', 'the', 'rules', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ông', 'rút_lui', 'vào', 'yên_lặng', '.', '<EOS>']
# target:  ['he', 'retreated', 'into', 'silence', '.', '<EOS>']
# predict:  ['he', 'rides', 'his', 'bleeding', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['câu_chuyện', 'này', 'chưa', 'kết_thúc', '.', '<EOS>']
# target:  ['this', 'is', 'not', 'a', 'finished', 'story', '.', '<EOS>']
# predict:  ['this', 'story', 'was', 'not', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['các', 'trung_tâm', 'được', 'thành_lập', '.', '<EOS>']
# target:  ['centers', 'were', 'established', '.', '<EOS>']
# predict:  ['the', 'centers', 'are', 'built', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['chúng_tôi', 'rất', 'nghèo', '.', '<EOS>']
# target:  ['we', 'were', 'poor', '.', '<EOS>']
# predict:  ['we', 're', 'very', 'poor', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['về', 'nhà_ở', 'đâu', '?', '<EOS>']
# target:  ['go', 'home', 'to', 'where', '?', '<EOS>']
# predict:  ['where', 'is', 'the', 'land', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'cùng_lúc', 'tôi', 'nhận', 'ra', 'rằng', 'làm', 'kẻ', 'ngoại_đạo', 'cũng', 'được', '<UNK>', 'người', 'mới', 'đến', 'mới', 'hiện_diện', 'và', 'không', 'chỉ', 'là', 'được', 'thôi', 'mà', 'là', 'một', 'điều', 'ta', 'cần', 'biết_ơn', 'có_thể', 'là', 'một', 'món', 'quà', 'từ', 'chiếc', 'thuyền', '.', '<EOS>']
# target:  ['and', 'i', 'realized', 'at', 'the', 'same', 'time', 'that', 'it', 'is', 'okay', 'to', 'be', 'an', 'outsider', 'a', 'recent', 'arrival', 'new', 'on', 'the', 'scene', 'and', 'not', 'just', 'okay', 'but', 'something', 'to', 'be', 'thankful', 'for', 'perhaps', 'a', 'gift', 'from', 'the', 'boat', '.', '<EOS>']
# predict:  ['and', 'while', 'i', 'realized', 'that', 'the', 'new', 'man', 'who', 'was', 'not', 'only', 'the', 'new', 'and', 'the', 'new', 'thing', 'that', 'was', 'not', 'only', 'a', 'new', 'guy', 'who', 'would', 'be', 'a', 'happy', 'experience', 'from', 'a', 'new', 'guy', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'tôi', 'cho_rằng', 'những', 'gì', 'mà', 'chúng_ta', 'nhận_thấy', 'được', 'đó', 'là', 'nếu', 'bạn', 'là', 'giáo_viên', 'lời_nói', 'của', 'bạn', 'sẽ', 'có', 'ý_nghĩa', 'nhưng', 'nếu', 'bạn', 'là', 'một', 'giáo_viên', 'giàu', 'lòng', 'trắc_ẩn', 'lời_nói', 'của', 'bạn', 'đặc_biệt', 'có', 'ý_nghĩa', '.', '<EOS>']
# target:  ['and', 'i', 'think', 'what', 'we', 've', 'learned', 'is', 'that', 'if', 'you', 're', 'a', 'teacher', 'your', 'words', 'can', 'be', 'meaningful', 'but', 'if', 'you', 're', 'a', 'compassionate', 'teacher', 'they', 'can', 'be', 'especially', 'meaningful', '.', '<EOS>']
# predict:  ['and', 'what', 'i', 'think', 'is', 'if', 'you', 're', 'lucky', 'you', 'have', 'a', 'good', 'idea', 'if', 'you', 're', 'lucky', 'but', 'you', 'have', 'a', 'strong', 'belief', 'if', 'you', 'have', 'a', 'teacher', 'to', 'be', 'admired', 'as', 'if', 'you', 'have', 'a', 'strong', 'interest', '.']
# -----------------------------------------------
#
# input:  ['bởi_vì', 'chúng_tôi', 'là', 'ai', 'và', 'cuộc_đời', 'đã', 'định_hình', 'chúng_tôi', 'như', 'thế_nào', 'giờ', 'chúng_tôi', 'có_thể', 'thấy', 'rằng', 'những', 'người', 'đàn_ông', 'mà', 'có_thể', 'đã', 'đi', 'vào', 'cuộc_đời', 'của', 'chúng_tôi', 'sẽ', 'ngăn_trở', 'chúng_tôi', '.', '<EOS>']
# target:  ['given', 'who', 'we', 'were', 'and', 'how', 'life', 'had', 'shaped', 'us', 'we', 'can', 'now', 'see', 'that', 'the', 'men', 'who', 'might', 'have', 'come', 'into', 'our', 'lives', 'would', 'have', '<UNK>', 'us', '.', '<EOS>']
# predict:  ['because', 'we', 'were', 'and', 'who', 'who', 'had', 'been', 'able', 'to', 'see', 'how', 'we', 'could', 'measure', 'our', 'lives', 'that', 'we', 'could', 'see', 'how', 'we', 'were', 'going', 'to', 'see', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'dầu', 'vấp', 'phải', 'sự', 'không', 'ủng_hộ', 'của', 'chồng', 'bà', 'gây', 'chấn_động', 'khi', 'kiện', 'ông', 'ta', 'ra_toà', 'và', 'tự', 'khởi_tố', 'và', 'còn', 'gây', 'chấn_động', 'mạnh', 'hơn', 'khi', 'bà', 'thắng', 'kiện', '.', '<EOS>']
# target:  ['with', 'no', 'support', 'from', 'her', 'husband', 'she', 'caused', 'a', 'sensation', 'by', 'taking', 'him', 'to', 'court', 'and', 'prosecuting', 'her', 'own', 'case', 'and', 'a', 'far', 'greater', 'sensation', 'when', 'she', 'won', '.', '<EOS>']
# predict:  ['and', 'the', 'oil', 'didn', 't', 'have', 'to', 'be', 'the', 'victim', 'of', 'the', 'victim', 'and', 'the', 'victim', 'was', 'the', 'victim', 'of', 'the', 'rape', 'and', 'the', 'judge', 'was', 'the', 'case', 'when', 'she', 'was', 'the', 'battle', 'of', 'the', 'coin', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'một', 'trong', 'những', 'điều', 'nổi_bật', 'nhất', 'mà', 'tôi', 'nhận', 'ra', 'được', 'trong', 'khoảng', 'thời_gian', 'ngắn', 'tôi', 'đến', 'đây', 'đó', 'là', 'ted', 'có_một', 'bản', 'sắn', 'riêng', 'của', 'mình', '.', '<EOS>']
# target:  ['and', 'one', 'of', 'the', 'things', 'that', 's', 'emerged', 'in', 'my', 'short', 'time', 'here', 'is', 'that', 'ted', 'has', 'an', 'identity', '.', '<EOS>']
# predict:  ['and', 'one', 'of', 'the', 'most', 'transformative', 'i', 've', 'been', 'here', 'is', 'that', 'i', 've', 'been', 'here', 'to', 'this', 'is', 'a', 'ted', 'event', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['còn', 'nếu', 'bạn', 'là', 'một', 'bác_sĩ', 'bạn', 'có_thể', 'làm', 'vài', 'điều', 'tốt', 'nhưng', 'nếu', 'bạn', 'là', 'một', 'bác_sĩ', 'tận_tâm', 'bạn', 'có_thể', 'làm', 'thêm', 'nhiều', 'điều', 'tốt', 'khác', '.', '<EOS>']
# target:  ['if', 'you', 're', 'a', 'doctor', 'you', 'can', 'do', 'some', 'good', 'things', 'but', 'if', 'you', 're', 'a', 'caring', 'doctor', 'you', 'can', 'do', 'some', 'other', 'things', '.', '<EOS>']
# predict:  ['but', 'if', 'you', 'can', 'do', 'a', 'doctor', 'or', 'doctors', 'you', 'can', 'do', 'something', 'better', 'but', 'you', 're', 'going', 'to', 'do', 'a', 'lot', 'of', 'things', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['liệu', 'tôi', 'có_thể', 'cho', 'con', 'tôi', 'một', 'mạn_thuyền', 'trong', 'cuộc_đời', 'mạnh_mẽ', 'chìm', 'vào', 'mỗi', 'đợt', 'sóng', '<UNK>', 'đều_đều', 'không', 'đứt', 'chân_trời', 'mênh_mông', 'không', 'hứa_hẹn', 'điều', 'gì', 'cả', '?', '<EOS>']
# target:  ['can', 'i', 'give', 'them', 'a', 'bow', 'in', 'their', 'lives', 'dipping', 'bravely', 'into', 'each', 'wave', 'the', '<UNK>', 'and', 'steady', 'beat', 'of', 'the', 'engine', 'the', 'vast', 'horizon', 'that', 'guarantees', 'nothing', '?', '<EOS>']
# predict:  ['could', 'i', 'be', 'a', 'little', 'deep', 'in', 'a', 'life', 'in', 'a', 'deep', '<UNK>', '<UNK>', '<UNK>', 'that', 'i', 'would', 'have', 'to', 'do', 'with', 'the', '<UNK>', 'and', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['giờ_đây', 'tôi', 'đã', 'bước', 'ra', 'ngoài', "'", 'vùng', 'an_toàn', "'", 'của', 'mình', 'đủ', 'đẻ', 'biết', 'rằng', 'vâng', 'thế_giới', 'có_thể', 'sụp_đổ', 'nhưng', 'không', 'theo', 'cách', 'bạn', 'sợ_hãi', 'đâu', '.', '<EOS>']
# target:  ['i', 'have', 'stepped', 'outside', 'my', 'comfort', 'zone', 'enough', 'now', 'to', 'know', 'that', 'yes', 'the', 'world', 'does', 'fall', 'apart', 'but', 'not', 'in', 'the', 'way', 'that', 'you', 'fear', '.', '<EOS>']
# predict:  ['now', 'i', 've', 'been', 'traveling', 'on', 'my', 'own', 'world', 'to', 'make', 'sure', 'that', 'the', 'world', 'is', 'not', 'remote', 'but', 'you', 'can', 't', 'see', 'anywhere', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'cũng', 'đã', 'trải', 'qua', 'một', 'thời_gian', 'dài', 'sống', 'trong', 'cộng_đồng', 'của', 'những', 'người', 'có', 'thu_nhập', 'thấp', 'với', 'những', 'dự_án', 'và', 'nơi', 'tràn_ngập', 'sự', 'tuyệt_vọng', '<EOS>']
# target:  ['i', 'spend', 'most', 'of', 'my', 'time', 'in', 'very', 'low', 'income', 'communities', 'in', 'the', 'projects', 'and', 'places', 'where', 'there', 's', 'a', 'great', 'deal', 'of', 'hopelessness', '.', '<EOS>']
# predict:  ['i', 've', 'been', 'spending', 'through', 'a', 'long', 'time', 'in', 'the', 'community', 'of', 'people', 'who', 'have', 'been', 'working', 'with', 'low', 'income', 'and', 'low', 'levels', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'đôi_khi', 'bạn', 'đến', 'với', 'ted', 'nó', 'mang_lại', 'ý_nghĩa', 'và', 'sức_mạnh', 'cho', 'bạn', 'mà', 'nếu_như', 'bạn', 'không', 'đến', 'bạn', 'sẽ', 'không', 'có', 'được', 'sức_mạnh', 'như_thế', '<EOS>']
# target:  ['and', 'sometimes', 'when', 'it', 'comes', 'through', 'ted', 'it', 'has', 'meaning', 'and', 'power', 'that', 'it', 'doesn', 't', 'have', 'when', 'it', 'doesn', 't', '.', '<EOS>']
# predict:  ['and', 'you', 'can', 'come', 'to', 'the', 'ted', 'and', 'you', 'can', 't', 'give', 'it', 'to', 'the', 'power', 'that', 'if', 'you', 'don', 't', 'want', 'to', 'have', 'it', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['thế', 'là', 'tôi', 'nói', 'về', 'nạn', 'thanh_niên', 'thất_nghiệp', 'và', 'giáo_dục', 'và', 'về', 'những', 'người', 'bị', 'xã_hội', 'cách_li', 'bị', 'mất', 'quyền_lợi', 'và', 'bỏ_rơi', '.', '<EOS>']
# target:  ['so', 'i', 'spoke', 'out', 'on', 'youth', 'unemployment', 'and', 'education', 'and', 'the', 'neglect', 'of', 'the', 'marginalized', 'and', 'the', '<UNK>', '.', '<EOS>']
# predict:  ['so', 'i', 'was', 'about', 'the', '<UNK>', 'and', 'inertia', 'and', 'the', 'people', 'who', 'were', 'being', 'disconnected', 'and', 'displaced', 'and', 'displaced', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'tôi', 'đến', 'đây', 'tôi', 'lại', 'được', 'khuyến_khích', 'và', 'rồi', 'tôi', 'lắng_nghe', 'chính', 'điều', 'này', 'đã', 'tiếp', 'thêm', 'nghị_lực', 'cho', 'tôi', 'rất', 'nhiều', '<EOS>']
# target:  ['and', 'being', 'here', 'at', 'ted', 'and', 'seeing', 'the', 'stimulation', 'hearing', 'it', 'has', 'been', 'very', 'very', '<UNK>', 'to', 'me', '.', '<EOS>']
# predict:  ['and', 'i', 'was', 'going', 'to', 'go', 'and', 'i', 'gave', 'this', 'story', 'to', 'me', 'and', 'i', 'was', 'going', 'to', 'make', 'a', 'lot', 'of', 'a', 'lot', 'of', 'money', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'đã', 'phải', 'trải_qua', 'thời_gian', 'dài', 'trong', 'tù', 'sau', 'song', 'sắt', 'và', 'cả', 'trong', 'nhà_tù', 'dành', 'cho', 'người', 'bị', 'kết_án', 'tử_hình', '.', '<EOS>']
# target:  ['i', 'spend', 'most', 'of', 'my', 'time', 'in', 'jails', 'in', 'prisons', 'on', 'death', 'row', '.', '<EOS>']
# predict:  ['i', 'was', 'spending', 'a', 'long', 'time', 'in', 'prison', 'prison', 'and', 'prison', 'prison', 'were', 'in', 'prison', 'for', 'a', 'prison', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'thu_thập', 'được', 'một', 'đội', 'nhỏ', 'với', 'chúng_tôi', 'cái', 'tựa', 'không', 'làm', 'được', 'đâu', 'là', 'một', 'thử_thách', 'hấp_dẫn', 'không', 'cưỡng', 'được', '.', '<EOS>']
# target:  ['i', 'gathered', 'around', 'me', 'a', 'small', 'team', 'of', 'people', 'for', 'whom', 'the', 'label', 'quot', 'it', 'can', 't', 'be', 'done', 'quot', 'was', 'an', 'irresistible', 'challenge', '.', '<EOS>']
# predict:  ['i', 'started', 'a', 'team', 'with', 'a', 'backpack', 'that', 'was', 'not', 'exactly', 'the', 'same', 'thing', 'that', 'was', 'a', 'little', 'bit', 'of', 'a', 'balancing', 'solution', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['bời', 'vì', 'làm_người', 'đứng', 'phía', 'trong', 'có_thể', 'dễ', 'bị', 'thu_hẹp', 'tầm_nhìn', 'có_thể', 'dễ_dàng', 'chấp_nhận', 'những', 'định_kiến', 'trong', 'khu_vực', 'của', 'bạn', '.', '<EOS>']
# target:  ['because', 'being', 'an', 'insider', 'can', 'so', 'easily', 'mean', 'collapsing', 'the', 'horizons', 'can', 'so', 'easily', 'mean', 'accepting', 'the', 'presumptions', 'of', 'your', 'province', '.', '<EOS>']
# predict:  ['because', 'of', 'course', 'you', 'can', 'unlock', 'the', 'gap', 'in', 'the', 'easy', 'part', 'of', 'your', 'senses', 'are', 'limited', 'to', 'the', 'west', 'of', 'your', 'senses', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'gặp', 'những', 'người', 'từ', 'mọi', 'tầng_lớp', 'xã_hội', 'rất', 'nhiều', 'người', 'đang', 'làm_việc', 'họ', 'yêu_thích', 'sống', 'tại', 'ranh_giới', 'của', 'cơ_hội', '.', '<EOS>']
# target:  ['i', 'met', 'people', 'from', 'all', 'walks', 'of', 'life', 'so', 'many', 'of', 'them', 'doing', 'the', 'thing', 'they', 'loved', 'living', 'on', 'the', 'frontiers', 'of', 'possibility', '.', '<EOS>']
# predict:  ['i', 'met', 'people', 'from', 'the', 'people', 'who', 'live', 'in', 'the', 'world', 'that', 'are', 'living', 'in', 'the', 'business', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'nếu', 'tôi', 'có_thể', 'cho', 'điều', 'đó', 'và', 'vẫn', 'thấy', 'con', 'tôi', 'yên_bình', 'vượt_qua', 'tôi', 'sẽ', 'cho', 'con', 'tôi', '.', '<EOS>']
# target:  ['but', 'if', 'i', 'could', 'give', 'it', 'and', 'still', 'see', 'them', 'safely', 'through', 'i', 'would', '.', '<EOS>']
# predict:  ['but', 'if', 'i', 'could', 'still', 'see', 'my', 'children', 'and', 'i', 'still', 'give', 'my', 'child', 'to', 'fight', 'my', 'child', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['có_một', 'nguồn', 'năng_lượng', 'ngoài', 'đó', 'một', 'niềm', 'lạc_quan', '<UNK>', 'một', 'sự', 'pha_trộn', 'kì_lạ', 'của', 'sự', 'khiêm_nhường', 'và', 'liều_lĩnh', '.', '<EOS>']
# target:  ['there', 'was', 'an', 'energy', 'there', 'an', '<UNK>', 'optimism', 'a', 'strange', 'mixture', 'of', 'humility', 'and', 'daring', '.', '<EOS>']
# predict:  ['there', 's', 'a', 'vibrant', 'resource', 'of', 'a', 'magical', 'source', 'of', 'courage', 'and', 'unity', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'đang', 'tắm', 'trong', 'một', 'phòng', 'khách_sạn', 'ở', 'sydney', 'vào', 'thời_khắc', 'bà', 'mất', 'cách', 'đó', 'dặm', 'ở', 'melbourne', '.', '<EOS>']
# target:  ['i', 'was', 'taking', 'a', 'shower', 'in', 'a', 'hotel', 'room', 'in', 'sydney', 'the', 'moment', 'she', 'died', 'miles', 'away', 'in', 'melbourne', '.', '<EOS>']
# predict:  ['i', 'was', 'in', 'a', 'cafe', 'in', 'a', 'cafe', 'in', 'a', 'way', 'she', 'was', 'miles', 'away', 'in', 'the', 'morning', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['bà', 'lớn', 'lên', 'trong', 'thời_kì', 'mà', '<UNK>', 'là', 'chuẩn_mực', 'xã_hội', 'và', '<UNK>', 'địa_phương', 'có', 'quyền', '<UNK>', 'sát', '.', '<EOS>']
# target:  ['she', 'grew', 'up', 'at', 'a', 'time', 'when', '<UNK>', 'was', 'the', 'social', 'norm', 'and', 'the', 'local', 'mandarin', 'was', 'the', 'person', 'who', 'mattered', '.', '<EOS>']
# predict:  ['she', 'was', 'in', 'the', 'area', 'of', 'the', 'world', 'was', 'the', 'ministry', 'of', 'the', 'constitutional', 'and', 'the', 'authority', 'of', 'the', 'ministry', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['vài', 'ngày', 'sau', 'chúng_tôi', 'đến', 'một', 'ngôi', 'chùa', 'đạo_phật', 'ở', '<UNK>', 'và', 'ngồi', 'quanh', 'quan_tài', 'của', 'bà', '.', '<EOS>']
# target:  ['a', 'few', 'days', 'later', 'we', 'went', 'to', 'a', 'buddhist', 'temple', 'in', '<UNK>', 'and', 'sat', 'around', 'her', 'casket', '.', '<EOS>']
# predict:  ['a', 'few', 'days', 'later', 'we', 'had', 'a', '<UNK>', 'warrior', 'in', 'her', '<UNK>', 'and', 'her', 'painted', 'in', 'the', 'movie', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['hầu', 'hết', 'ý_tưởng', 'của', 'chúng_tôi', 'đều', 'điên_khùng', 'nhưng', 'vài', 'ý_tưởng', 'vô_cùng', 'tuyệt_vời', 'và', 'chúng_tôi', 'tạo', 'ra', 'đột_phá', '.', '<EOS>']
# target:  ['most', 'of', 'our', 'ideas', 'were', 'crazy', 'but', 'a', 'few', 'were', 'brilliant', 'and', 'we', 'broke', 'through', '.', '<EOS>']
# predict:  ['most', 'of', 'us', 'we', 've', 'got', 'a', 'fantastic', 'idea', 'but', 'we', 've', 'got', 'some', 'ideas', 'and', 'we', 've', 'discovered', 'some', 'ideas', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'các', 'bạn', 'có_thể', 'nói', 'về', 'rất', 'nhiều', 'điều', 'có', 'ảnh_hưởng', 'trên', 'toàn', 'thế_giới', 'tại', 'đây', '.', '<EOS>']
# target:  ['and', 'you', 'can', 'actually', 'say', 'things', 'here', 'that', 'have', 'impacts', 'around', 'the', 'world', '.', '<EOS>']
# predict:  ['and', 'you', 'can', 'talk', 'about', 'this', 'whole', 'lot', 'of', 'different', 'things', 'around', 'the', 'world', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['mẹ', 'tôi', 'hỏi', 'nhà_sư', 'tại_sao', 'tay', 'mẹ', 'tôi', 'ấm', 'thế', 'mà', 'cả', 'người', 'lại', '<UNK>', '?', '<UNK>', '<EOS>']
# target:  ['she', 'asked', 'the', 'monk', 'quot', 'why', 'is', 'it', 'that', 'her', 'hand', 'is', 'so', 'warm', 'and', 'the', 'rest', 'of', 'her', 'is', 'so', 'cold', '?', 'quot', '<UNK>', '<EOS>']
# predict:  ['my', 'mother', 'said', 'quot', 'why', 'do', 'you', 'hate', 'the', 'gentle', 'of', 'the', 'other', 'people', '?', 'quot', '<UNK>', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'vâng', 'mẹ', 'của', 'chị', 'tan', 'hôm_nay', 'cũng', 'ở', 'đây', 'ở', 'hàng', 'ghế', 'thứ_tư', 'hay', 'năm', '.', '<EOS>']
# ...
# predict:  ['we', 'never', 'never', 'do', 'it', 'for', 'our', 'own', 'nation', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['làm', 'thế_nào', 'mà', 'việc', 'tấn_công', 'này', 'có_thể', 'khiến', 'ai', 'đó', 'mất_mạng', 'được', '?', '<EOS>']
# target:  ['so', 'how', 'do', 'people', 'die', 'as', 'the', 'result', 'of', 'a', 'hack', 'like', 'this', '?', '<EOS>']
# predict:  ['how', 'can', 'we', 'make', 'this', 'attacks', 'to', 'attack', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'động_lực', 'của', 'loại', 'tội_phạm', 'mạng', 'này', 'rất', 'đơn_giản', 'và', 'dễ_hiểu', '.', '<EOS>']
# target:  ['and', 'the', 'motives', 'of', 'online', 'criminals', 'are', 'very', 'easy', 'to', 'understand', '.', '<EOS>']
# predict:  ['and', 'the', 'cybercriminals', 'of', 'this', 'is', 'a', 'simple', 'viral', 'and', 'it', 's', 'very', 'simple', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'có_vẻ', 'như', 'không_ai', 'định', 'làm', 'ầm', 'lên', 'về', 'chuyện', 'này', '.', '<EOS>']
# target:  ['and', 'nobody', 'seems', 'to', 'be', 'making', 'a', 'fuss', 'about', 'it', '.', '<EOS>']
# predict:  ['and', 'the', 'only', 'thing', 'you', 're', 'going', 'to', 'do', 'is', 'that', 's', 'like', 'this', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['như', 'ở', 'đây', 'chúng_ta', 'có', '<UNK>', '<UNK>', 'đến', 'từ', 'thành_phố', 'kiev', 'ukraine', '<EOS>']
# target:  ['like', 'here', 'we', 'have', 'mr', '.', '<UNK>', '<UNK>', 'from', 'the', 'city', 'of', 'kiev', 'in', 'ukraine', '.', '<EOS>']
# predict:  ['as', 'we', 'have', 'this', 'wedding', 'from', 'the', 'syrian', 'republic', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'chúng_tôi', 'muốn', 'vật_liệu', 'này', 'tiếp_cận', 'được', 'với', 'mọi', 'người', '.', '<EOS>']
# target:  ['and', 'we', 'want', 'to', 'make', 'this', 'material', 'accessible', 'to', 'everyone', '.', '<EOS>']
# predict:  ['and', 'we', 'want', 'to', 'be', 'able', 'to', 'build', 'this', 'with', 'people', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'đó', 'chính_xác', 'là', 'điều', 'đã', 'xảy', 'ra', 'với', '<UNK>', '.', '<EOS>']
# target:  ['and', 'this', 'is', 'exactly', 'what', 'happened', 'with', 'the', 'case', 'of', '<UNK>', '.', '<EOS>']
# predict:  ['and', 'that', 's', 'exactly', 'what', 'happened', 'to', 'happen', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['điều', 'này', 'đang', 'diễn', 'ra', 'với', 'chúng', 'ta', 'ngày', 'hôm_nay', '.', '<EOS>']
# target:  ['this', 'is', 'happening', 'to', 'us', 'today', '.', '<EOS>']
# predict:  ['this', 'is', 'happening', 'today', 'we', 're', 'going', 'to', 'day', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['ai', 'đó', 'đã', 'xâm_nhập', 'vào', 'hệ_thống', 'và', 'phá_huỷ', 'nó', 'hoàn_toàn', '.', '<EOS>']
# target:  ['somebody', 'broke', 'in', 'and', 'they', 'hacked', 'it', 'thoroughly', '.', '<EOS>']
# predict:  ['somebody', 'has', 'been', 'transformed', 'into', 'the', 'system', 'and', 'it', 's', 'totally', 'entirely', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['bạn', 'sẽ', 'làm', 'gì', 'với', 'những', 'chứng_chỉ', 'đó', '?', '<EOS>']
# target:  ['what', 'do', 'you', 'do', 'with', 'certificates', '?', '<EOS>']
# predict:  ['what', 'do', 'you', 'do', 'with', 'those', 'kinds', 'of', 'equipment', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['đây', 'chính', 'là', 'trụ_sở', 'chính', 'của', 'công_ty', 'đó', '.', '<EOS>']
# target:  ['the', 'company', 'headquarters', 'are', 'right', 'here', '.', '<EOS>']
# predict:  ['this', 'is', 'the', 'company', 'of', 'the', 'company', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['trong', 'đó', 'có', 'tập', 'tài_liệu', 'được', 'đánh_dấu', '<UNK>', '<UNK>', '<EOS>']
# target:  ['among', 'those', 'papers', 'was', 'this', 'binder', 'entitled', 'quot', '<UNK>', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['in', 'this', 'condition', 'that', 'was', '<UNK>', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['matthew', 'anderson', 'tariq', 'al', '<UNK>', 'vân_vân', 'và', 'vân_vân', '.', '<EOS>']
# target:  ['this', 'is', 'matthew', 'anderson', 'tariq', 'al', '<UNK>', 'and', 'so', 'on', 'and', 'so', 'on', '.', '<EOS>']
# predict:  ['his', 'holiness', 'matthew', 'al', '<UNK>', '.', 'and', 'he', 's', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'có', 'là', 'câu', 'trả_lời', 'của_ông', 'ta', '.', '<EOS>']
# target:  ['and', 'his', 'answer', 'was', 'yes', '.', '<EOS>']
# predict:  ['and', 'that', 's', 'the', 'answer', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['đây', 'là', 'vladimir', '<UNK>', 'đến', 'từ', '<UNK>', 'estonia', '<EOS>']
# target:  ['here', 's', 'vladimir', '<UNK>', 'form', '<UNK>', 'in', 'estonia', '.', '<EOS>']
# predict:  ['this', 'is', 'from', 'the', '<UNK>', 'from', 'the', 'mississippi', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['hãy', 'tiến', 'lên', 'và', 'bắt_đầu', 'phát_minh', '.', '<EOS>']
# target:  ['so', 'go', 'ahead', 'and', 'start', 'inventing', '.', '<EOS>']
# predict:  ['let', 's', 'go', 'and', 'start', 'and', 'start', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['<UNK>', 'là', 'một', 'công_ty', 'cung_cấp', 'dịch_vụ', 'chứng_thực', '<EOS>']
# target:  ['well', '<UNK>', 'is', 'a', 'c', '.a', '.', '<EOS>']
# predict:  ['<UNK>', 'quot', 'is', 'a', 'company', 'of', 'service', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'tạo', 'ra', 'các', 'chứng_chỉ', 'giả_mạo', '.', '<EOS>']
# target:  ['and', 'issue', 'rogue', 'certificates', '.', '<EOS>']
# predict:  ['and', 'create', 'a', 'new', 'monopoly', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['thế', 'nên', '<UNK>', 'là', 'dự_án', 'mở', '.', '<EOS>']
# target:  ['so', '<UNK>', 'is', 'open', 'source', '.', '<EOS>']
# predict:  ['so', 'the', 'open', 'open', 'is', 'open', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['họ', 'bán', 'các', 'chứng', 'chỉ', 'bảo_mật', '<EOS>']
# target:  ['they', 'sell', 'certificates', '.', '<EOS>']
# predict:  ['they', 'sell', 'the', 'medicines', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['có', 'ba', 'nguồn', '<UNK>', '.', '<EOS>']
# target:  ['we', 'have', 'three', 'main', 'groups', '.', '<EOS>']
# predict:  ['there', 'are', 'three', 'sources', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['từ', 'những', 'tội_phạm', 'mạng', '<EOS>']
# target:  ['we', 'have', 'online', 'criminals', '.', '<EOS>']
# predict:  ['from', 'the', 'web', 'online', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['cám_ơn', 'các', 'bạn', '.', '<EOS>']
# target:  ['thank', 'you', '.', '<EOS>']
# predict:  ['thank', 'you', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['stephen', 'watt', '.', '<EOS>']
# target:  ['this', 'is', 'stephen', 'watt', '.', '<EOS>']
# predict:  ['stephen', 'watt', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['alfred', '<UNK>', '.', '<EOS>']
# target:  ['this', 'is', 'alfred', '<UNK>', '.', '<EOS>']
# predict:  ['he', 'was', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['kiếm', 'tiền', '!', '<EOS>']
# target:  ['these', 'guys', 'make', 'money', '.', '<EOS>']
# predict:  ['make', 'money', '!', '<EOS>']
# -----------------------------------------------
#
# input:  ['bjorn', 'sundin', '.', '<EOS>']
# target:  ['this', 'is', 'bjorn', 'sundin', '.', '<EOS>']
# predict:  ['bjorn', 'de', 'botton', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['họ', 'thậm_chí', 'sẽ', 'sử_dụng', 'những', 'công_cụ', 'như', 'trojan', '<UNK>', 'để', 'lây_nhiễm', 'vào', 'máy_tính', 'của', 'bạn', 'và', 'từ_đó', 'họ', 'có_thể', 'có', 'được', 'mọi', 'thông_tin', 'bạn', 'trao_đổi', 'có', 'được', 'mọi', 'cuộc', 'hội_thoại', 'qua', 'mạng', 'của', 'bạn', 'và', 'có', 'được', 'mật_khẩu', 'của', '<EOS>']
# target:  ['they', 'will', 'even', 'use', 'tools', 'like', 'state', '<UNK>', 'to', 'infect', 'your', 'computer', 'with', 'a', '<UNK>', 'which', 'enables', 'them', 'to', 'watch', 'all', 'your', 'communication', 'to', 'listen', 'to', 'your', 'online', 'discussions', 'to', 'collect', 'your', 'passwords', '.', '<EOS>']
# predict:  ['they', 're', 'using', 'software', 'software', 'to', 'get', 'their', 'computers', 'to', 'get', 'their', 'own', 'computer', 'and', 'they', 're', 'going', 'to', 'get', 'your', 'own', 'computer', 'and', 'you', 've', 'got', 'to', 'get', 'a', 'way', 'that', 's', 'used', 'to', 'get', 'and', 'get', 'through', 'the']
# -----------------------------------------------
#
# input:  ['ví_dụ', 'như', 'ở', 'đức', 'vài', 'tuần', 'trước_đây', 'người_ta', 'đã', 'phát_hiện', 'ra', 'trojan', '<UNK>', 'là', 'một', 'loại', 'trojan', 'được', 'nhân_viên', 'chính_phủ', 'đức', 'sử_dụng', 'để', 'điều_tra', 'người', 'dân', 'của', 'họ', '.', '<EOS>']
# target:  ['for', 'example', 'in', 'germany', 'just', 'a', 'couple', 'of', 'weeks', 'ago', 'the', 'so', 'called', 'state', '<UNK>', 'was', 'found', 'which', 'was', 'a', '<UNK>', 'used', 'by', 'german', 'government', 'officials', 'to', 'investigate', 'their', 'own', 'citizens', '.', '<EOS>']
# predict:  ['in', 'the', 'last', 'few', 'years', 'ago', 'he', 'was', 'a', 'german', 'government', 'recently', 'had', 'a', 'number', 'of', 'people', 'who', 'had', 'been', 'elected', 'to', 'use', 'their', 'government', 'to', 'their', 'government', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'trong_khi', 'chúng_ta', 'vẫn', 'tin_tưởng', 'vào', 'chính_phủ', 'ngay', 'lúc_này', 'ngay', 'tại', 'đây', 'vào', 'năm', 'này', 'rằng', 'mọi', 'quyền_lợi', 'chúng_ta', 'mất', 'đi', 'đều', 'là_vì', 'những', 'thứ', 'tốt_đẹp', 'hơn', '.', '<EOS>']
# target:  ['and', 'while', 'we', 'might', 'trust', 'our', 'governments', 'right', 'now', 'right', 'here', 'in', 'any', 'right', 'we', 'give', 'away', 'will', 'be', 'given', 'away', 'for', 'good', '.', '<EOS>']
# predict:  ['and', 'we', 're', 'certainly', 'dependent', 'in', 'the', 'world', 'because', 'we', 're', 'going', 'to', 'be', 'here', 'in', 'the', 'second', 'years', 'because', 'we', 're', 'all', 'these', 'things', 'that', 'are', 'more', 'things', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tuy_nhiên', 'sẽ', 'có_người', 'khi', 'xem_xét', 'vấn_đề', 'này', 'sẽ', 'phản_ứng', 'như_sau', 'ok', 'nghe', 'tệ', 'thật', 'đấy', 'nhưng', 'nó', 'không', 'ảnh_hưởng', 'gì', 'đến', 'tôi', 'vì', 'tôi', 'là', 'một', 'công_dân', '<UNK>', '<EOS>']
# target:  ['now', 'when', 'we', 'think', 'deeper', 'about', 'things', 'like', 'these', 'the', 'obvious', 'response', 'from', 'people', 'should', 'be', 'that', 'quot', 'okay', 'that', 'sounds', 'bad', 'but', 'that', 'doesn', 't', 'really', 'affect', 'me', 'because', 'i', 'm', 'a', 'legal', 'citizen', '.', '<EOS>']
# predict:  ['but', 'it', 's', 'going', 'to', 'be', 'bad', 'to', 'see', 'that', 's', 'going', 'to', 'be', 'bad', 'but', 'it', 's', 'not', 'going', 'to', 'be', 'because', 'i', 'm', 'sure', 'it', 's', 'a', 'bad', 'crime', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['và', 'liệu', 'chúng_ta', 'có', 'còn', 'tin_tưởng', 'một', 'cách', 'mù_quáng', 'vào', 'bất_kỳ', 'chính_phủ', 'tương_lai', 'nào', 'một', 'chính_phủ', 'mà', 'chúng_ta', 'có_thể', 'có', 'trong', 'năm_tới', '?', '<EOS>']
# target:  ['and', 'do', 'we', 'trust', 'do', 'we', 'blindly', 'trust', 'any', 'future', 'government', 'a', 'government', 'we', 'might', 'have', 'years', 'from', 'now', '?', '<EOS>']
# predict:  ['and', 'how', 'does', 'we', 'vote', 'a', 'government', 'to', 'vote', 'the', 'world', 's', 'aid', 'in', 'the', 'world', 'that', 'we', 'have', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['nếu', 'bạn', 'đang', 'bị', 'nghi_ngờ', 'có', 'dính_líu', 'đến', 'một', 'tội_ác', 'nào', 'đó', 'thì', 'điều', 'chắc_chắn', 'là', 'điện_thoại', 'của', 'bạn', 'đang', 'có', 'rệp', '.', '<EOS>']
# target:  ['if', 'you', 'are', 'a', 'suspect', 'in', 'a', 'criminal', 'case', 'well', 'it', 's', 'pretty', 'obvious', 'your', 'phone', 'will', 'be', 'tapped', '.', '<EOS>']
# predict:  ['if', 'you', 're', 'being', 'aware', 'that', 's', 'a', 'crime', 'that', 's', 'a', 'crime', 'that', 's', 'the', 'default', 'of', 'your', 'senses', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['đó', 'chính', 'là', 'câu', 'hỏi', 'mà', 'chúng_ta', 'sẽ', 'phải', 'lo_lắng', 'trong', 'năm', 'tiếp_theo', '.', '<EOS>']
# target:  ['and', 'these', 'are', 'the', 'questions', 'that', 'we', 'have', 'to', 'worry', 'about', 'for', 'the', 'next', 'years', '.', '<EOS>']
# predict:  ['that', 's', 'the', 'question', 'that', 'we', 'will', 'be', 'asked', 'to', 'do', 'in', 'the', 'last', 'years', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['đây', 'không', 'phải', 'là', 'vấn_đề', 'giữa', 'quyền', 'riêng_tư', 'và', 'an_ninh', 'của', 'đất_nước', '.', '<EOS>']
# target:  ['this', 'is', 'not', 'a', 'question', 'between', 'privacy', 'against', 'security', '.', '<EOS>']
# predict:  ['this', 'is', 'not', 'the', 'relationship', 'between', 'the', 'security', 'and', 'the', 'security', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'chính_phủ', 'phương_tây', 'cũng', 'thực_hiện', 'điều', 'đó', 'ngay', 'tại', 'quốc_gia', 'của', 'mình', '<EOS>']
# target:  ['but', 'western', 'governments', 'are', 'doing', 'it', 'to', 'themselves', 'as', 'well', '.', '<EOS>']
# predict:  ['but', 'china', 'also', 'also', 'recognized', 'that', 'in', 'the', 'country', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['đây', 'là', 'một', 'vấn_đề', 'giữa', 'tự_do', 'và', 'sự', 'kiểm_soát', '.', '<EOS>']
# target:  ['it', 's', 'a', 'question', 'of', 'freedom', 'against', 'control', '.', '<EOS>']
# predict:  ['this', 'is', 'a', 'distinction', 'of', 'freedom', 'and', 'transparency', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['tôi', 'hoàn_toàn', 'không', 'có', 'gì', 'khuất', '<UNK>', 'che', 'dấu', '.', '<EOS>']
# target:  ['because', 'i', 'have', 'nothing', 'to', 'hide', '.', 'quot', '<UNK>', '<EOS>']
# predict:  ['i', 'was', 'nothing', 'that', 'the', '<UNK>', 'was', 'the', '<UNK>', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['họ', 'nghe', 'lén', 'đường', 'truyền', 'internet', 'của', 'bạn', '.', '<EOS>']
# target:  ['they', 'will', 'tap', 'your', 'internet', 'connection', '.', '<EOS>']
# predict:  ['they', 'heard', 'the', 'internet', 'via', 'your', 'internet', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'mọi', 'chuyện', 'không', 'chỉ', 'dừng', 'ở', 'đó', '.', '<EOS>']
# target:  ['but', 'today', 'it', 'goes', 'beyond', 'that', '.', '<EOS>']
# predict:  ['but', 'it', 's', 'not', 'just', 'there', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['nhưng', 'lập_luận', 'này', 'là', 'không', 'hợp_lý', '.', '<EOS>']
# target:  ['and', 'this', 'is', 'an', 'argument', 'which', 'doesn', 't', 'make', 'sense', '.', '<EOS>']
# predict:  ['but', 'the', 'reason', 'is', 'not', 'fair', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['quyền', 'riêng', '<UNK>', 'cần', 'phải', 'tranh_luận', '.', '<EOS>']
# target:  ['privacy', 'is', 'not', 'up', 'for', 'discussion', '.', '<EOS>']
# predict:  ['<UNK>', 'is', 'a', '<UNK>', '.', '<EOS>']
# -----------------------------------------------
#
# input:  ['vậy', 'tại_sao', 'tôi', 'phải', 'lo_lắng', '?', '<EOS>']
# target:  ['why', 'should', 'i', 'worry', '?', '<EOS>']
# predict:  ['so', 'why', 'are', 'i', 'worry', '?', '<EOS>']
# -----------------------------------------------
#
# input:  ['quyền', 'riêng_tư', 'phải', 'được', 'đảm_bảo', '.', '<EOS>']
# target:  ['privacy', 'is', 'implied', '.', '<EOS>']
# predict:  ['privacy', 'is', 'to', 'be', 'trusted', '.', '<EOS>']
# -----------------------------------------------
